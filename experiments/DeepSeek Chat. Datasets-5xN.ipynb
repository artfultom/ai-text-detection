# %% [markdown]
# # Генерация датасетов моделью DeepSeek Chat
#
# DeepSeek-V3.2

# %%
EXAMPLE_ID = 0
MODEL = 'deepseek-chat'
START = 0
OUT_COUNT = 1000
OUT_FILE_PREFIX = 'deepseek_essays'
PAUSE_SECONDS = 1

# %% [markdown]
# ### Исходный датасет, написанный человеком

# %%
import pandas as pd

df = pd.read_csv("../datasets/human_essays.csv", encoding="utf-8")
df.head(10)
# Out:
#                                                title  \
# 0    12 Years a Slave: An Analysis of the Film Essay
# 1  20+ Social Media Post Ideas to Radically Simpl...
# 2  533 U.S. 27 (2001) Kyllo v. United States: The...
# 3            A Charles Schwab Corporation Case Essay
# 4  A Clinical Office Assistant’s Attire Research ...
# 5  A Comic Science Fiction Film “Back to the Futu...
# 6   A Community Yard Sale as a Memorable Event Essay
# 7  A Complex in the “Every Secret Thing” Film by ...
# 8  A Customer Told to Wear a Mask Threw Snow at a...
# 9  A Disconnect Between Public Transportation and...
#
#                                                 text
# 0  The 2013 film 12 Years a Slave proved that sla...
# 1  Social Media Examiner’s (2021) video on social...
# 2  Table of Contents\n 1. Facts\n 2. Issue\n 3. H...
# 3  Charles Schwab is a for-profit Corporation who...
# 4  The work of a clinical or medical office worke...
# 5  Table of Contents\n 1. Introduction\n 2. Movie...
# 6  Autumn is not generally viewed as an appropria...
# 7  Carl Jung identifies the mother complex with a...
# 8  The article describes a recent Chicago hot dog...
# 9  One realistic way to commute is using private ...

# %% [markdown]
# #### Пример:

# %%
print(f"{df.iloc[EXAMPLE_ID,0]}\n\n{df.iloc[EXAMPLE_ID,1]}")
# Out:
# 12 Years a Slave: An Analysis of the Film Essay
#
# The 2013 film 12 Years a Slave proved that slavery is a worldwide issue. Indeed, the film made $150 million outside the United States and $57 million in the U.S., with a production budget of $20 million (Sharf, 2020). The movie was based on the memoir Twelve Years a Slave by Solomon Northup (Ntim, 2020). It tells the story of a free African American man who was kidnapped and sold into slavery. Solomon spent twelve years away from his family, being traded from one master to another. Fortunately, the protagonist met a person who helped him deliver a message to his family and friends, who came and rescued him. This movie accurately illustrates discriminatory relationships between white slaveholders and black slaves that stemmed from the dysfunctional system in the country and prejudices in people’s mindsets at that time.
#
# The two main ethnic groups presented in this film are White and African Americans, and the three social groups are affluent slaveholders, working for middle class, and enslaved people. The movie starts with the story of a free African American violinist Solomon Northup, living with his family in Saratoga, New York (McQueen, 2013). However, he was abducted by two white men, who tortured the man and sold him into slavery, changing his name to Plat. Before they met, Solomon and these two slave traders belonged to the same middle class. However, the fact that Northup was an African American made these individuals believe that they had the right to withdraw their freedom. The two masters that Solomon had were William Ford and Edwin Epps (McQueen, 2013). The former was kind and religious, while the latter was cruel and sadistic. Since the movie was based on a real story, it indicated that slaveholders had different characters, but all had the wrong perception of race.
#
# Although 12 Years a Slave is a film about slavery, the issues of collectivism and individualism are also raised. Specifically, the main character never identified himself as an enslaved man and continued claiming he was a free citizen (McQueen, 2013). However, his counterparts on the plant had a collective mindset, imprinted in them since childhood, that slavery is normal. These people helped each other because they belonged to the same group. Although Solomon tried to become a part of this community, his individual goal to return home was above the collective values.
#
# The movie also showed prejudice, generalizations, stereotyping, and discrimination against black people. For instance, when Ford brings Solomon and Elisa to his plantation, his wife expresses her sadness that Elisa got separated from her children. However, she also stated that “something to eat and some rest” could help that woman forget her children (McQueen, 2013, 32:47-32:51). This scene demonstrated the common prejudice about slaves that they were not capable of the same feelings as white people. An example of generalization and stereotyping was how Tibeats, a carpenter, became hostile to Solomon when he showed his intelligence and gave Ford advice. In fact, Tibeats believed that Plat would never be more competent than any white individual because Plat was a “nigger” (McQueen, 2013, 36:35-36:37). Notably, before Northup became enslaved, he never experienced discrimination, but when the main character was sold into slavery, discrimination was the only attitude that he could observe.
#
# In summary, 12 Years a Slave depicts the life of enslaved people and slave owners almost two centuries ago. The film narrates a free black man’s life from the moment when he enjoyed his family’s company in the state of New York to his abduction, enslavement, and eventual liberation. Overall, the movie raised such critical issues as discrimination, prejudice, stereotyping, and generalization that allowed slaveholders to maintain this societal structure for a long time.
#
# References
#
# McQueen, S. (2013). 12 years a slave [Film]. New Regency Productions.
#
# Ntim, Z. (2020). Steve McQueen says it took 11 years to create his new anthology “Small Axe” and reveals why producers almost pulled out of his Oscar-winning film “12 Years a Slave.” Insider.
#
# Sharf, Z. (2020). Steve McQueen recalls producers rejecting “12 Years a Slave” over false beliefs about black films. Indie Wire.

# %% [markdown]
# ### Утилиты

# %%
import math
import re


def round_word_count(c):
    return math.floor(c / 100) * 100

def word_count(text):
    words = re.findall(r'\b\w+\b', text)
    return round_word_count(len(words))

def print_example(data, example_id):
    if 'prompt' in data.iloc[example_id]:
        print(f"Prompt {'=' * 93}\n{data.iloc[example_id]['prompt']}")
        print(f"{'=' * 100}")
        print(f"{data.iloc[example_id]['title']}\n\n{data.iloc[example_id]['text']}")
        print(f"{'=' * 100}")
    if 'prompt_2' in data.iloc[example_id]:
        print(f"Prompt 1 {'=' * 93}\n{data.iloc[example_id]['prompt_1']}")
        print(f"{'=' * 100}")
        print(f"{data.iloc[example_id]['response']}")
        print(f"Prompt 2 {'=' * 93}\n{data.iloc[example_id]['prompt_2']}")
        print(f"{'=' * 100}")
        print(f"{data.iloc[example_id]['title']}\n\n{data.iloc[example_id]['text']}")
        print(f"{'=' * 100}")

def print_progress(start, i, n):
    if (i - start) % (n / 100) == 0:
        print(f"{100 * (i - start) / n}% done")

# %%
from dotenv import load_dotenv
import os
from openai import OpenAI


load_dotenv()

client = OpenAI(api_key=os.getenv("DEEPSEEK_API_KEY"), base_url="https://api.deepseek.com")

# %%
import time


def generate_response(prompt):
    response = client.chat.completions.create(
        model=MODEL,
        messages=[
            {
                "role": "system",
                "content": "You are an expert academic essay writer. You produce well-structured, logical, and substantive essays with clear argumentation, proper citations, and academic rigor."
            },
            {
                "role": "user",
                "content": prompt
            }
        ],
        stream=False
    )

    time.sleep(PAUSE_SECONDS)
    
    return response.choices[0].message.content

# %% [markdown]
# ### Вариант 1. Prompt-based generation
#
# ```
# Write an essay of about {} words on the topic '{}'.
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
# ```

# %%
def generate(model_name, df, prompt_raw, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
    
        prompt_formatted = prompt_raw.format(length, title)

        try:
            response = generate_response(prompt_formatted)
        except:
            continue
            
        response = response.lstrip()
    
        rows.append({"title": title, "prompt": prompt_formatted, "text": response, "model": model_name})

        print_progress(start, i, n)
    
    return pd.DataFrame(rows)

# %%
prompt = """
Write an essay of about {} words on the topic '{}'.
Start directly with the first sentence of the essay. Absolutely no title or heading of any kind. 
Output only the essay text. 
"""

df1 = generate(MODEL, df, prompt, start=START, n=OUT_COUNT)
df1.head()
# Out:
# 0.0% done
# 1.0% done
# 2.0% done
# 3.0% done
# 4.0% done
# 5.0% done
# 6.0% done
# 7.0% done
# 8.0% done
# 9.0% done
# 10.0% done
# 11.0% done
# 12.0% done
# 13.0% done
# 14.0% done
# 15.0% done
# 16.0% done
# 17.0% done
# 18.0% done
# 19.0% done
# 20.0% done
# 21.0% done
# 22.0% done
# 23.0% done
# 24.0% done
# 25.0% done
# 26.0% done
# 27.0% done
# 28.0% done
# 29.0% done
# 30.0% done
# 31.0% done
# 32.0% done
# 33.0% done
# 34.0% done
# 35.0% done
# 36.0% done
# 37.0% done
# 38.0% done
# 39.0% done
# 40.0% done
# 41.0% done
# 42.0% done
# 43.0% done
# 44.0% done
# 45.0% done
# 46.0% done
# 47.0% done
# 48.0% done
# 49.0% done
# 50.0% done
# 51.0% done
# 52.0% done
# 53.0% done
# 54.0% done
# 55.0% done
# 56.0% done
# 57.0% done
# 58.0% done
# 59.0% done
# 60.0% done
# 61.0% done
# 62.0% done
# 63.0% done
# 64.0% done
# 65.0% done
# 66.0% done
# 67.0% done
# 68.0% done
# 69.0% done
# 70.0% done
# 71.0% done
# 72.0% done
# 73.0% done
# 74.0% done
# 75.0% done
# 76.0% done
# 77.0% done
# 78.0% done
# 79.0% done
# 80.0% done
# 81.0% done
# 82.0% done
# 83.0% done
# 84.0% done
# 85.0% done
# 86.0% done
# 87.0% done
# 88.0% done
# 89.0% done
# 90.0% done
# 91.0% done
# 92.0% done
# 93.0% done
# 94.0% done
# 95.0% done
# 96.0% done
# 97.0% done
# 98.0% done
# 99.0% done
#                                                title  \
# 0    12 Years a Slave: An Analysis of the Film Essay
# 1  20+ Social Media Post Ideas to Radically Simpl...
# 2  533 U.S. 27 (2001) Kyllo v. United States: The...
# 3            A Charles Schwab Corporation Case Essay
# 4  A Clinical Office Assistant’s Attire Research ...
#
#                                               prompt  \
# 0  \nWrite an essay of about 600 words on the top...
# 1  \nWrite an essay of about 300 words on the top...
# 2  \nWrite an essay of about 300 words on the top...
# 3  \nWrite an essay of about 300 words on the top...
# 4  \nWrite an essay of about 400 words on the top...
#
#                                                 text          model
# 0  The cinematic adaptation of Solomon Northup’s ...  deepseek-chat
# 1  In an era of digital saturation, the most effe...  deepseek-chat
# 2  The Supreme Court’s decision in *Kyllo v. Unit...  deepseek-chat
# 3  The Charles Schwab Corporation’s evolution fro...  deepseek-chat
# 4  The significance of a clinical office assistan...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df1, EXAMPLE_ID)
# Out:
# Prompt =============================================================================================
#
# Write an essay of about 600 words on the topic '12 Years a Slave: An Analysis of the Film Essay'.
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
#
# ====================================================================================================
# 12 Years a Slave: An Analysis of the Film Essay
#
# The cinematic adaptation of Solomon Northup’s 1853 memoir, *12 Years a Slave*, directed by Steve McQueen, transcends the conventions of the historical drama to deliver a visceral and unflinching meditation on the institutionalized horror of American slavery. Rather than offering a narrative of triumphant escape or redemptive violence, the film immerses the viewer in the brutal, mundane reality of the “peculiar institution,” using Northup’s singular ordeal as a lens to examine the systemic dehumanization, psychological complexity, and moral corruption inherent in the slaveholding South. Through its meticulous aesthetic choices, stark character portrayals, and deliberate narrative pacing, the film constructs a powerful essay on the nature of stolen liberty and the resilience of the human spirit under conditions designed to crush it.
#
# Central to the film’s analytical power is its unrelenting focus on the physical and psychological mechanics of slavery. McQueen refuses to shy away from prolonged, almost painterly scenes of violence, such as the harrowing sequence of Patsey’s whipping. These are not presented as sensationalist spectacle but as clinical, necessary evidence. The prolonged takes force the audience to endure what the characters endure, breaking the typical cinematic rhythm that allows for emotional distance. This technique essays the idea that violence was not an aberration but a fundamental tool of control, a daily currency of terror that sustained the economic system. The soundscape—the crack of the whip, the labored breathing, the oppressive silence of the fields—further underscores this, making the institution feel inescapably tangible. Solomon’s own journey from a free man of status to a piece of property named “Platt” meticulously charts the process of dehumanization, where his skills, intelligence, and very identity are either suppressed or co-opted for his master’s benefit.
#
# The film further deepens its analysis through its nuanced, though unforgiving, portrayal of slaveholders. The dichotomy between the ostensibly “benevolent” master Ford (Benedict Cumberbatch) and the pathologically cruel Edwin Epps (Michael Fassbender) is ultimately revealed as a false one. Ford, while expressing personal discomfort with slavery, actively participates in and profits from the system; his kindness is a conditional luxury that does nothing to challenge the inherent injustice. Epps, in contrast, embodies the system’s logical extreme, using scripture to justify his brutality and exhibiting a twisted, possessive obsession with Patsey that lays bare the sexual violence underpinning the master-slave dynamic. These character studies argue that the institution corrupted all within its sphere, from the self-deluded paternalist to the outright sadist, creating a moral universe where humanity was irrevocably fractured.
#
# Perhaps the most profound element of the film’s essay is its exploration of survival and identity. Solomon’s resilience is not depicted through overt rebellion but through a desperate, intelligent clinging to his sense of self. His whispered declaration, “I don’t want to survive. I want to live,” encapsulates the core existential struggle. The preservation of his identity becomes an internal act of defiance—crafting a violin, a symbol of his cultured past, or secretly writing his name. The film suggests that in an system designed to reduce people to laboring bodies, the maintenance of one’s inner life is a radical act. This focus complicates simpler narratives of resistance, highlighting the profound psychological warfare waged upon the enslaved.
#
# In its final moments, the film offers a resolution that is emotionally potent yet deliberately anti-cathartic. Solomon’s return to his family is shrouded in a haunting silence and a gaze directly into the camera that seems to hold centuries of anguish and accusation. There is no grand speech, no sweeping score promising national healing. This choice reinforces the film’s core thesis: while Northup’s personal ordeal ended, the system that ensnared him endured, and its legacy is imprinted on the present. *12 Years a Slave* thus succeeds not merely as a historical recounting but as a rigorous cinematic essay. It uses one man’s story to dissect the anatomy of slavery itself, compelling the viewer to witness, to reflect, and to understand that the past’s brutality is not a closed chapter but a foundational trauma whose echoes demand continual examination.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_1.csv"

df1.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 2. Prompt-based Style Transfer
#
# ```
# Write an essay of about {} words on the topic '{}', following the stylistic and structural conventions of IvyPanda essays.
#
# STYLE REQUIREMENTS (IvyPanda-like):
# 1. The tone must be academic, clear, neutral, and objective.
# 2. The essay should include background context, a clear analytical structure, and well-developed paragraphs.
# 3. Arguments must be supported with reasoning, concise explanations, and relevant examples.
# 4. The writing must be coherent, logically progressive, and easy to read.
# 5. Avoid emotional language or overly dramatic phrasing.
#
# STRUCTURE REQUIREMENTS:
# 1. Divide the essay into several sections, each starting with a plain-text subheading.
# 2. Subheadings must contain only letters and spaces — no punctuation, no symbols, and absolutely no Markdown formatting.
#    - This means: no asterisks, no bold, no italics, no underscores, no brackets.
#    - Subheadings must appear as plain text lines, e.g. Background Context
# 3. Each subheading must be on its own line with exactly one blank line before and after it.
# 4. No overall essay title — begin directly with the first subheading.
# 5. Output must be plain text only (no Markdown, no asterisks, no bold, no italics, no hashtags, no special formatting).
#
# OPTIONAL ELEMENTS:
# You may include a plain-text references section at the end if appropriate to the topic, but this is optional.
#
# Begin with the first subheading, then continue with the first paragraph.
# Output only the essay text.
# ```

# %%
def generate(model_name, df, prompt_raw, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
    
        prompt_formatted = prompt_raw.format(length, title)
    
        try:
            response = generate_response(prompt_formatted)
        except:
            continue
            
        response = response.lstrip()
    
        rows.append({"title": title, "prompt": prompt_formatted, "text": response, "model": model_name})

        print_progress(start, i, n)
    
    return pd.DataFrame(rows)

# %%
prompt = """
Write an essay of about {} words on the topic '{}', following the stylistic and structural conventions of IvyPanda essays.

STYLE REQUIREMENTS (IvyPanda-like):
1. The tone must be academic, clear, neutral, and objective.
2. The essay should include background context, a clear analytical structure, and well-developed paragraphs.
3. Arguments must be supported with reasoning, concise explanations, and relevant examples.
4. The writing must be coherent, logically progressive, and easy to read.
5. Avoid emotional language or overly dramatic phrasing.

STRUCTURE REQUIREMENTS:
1. Divide the essay into several sections, each starting with a plain-text subheading.
2. Subheadings must contain only letters and spaces — no punctuation, no symbols, and absolutely no Markdown formatting.
   - This means: no asterisks, no bold, no italics, no underscores, no brackets.
   - Subheadings must appear as plain text lines, e.g. Background Context
3. Each subheading must be on its own line with exactly one blank line before and after it.
4. No overall essay title — begin directly with the first subheading.
5. Output must be plain text only (no Markdown, no asterisks, no bold, no italics, no hashtags, no special formatting).

OPTIONAL ELEMENTS:
You may include a plain-text references section at the end if appropriate to the topic, but this is optional.

Begin with the first subheading, then continue with the first paragraph.
Output only the essay text.
"""

df2 = generate(MODEL, df, prompt, start=START, n=OUT_COUNT)
df2.head()
# Out:
# 0.0% done
# 1.0% done
# 2.0% done
# 3.0% done
# 4.0% done
# 5.0% done
# 6.0% done
# 7.0% done
# 8.0% done
# 9.0% done
# 10.0% done
# 11.0% done
# 12.0% done
# 13.0% done
# 14.0% done
# 15.0% done
# 16.0% done
# 17.0% done
# 18.0% done
# 19.0% done
# 20.0% done
# 21.0% done
# 22.0% done
# 23.0% done
# 24.0% done
# 25.0% done
# 26.0% done
# 27.0% done
# 28.0% done
# 29.0% done
# 30.0% done
# 31.0% done
# 32.0% done
# 33.0% done
# 34.0% done
# 35.0% done
# 36.0% done
# 37.0% done
# 38.0% done
# 39.0% done
# 40.0% done
# 41.0% done
# 42.0% done
# 43.0% done
# 44.0% done
# 45.0% done
# 46.0% done
# 47.0% done
# 48.0% done
# 49.0% done
# 50.0% done
# 51.0% done
# 52.0% done
# 53.0% done
# 54.0% done
# 55.0% done
# 56.0% done
# 57.0% done
# 58.0% done
# 59.0% done
# 60.0% done
# 61.0% done
# 62.0% done
# 63.0% done
# 64.0% done
# 65.0% done
# 66.0% done
# 67.0% done
# 68.0% done
# 69.0% done
# 70.0% done
# 71.0% done
# 72.0% done
# 73.0% done
# 74.0% done
# 75.0% done
# 76.0% done
# 77.0% done
# 78.0% done
# 79.0% done
# 80.0% done
# 81.0% done
# 82.0% done
# 83.0% done
# 84.0% done
# 85.0% done
# 86.0% done
# 87.0% done
# 88.0% done
# 89.0% done
# 90.0% done
# 91.0% done
# 92.0% done
# 93.0% done
# 94.0% done
# 95.0% done
# 96.0% done
# 97.0% done
# 98.0% done
# 99.0% done
#                                                title  \
# 0    12 Years a Slave: An Analysis of the Film Essay
# 1  20+ Social Media Post Ideas to Radically Simpl...
# 2  533 U.S. 27 (2001) Kyllo v. United States: The...
# 3            A Charles Schwab Corporation Case Essay
# 4  A Clinical Office Assistant’s Attire Research ...
#
#                                               prompt  \
# 0  \nWrite an essay of about 600 words on the top...
# 1  \nWrite an essay of about 300 words on the top...
# 2  \nWrite an essay of about 300 words on the top...
# 3  \nWrite an essay of about 300 words on the top...
# 4  \nWrite an essay of about 400 words on the top...
#
#                                                 text          model
# 0  Background Context\n\nThe 2013 film *12 Years ...  deepseek-chat
# 1  Background Context\n\nThe contemporary marketi...  deepseek-chat
# 2  Background Context\n\nThe Fourth Amendment to ...  deepseek-chat
# 3  Background Context\n\nThe Charles Schwab Corpo...  deepseek-chat
# 4  Background Context\n\nThe attire of clinical o...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df2, EXAMPLE_ID)
# Out:
# Prompt =============================================================================================
#
# Write an essay of about 600 words on the topic '12 Years a Slave: An Analysis of the Film Essay', following the stylistic and structural conventions of IvyPanda essays.
#
# STYLE REQUIREMENTS (IvyPanda-like):
# 1. The tone must be academic, clear, neutral, and objective.
# 2. The essay should include background context, a clear analytical structure, and well-developed paragraphs.
# 3. Arguments must be supported with reasoning, concise explanations, and relevant examples.
# 4. The writing must be coherent, logically progressive, and easy to read.
# 5. Avoid emotional language or overly dramatic phrasing.
#
# STRUCTURE REQUIREMENTS:
# 1. Divide the essay into several sections, each starting with a plain-text subheading.
# 2. Subheadings must contain only letters and spaces — no punctuation, no symbols, and absolutely no Markdown formatting.
#    - This means: no asterisks, no bold, no italics, no underscores, no brackets.
#    - Subheadings must appear as plain text lines, e.g. Background Context
# 3. Each subheading must be on its own line with exactly one blank line before and after it.
# 4. No overall essay title — begin directly with the first subheading.
# 5. Output must be plain text only (no Markdown, no asterisks, no bold, no italics, no hashtags, no special formatting).
#
# OPTIONAL ELEMENTS:
# You may include a plain-text references section at the end if appropriate to the topic, but this is optional.
#
# Begin with the first subheading, then continue with the first paragraph.
# Output only the essay text.
#
# ====================================================================================================
# 12 Years a Slave: An Analysis of the Film Essay
#
# Background Context
#
# The 2013 film *12 Years a Slave*, directed by Steve McQueen and based on Solomon Northup’s 1853 memoir of the same name, stands as a seminal work in the cinematic portrayal of American slavery. Its critical and commercial success, including the Academy Award for Best Picture, underscores its cultural impact. Unlike many historical dramas that employ a degree of narrative distance or redemptive framing, McQueen’s film distinguishes itself through an unflinching, visceral approach. It functions not merely as a period piece but as a rigorous historical and psychological analysis of the “peculiar institution.” The film’s power derives from its commitment to depicting the systemic brutality of slavery while simultaneously exploring the complex mechanisms of survival, identity, and resistance through the specific, harrowing journey of its protagonist, a free Black man kidnapped and sold into bondage.
#
# Narrative Perspective and Historical Authenticity
#
# The film’s analytical potency is rooted in its narrative perspective. By telling the story from the first-person viewpoint of Solomon Northup, a literate violinist and free man from New York, the film immediately establishes a critical lens. Solomon’s initial status as a free citizen allows the audience to enter the world of slavery not as an abstract historical concept, but as a sudden, violent imposition. This perspective shatters any notion of enslaved people as inherently accustomed to their condition. His internal monologue, his desperate attempts to assert his true identity, and his strategic silence all serve as a continuous commentary on the system’s fundamental denial of personhood. Furthermore, the film’s dedication to historical authenticity, meticulously recreating the language, settings, and brutal labor practices of Louisiana plantations, grounds its analysis in tangible reality. This authenticity refuses to allow the viewer the comfort of abstraction, making the systemic violence palpably personal.
#
# The Machinery of Dehumanization
#
# A central analytical thrust of the film is its detailed examination of the machinery of dehumanization. McQueen presents slavery not as a monolithic evil but as a multifaceted system sustained by economic logic, legal sanction, and pervasive psychological terror. The character of Edwin Epps, a plantation owner who justifies his cruelty with distorted biblical passages, exemplifies the ideological underpinnings used to legitimize brutality. The film meticulously depicts the tools of control: the constant surveillance, the arbitrary punishments, the deliberate separation of families, and the erasure of original names. A pivotal scene involves Solomon being forced to whip Patsey, a fellow enslaved woman. This moment is not just an act of physical violence but a profound psychological assault, designed to break Solomon’s spirit by compelling him to participate in the very system that torments him. The camera’s unblinking gaze on such atrocities forces an analytical recognition of slavery as a process that seeks to corrupt both the victim and, in different ways, the perpetrator.
#
# Resistance and the Fragility of the Self
#
# Despite its grim subject matter, the film’s analysis extends to nuanced forms of resistance and the struggle to maintain a sense of self. Solomon’s journey is a study in adaptive survival. His initial, vocal protests give way to a calculated performance of submission, all while he secretly plans his escape. This intellectual resistance—retaining his knowledge, his memory of freedom, and his hope—is portrayed as a vital act of defiance. The character of Patsey represents another dimension of this analysis. Her exceptional skill at picking cotton makes her economically valuable to Epps, yet this “favor” only intensifies her suffering, highlighting the perverse dynamics of the system. Her request for Solomon to end her life is a tragic articulation of a desire for agency, however horrific. The film suggests that within the totalizing institution of slavery, resistance manifests in a spectrum of ways, from quiet solidarity and cultural preservation to the sheer act of enduring.
#
# Conclusion
#
# *12 Years a Slave* transcends its role as a historical drama to offer a penetrating analytical essay on film. Through its focused narrative perspective, commitment to visceral authenticity, and exploration of dehumanization and resistance, it dissects the American slave system with unparalleled clarity. The film avoids sentimentalism or easy moralizing, opting instead for a stark, almost forensic examination that implicates the viewer in its gaze. By centering the experience of a man who knew freedom, it underscores slavery as a deliberate and contingent crime against humanity, not a natural state. In doing so, the film serves as a powerful cinematic testament to Solomon Northup’s story and a challenging, essential work of historical analysis.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_2.csv"

df2.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 3. Few-shot prompting
#
# ```
# You are a helpful writing assistant. Your task is to generate essays of a given length and topic.
# Start directly with the first sentence. No titles or headings. Output only the essay text.
#
# Here is an example:
#
# Example topic: "{}"
# Example length: {} words
#
# Example output:
# {}
#
# Now generate a new essay.
#
# Topic: "{}"
# Length: {} words
#
# Write the essay now.
# ```
#
# В качестве примера используется эссе из этого же набора, но на другую тему.

# %%
def generate_few_shot(model_name, df, prompt_raw, start=0, n=5000):
    rows = []
    for i in range(start + 1, start + n + 1):
        prev_title = df.loc[i - 1, "title"]
        prev_length = word_count(df.loc[i - 1, "text"])
        prev_text = df.loc[i - 1, "text"]
        
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
    
        prompt_formatted = prompt_raw.format(prev_title, prev_length, prev_text, title, length)

        try:
            response = generate_response(prompt_formatted)
        except:
            continue
            
        response = response.lstrip()
    
        rows.append({"title": title, "prompt": prompt_formatted, "text": response, "model": model_name})

        print_progress(start, i, n)
    
    return pd.DataFrame(rows)

# %%
prompt = """
You are a helpful writing assistant. Your task is to generate essays of a given length and topic.
Start directly with the first sentence. No titles or headings. Output only the essay text.

Here is an example:

Example topic: "{}"
Example length: {} words

Example output:
{}

Now generate a new essay.

Topic: "{}"
Length: {} words

Write the essay now.
"""

df3 = generate_few_shot(MODEL, df, prompt, start=START, n=OUT_COUNT)
df3.head()
# Out:
# 1.0% done
# 2.0% done
# 3.0% done
# 4.0% done
# 5.0% done
# 6.0% done
# 7.0% done
# 8.0% done
# 9.0% done
# 10.0% done
# 11.0% done
# 12.0% done
# 13.0% done
# 14.0% done
# 15.0% done
# 16.0% done
# 17.0% done
# 18.0% done
# 19.0% done
# 20.0% done
# 21.0% done
# 22.0% done
# 23.0% done
# 24.0% done
# 25.0% done
# 26.0% done
# 27.0% done
# 28.0% done
# 29.0% done
# 30.0% done
# 31.0% done
# 32.0% done
# 33.0% done
# 34.0% done
# 35.0% done
# 36.0% done
# 37.0% done
# 38.0% done
# 39.0% done
# 40.0% done
# 41.0% done
# 42.0% done
# 43.0% done
# 44.0% done
# 45.0% done
# 46.0% done
# 47.0% done
# 48.0% done
# 49.0% done
# 50.0% done
# 51.0% done
# 52.0% done
# 53.0% done
# 54.0% done
# 55.0% done
# 56.0% done
# 57.0% done
# 58.0% done
# 59.0% done
# 60.0% done
# 61.0% done
# 62.0% done
# 63.0% done
# 64.0% done
# 65.0% done
# 66.0% done
# 67.0% done
# 68.0% done
# 69.0% done
# 70.0% done
# 71.0% done
# 72.0% done
# 73.0% done
# 74.0% done
# 75.0% done
# 76.0% done
# 77.0% done
# 78.0% done
# 79.0% done
# 80.0% done
# 81.0% done
# 82.0% done
# 83.0% done
# 84.0% done
# 85.0% done
# 86.0% done
# 87.0% done
# 88.0% done
# 89.0% done
# 90.0% done
# 91.0% done
# 92.0% done
# 93.0% done
# 94.0% done
# 95.0% done
# 96.0% done
# 97.0% done
# 98.0% done
# 99.0% done
# 100.0% done
#                                                title  \
# 0  20+ Social Media Post Ideas to Radically Simpl...
# 1  533 U.S. 27 (2001) Kyllo v. United States: The...
# 2            A Charles Schwab Corporation Case Essay
# 3  A Clinical Office Assistant’s Attire Research ...
# 4  A Comic Science Fiction Film “Back to the Futu...
#
#                                               prompt  \
# 0  \nYou are a helpful writing assistant. Your ta...
# 1  \nYou are a helpful writing assistant. Your ta...
# 2  \nYou are a helpful writing assistant. Your ta...
# 3  \nYou are a helpful writing assistant. Your ta...
# 4  \nYou are a helpful writing assistant. Your ta...
#
#                                                 text          model
# 0  The relentless demand for fresh content can ma...  deepseek-chat
# 1  In the landmark case of Kyllo v. United States...  deepseek-chat
# 2  The Charles Schwab Corporation, founded in 197...  deepseek-chat
# 3  The attire of a clinical office assistant serv...  deepseek-chat
# 4  The 1985 film *Back to the Future*, directed b...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df3, EXAMPLE_ID)
# Out:
# Prompt =============================================================================================
#
# You are a helpful writing assistant. Your task is to generate essays of a given length and topic.
# Start directly with the first sentence. No titles or headings. Output only the essay text.
#
# Here is an example:
#
# Example topic: "12 Years a Slave: An Analysis of the Film Essay"
# Example length: 600 words
#
# Example output:
# The 2013 film 12 Years a Slave proved that slavery is a worldwide issue. Indeed, the film made $150 million outside the United States and $57 million in the U.S., with a production budget of $20 million (Sharf, 2020). The movie was based on the memoir Twelve Years a Slave by Solomon Northup (Ntim, 2020). It tells the story of a free African American man who was kidnapped and sold into slavery. Solomon spent twelve years away from his family, being traded from one master to another. Fortunately, the protagonist met a person who helped him deliver a message to his family and friends, who came and rescued him. This movie accurately illustrates discriminatory relationships between white slaveholders and black slaves that stemmed from the dysfunctional system in the country and prejudices in people’s mindsets at that time.
#
# The two main ethnic groups presented in this film are White and African Americans, and the three social groups are affluent slaveholders, working for middle class, and enslaved people. The movie starts with the story of a free African American violinist Solomon Northup, living with his family in Saratoga, New York (McQueen, 2013). However, he was abducted by two white men, who tortured the man and sold him into slavery, changing his name to Plat. Before they met, Solomon and these two slave traders belonged to the same middle class. However, the fact that Northup was an African American made these individuals believe that they had the right to withdraw their freedom. The two masters that Solomon had were William Ford and Edwin Epps (McQueen, 2013). The former was kind and religious, while the latter was cruel and sadistic. Since the movie was based on a real story, it indicated that slaveholders had different characters, but all had the wrong perception of race.
#
# Although 12 Years a Slave is a film about slavery, the issues of collectivism and individualism are also raised. Specifically, the main character never identified himself as an enslaved man and continued claiming he was a free citizen (McQueen, 2013). However, his counterparts on the plant had a collective mindset, imprinted in them since childhood, that slavery is normal. These people helped each other because they belonged to the same group. Although Solomon tried to become a part of this community, his individual goal to return home was above the collective values.
#
# The movie also showed prejudice, generalizations, stereotyping, and discrimination against black people. For instance, when Ford brings Solomon and Elisa to his plantation, his wife expresses her sadness that Elisa got separated from her children. However, she also stated that “something to eat and some rest” could help that woman forget her children (McQueen, 2013, 32:47-32:51). This scene demonstrated the common prejudice about slaves that they were not capable of the same feelings as white people. An example of generalization and stereotyping was how Tibeats, a carpenter, became hostile to Solomon when he showed his intelligence and gave Ford advice. In fact, Tibeats believed that Plat would never be more competent than any white individual because Plat was a “nigger” (McQueen, 2013, 36:35-36:37). Notably, before Northup became enslaved, he never experienced discrimination, but when the main character was sold into slavery, discrimination was the only attitude that he could observe.
#
# In summary, 12 Years a Slave depicts the life of enslaved people and slave owners almost two centuries ago. The film narrates a free black man’s life from the moment when he enjoyed his family’s company in the state of New York to his abduction, enslavement, and eventual liberation. Overall, the movie raised such critical issues as discrimination, prejudice, stereotyping, and generalization that allowed slaveholders to maintain this societal structure for a long time.
#
# References
#
# McQueen, S. (2013). 12 years a slave [Film]. New Regency Productions.
#
# Ntim, Z. (2020). Steve McQueen says it took 11 years to create his new anthology “Small Axe” and reveals why producers almost pulled out of his Oscar-winning film “12 Years a Slave.” Insider.
#
# Sharf, Z. (2020). Steve McQueen recalls producers rejecting “12 Years a Slave” over false beliefs about black films. Indie Wire.
#
#
# Now generate a new essay.
#
# Topic: "20+ Social Media Post Ideas to Radically Simplify Your Marketing Essay"
# Length: 300 words
#
# Write the essay now.
#
# ====================================================================================================
# 20+ Social Media Post Ideas to Radically Simplify Your Marketing Essay
#
# The relentless demand for fresh content can make social media marketing feel overwhelmingly complex, yet a strategic simplification of approach can yield greater consistency and engagement. The key is to develop a repository of reliable, repeatable post ideas that align with core business objectives without requiring constant creative reinvention. One foundational category is educational content, which positions a brand as a trusted authority; this can be simplified into formats like "Tip of the Week" graphics, quick tutorial videos using trending audio, or curated lists of industry resources. Another radically simple strategy is to leverage user-generated content, transforming customers into brand advocates by featuring their photos, testimonials, or reviews in a dedicated weekly spotlight, which builds community while filling the content calendar. Furthermore, interactive posts such as polls, questions, and "fill-in-the-blank" prompts require minimal production effort but generate valuable audience insights and boost algorithmic visibility. Behind-the-scenes content also remains perennially effective, humanizing a brand through simple photos of the team, a time-lapse of a product being made, or a candid office moment. Ultimately, simplification does not mean a reduction in quality but rather a focus on core, sustainable content pillars. By establishing a rotating schedule of these proven idea categories—education, social proof, interaction, and transparency—marketers can escape the cycle of content panic, ensure a consistent brand presence, and free up resources to engage meaningfully with their audience. This systematic approach turns the chaos of constant posting into a manageable, results-oriented process.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_3.csv"

df3.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 4. Content Abstraction (Regeneration Learning)
#
# Первый промпт:
# ```
# Identify the writing style and format of the text, excluding all semantic content and themes.
#
# Text:
# {}
# ```
#
# Второй промпт:
# ```
# Write an essay of about {} words on the topic '{}'.
#
# You are given the following style-and-format description:
# '{}'
#
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
# ```

# %%
def generate_with_content(model_name, df, prompt_raw_1, prompt_raw_2, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
        text = df.loc[i, "text"]

        prompt_1_formatted = prompt_raw_1.format(text)

        try:
            response_1 = generate_response(prompt_1_formatted)
            response_1 = response_1.lstrip()
    
            prompt_2_formatted = prompt_raw_2.format(length, title, response_1)
            response_2 = generate_response(prompt_2_formatted)
        except:
            continue
            
        response = response_2.lstrip()
    
        rows.append({
            "title": title, 
            "prompt_1": prompt_1_formatted, 
            "response": response_1,
            "prompt_2": prompt_2_formatted, 
            "text": response, 
            "model": model_name
        })

        print_progress(start, i, n)
    
    return pd.DataFrame(rows)

# %%
prompt_1 = """
Identify the writing style and format of the text, excluding all semantic content and themes.

Text:
{}
"""

prompt_2 = """
Write an essay of about {} words on the topic '{}'.

You are given the following style-and-format description:
'{}'

Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
Output only the essay text.
"""

# %%
df4 = generate_with_content(MODEL, df, prompt_1, prompt_2, start=START, n=OUT_COUNT)
df4.head()
# Out:
# 0.0% done
# 1.0% done
# 2.0% done
# 3.0% done
# 4.0% done
# 5.0% done
# 6.0% done
# 7.0% done
# 8.0% done
# 9.0% done
# 10.0% done
# 11.0% done
# 12.0% done
# 13.0% done
# 14.0% done
# 15.0% done
# 16.0% done
# 17.0% done
# 18.0% done
# 19.0% done
# 20.0% done
# 21.0% done
# 22.0% done
# 23.0% done
# 24.0% done
# 25.0% done
# 26.0% done
# 27.0% done
# 28.0% done
# 29.0% done
# 30.0% done
# 31.0% done
# 32.0% done
# 33.0% done
# 34.0% done
# 35.0% done
# 36.0% done
# 37.0% done
# 38.0% done
# 39.0% done
# 40.0% done
# 41.0% done
# 42.0% done
# 43.0% done
# 44.0% done
# 45.0% done
# 46.0% done
# 47.0% done
# 48.0% done
# 49.0% done
# 50.0% done
# 51.0% done
# 52.0% done
# 53.0% done
# 54.0% done
# 55.0% done
# 56.0% done
# 57.0% done
# 58.0% done
# 59.0% done
# 60.0% done
# 61.0% done
# 62.0% done
# 63.0% done
# 64.0% done
# 65.0% done
# 66.0% done
# 67.0% done
# 68.0% done
# 69.0% done
# 70.0% done
# 71.0% done
# 72.0% done
# 73.0% done
# 74.0% done
# 75.0% done
# 76.0% done
# 77.0% done
# 78.0% done
# 79.0% done
# 80.0% done
# 81.0% done
# 82.0% done
# 83.0% done
# 84.0% done
# 85.0% done
# 86.0% done
# 87.0% done
# 88.0% done
# 89.0% done
# 90.0% done
# 91.0% done
# 92.0% done
# 93.0% done
# 94.0% done
# 95.0% done
# 96.0% done
# 97.0% done
# 98.0% done
# 99.0% done
#                                                title  \
# 0    12 Years a Slave: An Analysis of the Film Essay
# 1  20+ Social Media Post Ideas to Radically Simpl...
# 2  533 U.S. 27 (2001) Kyllo v. United States: The...
# 3            A Charles Schwab Corporation Case Essay
# 4  A Clinical Office Assistant’s Attire Research ...
#
#                                             prompt_1  \
# 0  \nIdentify the writing style and format of the...
# 1  \nIdentify the writing style and format of the...
# 2  \nIdentify the writing style and format of the...
# 3  \nIdentify the writing style and format of the...
# 4  \nIdentify the writing style and format of the...
#
#                                             response  \
# 0  The writing style is **academic** and **analyt...
# 1  **Writing Style and Format Analysis**\n\n**For...
# 2  Based solely on its structural and formal char...
# 3  **Writing Style and Format Analysis**\n\n**Sty...
# 4  Based on the structural and formal elements pr...
#
#                                             prompt_2  \
# 0  \nWrite an essay of about 600 words on the top...
# 1  \nWrite an essay of about 300 words on the top...
# 2  \nWrite an essay of about 300 words on the top...
# 3  \nWrite an essay of about 300 words on the top...
# 4  \nWrite an essay of about 400 words on the top...
#
#                                                 text          model
# 0  The 2013 film *12 Years a Slave*, directed by ...  deepseek-chat
# 1  The strategic simplification of marketing thro...  deepseek-chat
# 2  In *Kyllo v. United States*, 533 U.S. 27 (2001...  deepseek-chat
# 3  The Charles Schwab Corporation, a prominent fi...  deepseek-chat
# 4  My initial research into the role of a clinica...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df4, EXAMPLE_ID)
# Out:
# Prompt 1 =============================================================================================
#
# Identify the writing style and format of the text, excluding all semantic content and themes.
#
# Text:
# The 2013 film 12 Years a Slave proved that slavery is a worldwide issue. Indeed, the film made $150 million outside the United States and $57 million in the U.S., with a production budget of $20 million (Sharf, 2020). The movie was based on the memoir Twelve Years a Slave by Solomon Northup (Ntim, 2020). It tells the story of a free African American man who was kidnapped and sold into slavery. Solomon spent twelve years away from his family, being traded from one master to another. Fortunately, the protagonist met a person who helped him deliver a message to his family and friends, who came and rescued him. This movie accurately illustrates discriminatory relationships between white slaveholders and black slaves that stemmed from the dysfunctional system in the country and prejudices in people’s mindsets at that time.
#
# The two main ethnic groups presented in this film are White and African Americans, and the three social groups are affluent slaveholders, working for middle class, and enslaved people. The movie starts with the story of a free African American violinist Solomon Northup, living with his family in Saratoga, New York (McQueen, 2013). However, he was abducted by two white men, who tortured the man and sold him into slavery, changing his name to Plat. Before they met, Solomon and these two slave traders belonged to the same middle class. However, the fact that Northup was an African American made these individuals believe that they had the right to withdraw their freedom. The two masters that Solomon had were William Ford and Edwin Epps (McQueen, 2013). The former was kind and religious, while the latter was cruel and sadistic. Since the movie was based on a real story, it indicated that slaveholders had different characters, but all had the wrong perception of race.
#
# Although 12 Years a Slave is a film about slavery, the issues of collectivism and individualism are also raised. Specifically, the main character never identified himself as an enslaved man and continued claiming he was a free citizen (McQueen, 2013). However, his counterparts on the plant had a collective mindset, imprinted in them since childhood, that slavery is normal. These people helped each other because they belonged to the same group. Although Solomon tried to become a part of this community, his individual goal to return home was above the collective values.
#
# The movie also showed prejudice, generalizations, stereotyping, and discrimination against black people. For instance, when Ford brings Solomon and Elisa to his plantation, his wife expresses her sadness that Elisa got separated from her children. However, she also stated that “something to eat and some rest” could help that woman forget her children (McQueen, 2013, 32:47-32:51). This scene demonstrated the common prejudice about slaves that they were not capable of the same feelings as white people. An example of generalization and stereotyping was how Tibeats, a carpenter, became hostile to Solomon when he showed his intelligence and gave Ford advice. In fact, Tibeats believed that Plat would never be more competent than any white individual because Plat was a “nigger” (McQueen, 2013, 36:35-36:37). Notably, before Northup became enslaved, he never experienced discrimination, but when the main character was sold into slavery, discrimination was the only attitude that he could observe.
#
# In summary, 12 Years a Slave depicts the life of enslaved people and slave owners almost two centuries ago. The film narrates a free black man’s life from the moment when he enjoyed his family’s company in the state of New York to his abduction, enslavement, and eventual liberation. Overall, the movie raised such critical issues as discrimination, prejudice, stereotyping, and generalization that allowed slaveholders to maintain this societal structure for a long time.
#
# References
#
# McQueen, S. (2013). 12 years a slave [Film]. New Regency Productions.
#
# Ntim, Z. (2020). Steve McQueen says it took 11 years to create his new anthology “Small Axe” and reveals why producers almost pulled out of his Oscar-winning film “12 Years a Slave.” Insider.
#
# Sharf, Z. (2020). Steve McQueen recalls producers rejecting “12 Years a Slave” over false beliefs about black films. Indie Wire.
#
#
# ====================================================================================================
# The writing style is **academic** and **analytical**, employing a formal, objective tone with precise vocabulary. The format is that of a **structured academic essay**, specifically following a **five-paragraph expository structure** with an introduction, body paragraphs, and a conclusion, complete with a formal **reference list** in APA citation style.
# Prompt 2 =============================================================================================
#
# Write an essay of about 600 words on the topic '12 Years a Slave: An Analysis of the Film Essay'.
#
# You are given the following style-and-format description:
# 'The writing style is **academic** and **analytical**, employing a formal, objective tone with precise vocabulary. The format is that of a **structured academic essay**, specifically following a **five-paragraph expository structure** with an introduction, body paragraphs, and a conclusion, complete with a formal **reference list** in APA citation style.'
#
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
#
# ====================================================================================================
# 12 Years a Slave: An Analysis of the Film Essay
#
# The 2013 film *12 Years a Slave*, directed by Steve McQueen and based on Solomon Northup’s 1853 memoir, stands as a seminal work in the cinematic portrayal of American slavery, distinguished not merely by its historical fidelity but by its unflinching analytical focus on the systemic machinery of dehumanization. Moving beyond the conventions of the historical drama, McQueen employs a stark, aestheticized realism to dissect the ideological, economic, and psychological architecture of the “peculiar institution.” This essay argues that through its meticulous narrative structure, visceral visual language, and complex characterizations, the film functions as a profound analytical essay on film, systematically exposing slavery not as a historical aberration but as a logically coherent system built on the totalizing commodification of human beings. It achieves this by illustrating the corruption of law and morality, the internalization of oppression, and the fragile performativity of identity under a regime of absolute power.
#
# The film’s primary analytical thrust lies in its depiction of slavery as a normalized economic and legal system. McQueen deliberately avoids a simplistic morality tale of singular villainy, instead presenting a world where brutality is bureaucratized. The kidnapping of Solomon Northup, a free man, and his subsequent sale are transactions handled with cold efficiency, underscoring how the law was weaponized to sustain the slave economy. This systemic analysis is most potent in the character of Master Ford, portrayed as a “benevolent” slaveholder. Ford’s relative kindness is not presented as redemption but as a more insidious facet of the system; his failure to fundamentally challenge the institution, despite his personal conflict, demonstrates how even nominal morality is corrupted and rendered inert by economic and social complicity. The plantation is thus analyzed as a corporate entity, where human beings are assets, their value quantified and their spirits broken as a matter of business practice, rendering the violence not gratuitous but instrumental.
#
# Furthermore, McQueen’s directorial style constitutes a form of visual analysis, using prolonged, unblinking shots to force a contemplative engagement with suffering and resistance. The now-iconic scene of Solomon hanging from a tree for hours, his toes barely touching the earth as daily life continues indisturbedly around him, is a masterful cinematic thesis. The static frame analyzes the spectacle of punishment, the community’s enforced indifference, and the physiological reality of agony in a single, unbearable sequence. This aesthetic strategy refuses cathartic release or narrative convenience, instead insisting on the durational reality of bondage. Similarly, the sound design—the cacophony of insects, the crack of the whip, the sparse and haunting score—serves to analytically de-romanticize the Southern landscape, transforming it into a sensory prison that amplifies the psychological torment of the enslaved characters.
#
# The film’s analytical depth is equally rooted in its exploration of fractured identity and psychological survival. Chiwetel Ejiofor’s portrayal of Northup’s journey is a study in the performative masks required to endure. His character must suppress his literacy, intelligence, and history, consciously performing the role of “Platt,” the enslaved laborer. This internal duality analyzes the conflict between self-preservation and self-annihilation. The character of Patsey, however, provides the film’s most devastating analysis of the system’s gendered violence. Her exceptional labor value offers no protection, only making her a target for both the obsessive cruelty of Master Epps and the jealous rage of Mistress Epps. Her request for Solomon to end her life is a logical conclusion within the system’s brutal calculus, articulating a despair that transcends physical suffering and speaks to the utter eradication of personhood.
#
# In conclusion, *12 Years a Slave* transcends its role as a historical adaptation to operate as a rigorous cinematic essay. Through its structural precision, aesthetic discipline, and psychological acuity, it conducts a systematic analysis of American slavery as a totalizing system. It demonstrates how law, economy, and social custom were orchestrated to reduce people to property, how violence was a tool of management rather than mere savagery, and how identity itself became a site of brutal contestation. The film’s power and enduring significance derive not from a sentimental recounting of past horrors but from its analytical clarity, which implicates the viewer in a sober reflection on the mechanisms of dehumanization. By refusing to look away, McQueen’s film demands an intellectual and ethical engagement, securing its place as an essential work of historical and moral analysis.
#
# **Reference List**
#
# McQueen, S. (Director). (2013). *12 Years a Slave* [Film]. Fox Searchlight Pictures.
#
# Northup, S. (1853). *Twelve Years a Slave*. Derby & Miller.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_4.csv"

df4.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 5. Outline‑guided Text Generation
#
# Первый промпт:
# ```
# You are an academic writing instructor.
# Create a well-structured outline for an academic essay on the following topic: {}.
#
# Requirements:
#
# The outline must include the following sections:
# - Introduction
# - Main Body (2–4 thematic sections)
# - Counterarguments / Alternative Perspectives
# - Conclusion
#
# Each section should contain 2–3 concise bullet points describing the key ideas or arguments.
# The outline should reflect a clear thesis-driven structure.
# Use formal academic language.
#
# Do not write the essay itself
# ```
#
# Второй промпт:
# ```
# You are an academic essay writer.
# Write a coherent academic essay of about {} words on the topic '{}' strictly following the outline below.
#
# Outline:
# {}
#
# Requirements:
# - Follow the outline in the given order without adding or removing sections.
# - Develop each bullet point into a full, well-argued paragraph.
# - Maintain a formal academic tone and clear argumentative logic.
# - Use appropriate academic transitions and signposting.
# - Do not introduce new arguments or themes not present in the outline.
# - Avoid informal language, personal anecdotes, and unsupported claims.
# ```

# %%
def generate_with_plan(model_name, df, prompt_raw_1, prompt_raw_2, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
        text = df.loc[i, "text"]
    
        prompt_1_formatted = prompt_raw_1.format(title)

        try:
            response_1 = generate_response(prompt_1_formatted)
            response_1 = response_1.lstrip()
    
            prompt_2_formatted = prompt_raw_2.format(length, title, response_1)
            response_2 = generate_response(prompt_2_formatted)
        except:
            continue
            
        response = response_2.lstrip()
    
        rows.append({
            "title": title, 
            "prompt_1": prompt_1_formatted, 
            "response": response_1,
            "prompt_2": prompt_2_formatted, 
            "text": response, 
            "model": model_name
        })

        print_progress(start, i, n)
    
    return pd.DataFrame(rows)

# %%
prompt_1 = """
You are an academic writing instructor.
Create a well-structured outline for an academic essay on the following topic: {}.

Requirements:

The outline must include the following sections:
- Introduction
- Main Body (2–4 thematic sections)
- Counterarguments / Alternative Perspectives
- Conclusion

Each section should contain 2–3 concise bullet points describing the key ideas or arguments.
The outline should reflect a clear thesis-driven structure.
Use formal academic language.

Do not write the essay itself
"""

prompt_2 = """
You are an academic essay writer.
Write a coherent academic essay of about {} words on the topic '{}' strictly following the outline below.

Outline:
{}

Requirements:
- Follow the outline in the given order without adding or removing sections.
- Develop each bullet point into a full, well-argued paragraph.
- Maintain a formal academic tone and clear argumentative logic.
- Use appropriate academic transitions and signposting.
- Do not introduce new arguments or themes not present in the outline.
- Avoid informal language, personal anecdotes, and unsupported claims.
"""

# %%
df5 = generate_with_plan(MODEL, df, prompt_1, prompt_2, start=START, n=OUT_COUNT)
df5.head()
# Out:
# 0.0% done
# 1.0% done
# 2.0% done
# 3.0% done
# 4.0% done
# 5.0% done
# 6.0% done
# 7.0% done
# 8.0% done
# 9.0% done
# 10.0% done
# 11.0% done
# 12.0% done
# 13.0% done
# 14.0% done
# 15.0% done
# 16.0% done
# 17.0% done
# 18.0% done
# 19.0% done
# 20.0% done
# 21.0% done
# 22.0% done
# 23.0% done
# 24.0% done
# 25.0% done
# 26.0% done
# 27.0% done
# 28.0% done
# 29.0% done
# 30.0% done
# 31.0% done
# 32.0% done
# 33.0% done
# 34.0% done
# 35.0% done
# 36.0% done
# 37.0% done
# 38.0% done
# 39.0% done
# 40.0% done
# 41.0% done
# 42.0% done
# 43.0% done
# 44.0% done
# 45.0% done
# 46.0% done
# 47.0% done
# 48.0% done
# 49.0% done
# 50.0% done
# 51.0% done
# 52.0% done
# 53.0% done
# 54.0% done
# 55.0% done
# 56.0% done
# 57.0% done
# 58.0% done
# 59.0% done
# 60.0% done
# 61.0% done
# 62.0% done
# 63.0% done
# 64.0% done
# 65.0% done
# 66.0% done
# 67.0% done
# 68.0% done
# 69.0% done
# 70.0% done
# 71.0% done
# 72.0% done
# 73.0% done
# 74.0% done
# 75.0% done
# 76.0% done
# 77.0% done
# 78.0% done
# 79.0% done
# 80.0% done
# 81.0% done
# 82.0% done
# 83.0% done
# 84.0% done
# 85.0% done
# 86.0% done
# 87.0% done
# 88.0% done
# 89.0% done
# 90.0% done
# 91.0% done
# 92.0% done
# 93.0% done
# 94.0% done
# 95.0% done
# 96.0% done
# 97.0% done
# 98.0% done
# 99.0% done
#                                                title  \
# 0    12 Years a Slave: An Analysis of the Film Essay
# 1  20+ Social Media Post Ideas to Radically Simpl...
# 2  533 U.S. 27 (2001) Kyllo v. United States: The...
# 3            A Charles Schwab Corporation Case Essay
# 4  A Clinical Office Assistant’s Attire Research ...
#
#                                             prompt_1  \
# 0  \nYou are an academic writing instructor.\nCre...
# 1  \nYou are an academic writing instructor.\nCre...
# 2  \nYou are an academic writing instructor.\nCre...
# 3  \nYou are an academic writing instructor.\nCre...
# 4  \nYou are an academic writing instructor.\nCre...
#
#                                             response  \
# 0  **Essay Title:** *12 Years a Slave: Cinematic ...
# 1  **Academic Essay Outline**\n\n**Topic:** The E...
# 2  **Academic Essay Outline: *Kyllo v. United Sta...
# 3  **Outline for an Academic Essay: Innovation an...
# 4  **Title:** The Semiotics of Professional Attir...
#
#                                             prompt_2  \
# 0  \nYou are an academic essay writer.\nWrite a c...
# 1  \nYou are an academic essay writer.\nWrite a c...
# 2  \nYou are an academic essay writer.\nWrite a c...
# 3  \nYou are an academic essay writer.\nWrite a c...
# 4  \nYou are an academic essay writer.\nWrite a c...
#
#                                                 text          model
# 0  **12 Years a Slave: Cinematic Testimony and th...  deepseek-chat
# 1  **The Efficacy of Curated Social Media Content...  deepseek-chat
# 2  **Academic Essay: *Kyllo v. United States* and...  deepseek-chat
# 3  ### **A Charles Schwab Corporation Case Essay*...  deepseek-chat
# 4  **The Semiotics of Professional Attire: A Crit...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df5, EXAMPLE_ID)
# Out:
# Prompt 1 =============================================================================================
#
# You are an academic writing instructor.
# Create a well-structured outline for an academic essay on the following topic: 12 Years a Slave: An Analysis of the Film Essay.
#
# Requirements:
#
# The outline must include the following sections:
# - Introduction
# - Main Body (2–4 thematic sections)
# - Counterarguments / Alternative Perspectives
# - Conclusion
#
# Each section should contain 2–3 concise bullet points describing the key ideas or arguments.
# The outline should reflect a clear thesis-driven structure.
# Use formal academic language.
#
# Do not write the essay itself
#
# ====================================================================================================
# **Essay Title:** *12 Years a Slave: Cinematic Testimony and the Anatomy of Systemic Oppression*
#
# **Thesis Statement:** While *12 Years a Slave* serves as a visceral historical testimony to the brutality of chattel slavery, its profound significance lies in its systematic cinematic deconstruction of the institution’s ideological machinery—specifically, its exploitation of legal and economic structures, its psychological weaponization of time and identity, and its complicit normalization of violence—thereby challenging contemporary audiences to confront the enduring legacies of systemic dehumanization.
#
# ---
#
# ### **I. Introduction**
# *   **Opening Context:** Establish the film’s unique position as a major studio adaptation of a primary historical document (Solomon Northup’s 1853 memoir) and its critical reception as an unflinching portrayal of American slavery.
# *   **Thesis Presentation:** Present the central argument that the film transcends mere historical dramatization to analytically expose the interconnected systems—legal, economic, psychological, and social—that sustained slavery.
# *   **Roadmap:** Briefly outline the main thematic sections that will structure the analysis: the perversion of legal and economic frameworks, the assault on temporal and personal identity, and the spectacle of normalized violence.
#
# ### **II. Main Body: Thematic Section A – The Perversion of Law and Economy**
# *   **The Legal Fiction of Property:** Analyze how the film depicts the law not as a protector of rights but as a tool of oppression, exemplified by Solomon’s kidnapping and the powerless legal status of enslaved people, transforming human beings into legally defenseless commodities.
# *   **The Economic Architecture of Dehumanization:** Examine slavery as a calculated capitalist enterprise, focusing on scenes of valuation, sale, and plantation management (e.g., Epps’s cotton quotas), which illustrate how moral considerations are wholly subordinated to financial gain and labor extraction.
#
# ### **III. Main Body: Thematic Section B – The Assault on Time and Identity**
# *   **Suspended Temporality and Erased Narrative:** Argue that the film’s structure and mise-en-scène convey the psychological torment of enslaved time—a state of perpetual, hopeless present—contrasted sharply with Solomon’s memories of freedom, highlighting the systematic erasure of personal history and future aspiration.
# *   **The Coercive Reconstruction of Self:** Discuss the enforced renaming (“Platt”), the prohibition of literacy, and the demand for absolute performative submission as mechanisms to strip away autonomous identity and forcibly reconstruct the self solely in relation to the master’s will.
#
# ### **IV. Main Body: Thematic Section C – The Spectacle and Normalization of Violence**
# *   **Violence as Pedagogy and Social Control:** Analyze key scenes of punishment (e.g., the whipping of Patsey) not merely as displays of brutality but as didactic spectacles designed to terrorize the collective, reinforce hierarchy, and crush resistance, thereby maintaining the social order.
# *   **The Complicity of Bystanders and Ritual:** Explore how the film implicates a broader community in the system, from the forced participation of other enslaved people in punishments to the polite society that exists alongside extreme cruelty, demonstrating how violence becomes ritualized and normalized within the slaveholding culture.
#
# ### **V. Counterarguments / Alternative Perspectives**
# *   **Potential Critique of Exploitative Trauma:** Acknowledge and address the perspective that the film’s graphic focus on Black suffering risks aestheticizing trauma for a predominantly white audience, potentially reducing its narrative to a spectacle of victimhood.
# *   **Limitations of the “Exceptional” Narrative:** Consider the argument that centering on an educated, free-born Northern protagonist may inadvertently frame slavery’s ultimate horror as the enslavement of someone *like* the viewer, potentially marginalizing the experiences of those born into generational bondage.
# *   **The Film’s Redemptive Arc vs. Historical Reality:** Engage with the view that the narrative’s focus on Solomon’s eventual rescue, while historically accurate for him, provides a cathartic resolution that might soften the film’s overall impact regarding the irredeemable horror and permanence of slavery for millions.
#
# ### **VI. Conclusion**
# *   **Synthesis of Arguments:** Recapitulate how the film’s analytical power is cumulative, built through its layered examination of legal, economic, psychological, and violent systems working in concert to enact dehumanization.
# *   **Restatement of Thesis in New Terms:** Reaffirm that *12 Years a Slave* functions as both a memorial and a critical apparatus, using the medium of cinema to dissect the operational logic of slavery rather than merely catalog its atrocities.
# *   **Broader Implications and Contemporary Resonance:** Conclude by reflecting on the film’s enduring relevance, suggesting that its true imperative is to prompt critical reflection on modern systems of exploitation, racial injustice, and the mechanisms of dehumanization that persist in new forms.
# Prompt 2 =============================================================================================
#
# You are an academic essay writer.
# Write a coherent academic essay of about 600 words on the topic '12 Years a Slave: An Analysis of the Film Essay' strictly following the outline below.
#
# Outline:
# **Essay Title:** *12 Years a Slave: Cinematic Testimony and the Anatomy of Systemic Oppression*
#
# **Thesis Statement:** While *12 Years a Slave* serves as a visceral historical testimony to the brutality of chattel slavery, its profound significance lies in its systematic cinematic deconstruction of the institution’s ideological machinery—specifically, its exploitation of legal and economic structures, its psychological weaponization of time and identity, and its complicit normalization of violence—thereby challenging contemporary audiences to confront the enduring legacies of systemic dehumanization.
#
# ---
#
# ### **I. Introduction**
# *   **Opening Context:** Establish the film’s unique position as a major studio adaptation of a primary historical document (Solomon Northup’s 1853 memoir) and its critical reception as an unflinching portrayal of American slavery.
# *   **Thesis Presentation:** Present the central argument that the film transcends mere historical dramatization to analytically expose the interconnected systems—legal, economic, psychological, and social—that sustained slavery.
# *   **Roadmap:** Briefly outline the main thematic sections that will structure the analysis: the perversion of legal and economic frameworks, the assault on temporal and personal identity, and the spectacle of normalized violence.
#
# ### **II. Main Body: Thematic Section A – The Perversion of Law and Economy**
# *   **The Legal Fiction of Property:** Analyze how the film depicts the law not as a protector of rights but as a tool of oppression, exemplified by Solomon’s kidnapping and the powerless legal status of enslaved people, transforming human beings into legally defenseless commodities.
# *   **The Economic Architecture of Dehumanization:** Examine slavery as a calculated capitalist enterprise, focusing on scenes of valuation, sale, and plantation management (e.g., Epps’s cotton quotas), which illustrate how moral considerations are wholly subordinated to financial gain and labor extraction.
#
# ### **III. Main Body: Thematic Section B – The Assault on Time and Identity**
# *   **Suspended Temporality and Erased Narrative:** Argue that the film’s structure and mise-en-scène convey the psychological torment of enslaved time—a state of perpetual, hopeless present—contrasted sharply with Solomon’s memories of freedom, highlighting the systematic erasure of personal history and future aspiration.
# *   **The Coercive Reconstruction of Self:** Discuss the enforced renaming (“Platt”), the prohibition of literacy, and the demand for absolute performative submission as mechanisms to strip away autonomous identity and forcibly reconstruct the self solely in relation to the master’s will.
#
# ### **IV. Main Body: Thematic Section C – The Spectacle and Normalization of Violence**
# *   **Violence as Pedagogy and Social Control:** Analyze key scenes of punishment (e.g., the whipping of Patsey) not merely as displays of brutality but as didactic spectacles designed to terrorize the collective, reinforce hierarchy, and crush resistance, thereby maintaining the social order.
# *   **The Complicity of Bystanders and Ritual:** Explore how the film implicates a broader community in the system, from the forced participation of other enslaved people in punishments to the polite society that exists alongside extreme cruelty, demonstrating how violence becomes ritualized and normalized within the slaveholding culture.
#
# ### **V. Counterarguments / Alternative Perspectives**
# *   **Potential Critique of Exploitative Trauma:** Acknowledge and address the perspective that the film’s graphic focus on Black suffering risks aestheticizing trauma for a predominantly white audience, potentially reducing its narrative to a spectacle of victimhood.
# *   **Limitations of the “Exceptional” Narrative:** Consider the argument that centering on an educated, free-born Northern protagonist may inadvertently frame slavery’s ultimate horror as the enslavement of someone *like* the viewer, potentially marginalizing the experiences of those born into generational bondage.
# *   **The Film’s Redemptive Arc vs. Historical Reality:** Engage with the view that the narrative’s focus on Solomon’s eventual rescue, while historically accurate for him, provides a cathartic resolution that might soften the film’s overall impact regarding the irredeemable horror and permanence of slavery for millions.
#
# ### **VI. Conclusion**
# *   **Synthesis of Arguments:** Recapitulate how the film’s analytical power is cumulative, built through its layered examination of legal, economic, psychological, and violent systems working in concert to enact dehumanization.
# *   **Restatement of Thesis in New Terms:** Reaffirm that *12 Years a Slave* functions as both a memorial and a critical apparatus, using the medium of cinema to dissect the operational logic of slavery rather than merely catalog its atrocities.
# *   **Broader Implications and Contemporary Resonance:** Conclude by reflecting on the film’s enduring relevance, suggesting that its true imperative is to prompt critical reflection on modern systems of exploitation, racial injustice, and the mechanisms of dehumanization that persist in new forms.
#
# Requirements:
# - Follow the outline in the given order without adding or removing sections.
# - Develop each bullet point into a full, well-argued paragraph.
# - Maintain a formal academic tone and clear argumentative logic.
# - Use appropriate academic transitions and signposting.
# - Do not introduce new arguments or themes not present in the outline.
# - Avoid informal language, personal anecdotes, and unsupported claims.
#
# ====================================================================================================
# 12 Years a Slave: An Analysis of the Film Essay
#
# **12 Years a Slave: Cinematic Testimony and the Anatomy of Systemic Oppression**
#
# Steve McQueen’s *12 Years a Slave* occupies a singular position in contemporary cinema as a major studio adaptation of a primary historical document: Solomon Northup’s harrowing 1853 memoir. Lauded for its unflinching visual grammar, the film transcends its role as a visceral period piece to offer a searing historical testimony. However, its profound significance lies not merely in its depiction of brutality but in its systematic cinematic deconstruction of the ideological machinery of chattel slavery. While it viscerally documents atrocity, the film’s analytical power is derived from its meticulous exposure of the interconnected systems—legal, economic, psychological, and social—that sustained the institution. This essay will argue that *12 Years a Slave* functions as a critical apparatus, dissecting the perversion of legal and economic frameworks, the assault on temporal and personal identity, and the spectacle of normalized violence, thereby challenging audiences to confront the enduring legacies of systemic dehumanization.
#
# The film’s first major thematic intervention is its exposition of how slavery perverted legal and economic structures to codify dehumanization. The law is consistently depicted not as a bastion of justice but as a tool of oppression. Solomon Northup’s kidnapping in Washington D.C., a district governed by federal statute, and his subsequent imprisonment in a slave pen visually underscore the legal fiction that transformed a free man into defenseless property. The courtroom, traditionally a space for truth and redress, is entirely absent from Solomon’s ordeal; his appeals to white authority figures are met with violence or dismissal, illustrating that his personhood holds no legal standing. Concurrently, the film frames slavery as a ruthlessly efficient capitalist enterprise. Scenes of enslaved people being inspected, priced, and sold at auction reduce human beings to quantifiable assets. This economic architecture is further detailed on Edwin Epps’s plantation, where cotton-picking quotas and meticulous ledgers demonstrate a system where moral conscience is wholly subordinated to financial gain and labor extraction, revealing an institution sustained by calculated economic interest as much as by racial ideology.
#
# Beyond the physical bondage, *12 Years a Slave* masterfully conveys the psychological torment of slavery through its assault on time and identity. The film’s narrative structure and mise-en-scène evoke a state of suspended temporality—a perpetual, hopeless present. Long, static takes of grueling labor under a relentless sun communicate the crushing weight of enslaved time, where the future is an unimaginable abstraction. This is sharply contrasted with Solomon’s fleeting, almost ethereal memories of his family and life in Saratoga, highlighting the systematic erasure of personal history and future aspiration. Furthermore, the institution actively seeks to coercively reconstruct the self. Solomon is forcibly renamed “Platt,” his literacy—a tangible link to his autonomous identity—becomes a dangerous secret to be concealed, and his survival demands a performative submission that internally fractures his sense of self. This psychological warfare aims to annihilate the individual’s interior world, reconstructing identity solely in relation to the master’s capricious will.
#
# The system’s ultimate mechanism of control is the spectacle and normalization of violence, which the film presents not as aberrant cruelty but as essential social pedagogy. Key scenes of punishment, most devastatingly the whipping of Patsey, are framed as didactic spectacles. The violence is protracted, methodical, and often witnessed by the enslaved community. This public performance serves to terrorize the collective, reinforce the absolute hierarchy of power, and crush any nascent resistance, thereby maintaining the plantation’s social order. Moreover, McQueen implicates the broader community in this ritualized brutality. Other enslaved individuals are compelled to participate, either by holding down Patsey or by continuing their labor amidst her screams, illustrating how the system forces complicity. The juxtaposition of extreme violence with scenes of polite Southern society—lavish dinners and genteel conversation—demonstrates how such brutality became normalized, an accepted and invisible foundation for the slaveholding culture’s everyday life.
#
# A comprehensive analysis must engage with critiques of the film’s approach. Some scholars argue that its graphic, unrelenting focus on Black suffering risks aestheticizing trauma for a predominantly white viewership, potentially reducing the narrative to a spectacle of victimhood. Others note that centering on an educated, free-born Northern protagonist like Solomon may inadvertently frame slavery’s ultimate horror as the enslavement of someone perceived as “exceptional,” potentially marginalizing the experiences of those born into generational bondage. Furthermore, while historically accurate, the narrative’s redemptive arc—Solomon’s eventual rescue—provides a cathartic resolution that might soften the film’s impact regarding the irredeemable horror and permanence of slavery for millions who found no such escape.
#
# In synthesis, *12 Years a Slave* derives its formidable power from the cumulative effect of its layered systemic analysis. It functions as both a memorial and a critical apparatus, using the unique capacities of cinema to dissect the operational logic of slavery rather than merely catalog its atrocities. By restating the thesis in new terms, the film’s true imperative extends beyond historical reckoning to prompt critical reflection on contemporary resonance. It challenges audiences to recognize that the dehumanization it so meticulously anatomizes was not a historical anomaly but the product of interlocking systems—legal, economic, and social—whose logic and legacy demand vigilant scrutiny in modern contexts of exploitation, racial injustice, and carceral violence. In holding a mirror to the anatomy of oppression, McQueen’s film issues a profound and enduring call to moral and political consciousness.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_5.csv"

df5.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)
