# %% [markdown]
# # Генерация датасетов моделью DeepSeek Chat
#
# DeepSeek-V3.2

# %%
EXAMPLE_ID = 0
MODEL = 'deepseek-chat'
START = 2000
OUT_COUNT = 500
OUT_FILE_PREFIX = 'deepseek_essays'
PAUSE_SECONDS = 1

# %% [markdown]
# ### Исходный датасет, написанный человеком

# %%
import pandas as pd

df = pd.read_csv("../datasets/human_essays.csv", encoding="utf-8")
df.head(10)
# Out:
#                                                title  \
# 0    12 Years a Slave: An Analysis of the Film Essay
# 1  20+ Social Media Post Ideas to Radically Simpl...
# 2  533 U.S. 27 (2001) Kyllo v. United States: The...
# 3            A Charles Schwab Corporation Case Essay
# 4  A Clinical Office Assistant’s Attire Research ...
# 5  A Comic Science Fiction Film “Back to the Futu...
# 6   A Community Yard Sale as a Memorable Event Essay
# 7  A Complex in the “Every Secret Thing” Film by ...
# 8  A Customer Told to Wear a Mask Threw Snow at a...
# 9  A Disconnect Between Public Transportation and...
#
#                                                 text
# 0  The 2013 film 12 Years a Slave proved that sla...
# 1  Social Media Examiner’s (2021) video on social...
# 2  Table of Contents\n 1. Facts\n 2. Issue\n 3. H...
# 3  Charles Schwab is a for-profit Corporation who...
# 4  The work of a clinical or medical office worke...
# 5  Table of Contents\n 1. Introduction\n 2. Movie...
# 6  Autumn is not generally viewed as an appropria...
# 7  Carl Jung identifies the mother complex with a...
# 8  The article describes a recent Chicago hot dog...
# 9  One realistic way to commute is using private ...

# %% [markdown]
# #### Пример:

# %%
print(f"{df.iloc[EXAMPLE_ID,0]}\n\n{df.iloc[EXAMPLE_ID,1]}")
# Out:
# 12 Years a Slave: An Analysis of the Film Essay
#
# The 2013 film 12 Years a Slave proved that slavery is a worldwide issue. Indeed, the film made $150 million outside the United States and $57 million in the U.S., with a production budget of $20 million (Sharf, 2020). The movie was based on the memoir Twelve Years a Slave by Solomon Northup (Ntim, 2020). It tells the story of a free African American man who was kidnapped and sold into slavery. Solomon spent twelve years away from his family, being traded from one master to another. Fortunately, the protagonist met a person who helped him deliver a message to his family and friends, who came and rescued him. This movie accurately illustrates discriminatory relationships between white slaveholders and black slaves that stemmed from the dysfunctional system in the country and prejudices in people’s mindsets at that time.
#
# The two main ethnic groups presented in this film are White and African Americans, and the three social groups are affluent slaveholders, working for middle class, and enslaved people. The movie starts with the story of a free African American violinist Solomon Northup, living with his family in Saratoga, New York (McQueen, 2013). However, he was abducted by two white men, who tortured the man and sold him into slavery, changing his name to Plat. Before they met, Solomon and these two slave traders belonged to the same middle class. However, the fact that Northup was an African American made these individuals believe that they had the right to withdraw their freedom. The two masters that Solomon had were William Ford and Edwin Epps (McQueen, 2013). The former was kind and religious, while the latter was cruel and sadistic. Since the movie was based on a real story, it indicated that slaveholders had different characters, but all had the wrong perception of race.
#
# Although 12 Years a Slave is a film about slavery, the issues of collectivism and individualism are also raised. Specifically, the main character never identified himself as an enslaved man and continued claiming he was a free citizen (McQueen, 2013). However, his counterparts on the plant had a collective mindset, imprinted in them since childhood, that slavery is normal. These people helped each other because they belonged to the same group. Although Solomon tried to become a part of this community, his individual goal to return home was above the collective values.
#
# The movie also showed prejudice, generalizations, stereotyping, and discrimination against black people. For instance, when Ford brings Solomon and Elisa to his plantation, his wife expresses her sadness that Elisa got separated from her children. However, she also stated that “something to eat and some rest” could help that woman forget her children (McQueen, 2013, 32:47-32:51). This scene demonstrated the common prejudice about slaves that they were not capable of the same feelings as white people. An example of generalization and stereotyping was how Tibeats, a carpenter, became hostile to Solomon when he showed his intelligence and gave Ford advice. In fact, Tibeats believed that Plat would never be more competent than any white individual because Plat was a “nigger” (McQueen, 2013, 36:35-36:37). Notably, before Northup became enslaved, he never experienced discrimination, but when the main character was sold into slavery, discrimination was the only attitude that he could observe.
#
# In summary, 12 Years a Slave depicts the life of enslaved people and slave owners almost two centuries ago. The film narrates a free black man’s life from the moment when he enjoyed his family’s company in the state of New York to his abduction, enslavement, and eventual liberation. Overall, the movie raised such critical issues as discrimination, prejudice, stereotyping, and generalization that allowed slaveholders to maintain this societal structure for a long time.
#
# References
#
# McQueen, S. (2013). 12 years a slave [Film]. New Regency Productions.
#
# Ntim, Z. (2020). Steve McQueen says it took 11 years to create his new anthology “Small Axe” and reveals why producers almost pulled out of his Oscar-winning film “12 Years a Slave.” Insider.
#
# Sharf, Z. (2020). Steve McQueen recalls producers rejecting “12 Years a Slave” over false beliefs about black films. Indie Wire.

# %% [markdown]
# ### Утилиты

# %%
import math
import re


def round_word_count(c):
    return math.floor(c / 100) * 100

def word_count(text):
    words = re.findall(r'\b\w+\b', text)
    return round_word_count(len(words))

def print_example(data, example_id):
    if 'prompt' in data.iloc[example_id]:
        print(f"Prompt {'=' * 93}\n{data.iloc[example_id]['prompt']}")
        print(f"{'=' * 100}")
        print(f"{data.iloc[example_id]['title']}\n\n{data.iloc[example_id]['text']}")
        print(f"{'=' * 100}")
    if 'prompt_2' in data.iloc[example_id]:
        print(f"Prompt 1 {'=' * 93}\n{data.iloc[example_id]['prompt_1']}")
        print(f"{'=' * 100}")
        print(f"{data.iloc[example_id]['response']}")
        print(f"Prompt 2 {'=' * 93}\n{data.iloc[example_id]['prompt_2']}")
        print(f"{'=' * 100}")
        print(f"{data.iloc[example_id]['title']}\n\n{data.iloc[example_id]['text']}")
        print(f"{'=' * 100}")

def print_progress(start, i, n):
    if (i - start) % (n / 100) == 0:
        print(f"{100 * (i - start) / n}% done")

# %%
from dotenv import load_dotenv
import os
from openai import OpenAI


load_dotenv()

client = OpenAI(api_key=os.getenv("DEEPSEEK_API_KEY"), base_url="https://api.deepseek.com")

# %%
import time


def generate_response(prompt):
    response = client.chat.completions.create(
        model=MODEL,
        messages=[
            {
                "role": "system",
                "content": "You are an expert academic essay writer. You produce well-structured, logical, and substantive essays with clear argumentation, proper citations, and academic rigor."
            },
            {
                "role": "user",
                "content": prompt
            }
        ],
        stream=False
    )

    time.sleep(PAUSE_SECONDS)
    
    return response.choices[0].message.content

# %% [markdown]
# ### Вариант 1. Prompt-based generation
#
# ```
# Write an essay of about {} words on the topic '{}'.
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
# ```

# %%
def generate(model_name, df, prompt_raw, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
    
        prompt_formatted = prompt_raw.format(length, title)

        try:
            response = generate_response(prompt_formatted)
        except:
            continue
            
        response = response.lstrip()
    
        rows.append({"title": title, "prompt": prompt_formatted, "text": response, "model": model_name})

        print_progress(start, i, n)
    
    return pd.DataFrame(rows)

# %%
prompt = """
Write an essay of about {} words on the topic '{}'.
Start directly with the first sentence of the essay. Absolutely no title or heading of any kind. 
Output only the essay text. 
"""

df1 = generate(MODEL, df, prompt, start=START, n=OUT_COUNT)
df1.head()
# Out:
# 0.0% done
# 1.0% done
# 2.0% done
# 3.0% done
# 4.0% done
# 5.0% done
# 6.0% done
# 7.0% done
# 8.0% done
# 9.0% done
# 10.0% done
# 11.0% done
# 12.0% done
# 13.0% done
# 14.0% done
# 15.0% done
# 16.0% done
# 17.0% done
# 18.0% done
# 19.0% done
# 20.0% done
# 21.0% done
# 22.0% done
# 23.0% done
# 24.0% done
# 25.0% done
# 26.0% done
# 27.0% done
# 28.0% done
# 29.0% done
# 30.0% done
# 31.0% done
# 32.0% done
# 33.0% done
# 34.0% done
# 35.0% done
# 36.0% done
# 37.0% done
# 38.0% done
# 39.0% done
# 40.0% done
# 41.0% done
# 42.0% done
# 43.0% done
# 44.0% done
# 45.0% done
# 46.0% done
# 47.0% done
# 48.0% done
# 49.0% done
# 50.0% done
# 51.0% done
# 52.0% done
# 53.0% done
# 54.0% done
# 55.0% done
# 56.0% done
# 57.0% done
# 58.0% done
# 59.0% done
# 60.0% done
# 61.0% done
# 62.0% done
# 63.0% done
# 64.0% done
# 65.0% done
# 66.0% done
# 67.0% done
# 68.0% done
# 69.0% done
# 70.0% done
# 71.0% done
# 72.0% done
# 73.0% done
# 74.0% done
# 75.0% done
# 76.0% done
# 77.0% done
# 78.0% done
# 79.0% done
# 80.0% done
# 81.0% done
# 82.0% done
# 83.0% done
# 84.0% done
# 85.0% done
# 86.0% done
# 87.0% done
# 88.0% done
# 89.0% done
# 90.0% done
# 91.0% done
# 92.0% done
# 93.0% done
# 94.0% done
# 95.0% done
# 96.0% done
# 97.0% done
# 98.0% done
# 99.0% done
#                                                title  \
# 0  A Deontological Ethical Framework Problem Solv...
# 1  A Fire Research Program in the State of Califo...
# 2    A Gang Culture Among the Latinos Research Paper
# 3  A Qualitative Research Method and Its Use in a...
# 4  “A River Runs Through It”: The Novella vs. The...
#
#                                               prompt  \
# 0  \nWrite an essay of about 200 words on the top...
# 1  \nWrite an essay of about 1000 words on the to...
# 2  \nWrite an essay of about 2900 words on the to...
# 3  \nWrite an essay of about 1200 words on the to...
# 4  \nWrite an essay of about 900 words on the top...
#
#                                                 text          model
# 0  A deontological ethical framework provides a r...  deepseek-chat
# 1  The catastrophic wildfires that have become a ...  deepseek-chat
# 2  The phenomenon of gang culture within Latino c...  deepseek-chat
# 3  The landscape of academic inquiry is richly te...  deepseek-chat
# 4  The enduring power of Norman Maclean’s 1976 no...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df1, EXAMPLE_ID)
# Out:
# Prompt =============================================================================================
#
# Write an essay of about 200 words on the topic 'A Deontological Ethical Framework Problem Solving Research Paper'.
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
#
# ====================================================================================================
# A Deontological Ethical Framework Problem Solving Research Paper
#
# A deontological ethical framework provides a robust and principled approach to problem-solving in research, prioritizing duty and adherence to moral rules over the consequences of an action. This paper argues that deontological principles, such as respect for persons, informed consent, and the categorical imperative, offer essential guardrails for ethical research conduct. For instance, when designing a study involving human participants, a deontologist would insist on obtaining explicit, voluntary consent as an inviolable duty, regardless of whether bypassing it might yield more expedient or beneficial results for society. This stands in contrast to utilitarian calculations, which could justify minor harms for a greater good. The deontological focus on intention and universalizable maxims ensures that research procedures themselves are inherently just, protecting the dignity and autonomy of all involved. Consequently, applying this framework compels researchers to scrutinize their methodologies for inherent rights violations, fostering a research environment built on trust and moral integrity, which is ultimately foundational for sustainable scientific progress.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_1.csv"

df1.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 2. Prompt-based Style Transfer
#
# ```
# Write an essay of about {} words on the topic '{}', following the stylistic and structural conventions of IvyPanda essays.
#
# STYLE REQUIREMENTS (IvyPanda-like):
# 1. The tone must be academic, clear, neutral, and objective.
# 2. The essay should include background context, a clear analytical structure, and well-developed paragraphs.
# 3. Arguments must be supported with reasoning, concise explanations, and relevant examples.
# 4. The writing must be coherent, logically progressive, and easy to read.
# 5. Avoid emotional language or overly dramatic phrasing.
#
# STRUCTURE REQUIREMENTS:
# 1. Divide the essay into several sections, each starting with a plain-text subheading.
# 2. Subheadings must contain only letters and spaces — no punctuation, no symbols, and absolutely no Markdown formatting.
#    - This means: no asterisks, no bold, no italics, no underscores, no brackets.
#    - Subheadings must appear as plain text lines, e.g. Background Context
# 3. Each subheading must be on its own line with exactly one blank line before and after it.
# 4. No overall essay title — begin directly with the first subheading.
# 5. Output must be plain text only (no Markdown, no asterisks, no bold, no italics, no hashtags, no special formatting).
#
# OPTIONAL ELEMENTS:
# You may include a plain-text references section at the end if appropriate to the topic, but this is optional.
#
# Begin with the first subheading, then continue with the first paragraph.
# Output only the essay text.
# ```

# %%
def generate(model_name, df, prompt_raw, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
    
        prompt_formatted = prompt_raw.format(length, title)
    
        try:
            response = generate_response(prompt_formatted)
        except:
            continue
            
        response = response.lstrip()
    
        rows.append({"title": title, "prompt": prompt_formatted, "text": response, "model": model_name})

        print_progress(start, i, n)
    
    return pd.DataFrame(rows)

# %%
prompt = """
Write an essay of about {} words on the topic '{}', following the stylistic and structural conventions of IvyPanda essays.

STYLE REQUIREMENTS (IvyPanda-like):
1. The tone must be academic, clear, neutral, and objective.
2. The essay should include background context, a clear analytical structure, and well-developed paragraphs.
3. Arguments must be supported with reasoning, concise explanations, and relevant examples.
4. The writing must be coherent, logically progressive, and easy to read.
5. Avoid emotional language or overly dramatic phrasing.

STRUCTURE REQUIREMENTS:
1. Divide the essay into several sections, each starting with a plain-text subheading.
2. Subheadings must contain only letters and spaces — no punctuation, no symbols, and absolutely no Markdown formatting.
   - This means: no asterisks, no bold, no italics, no underscores, no brackets.
   - Subheadings must appear as plain text lines, e.g. Background Context
3. Each subheading must be on its own line with exactly one blank line before and after it.
4. No overall essay title — begin directly with the first subheading.
5. Output must be plain text only (no Markdown, no asterisks, no bold, no italics, no hashtags, no special formatting).

OPTIONAL ELEMENTS:
You may include a plain-text references section at the end if appropriate to the topic, but this is optional.

Begin with the first subheading, then continue with the first paragraph.
Output only the essay text.
"""

df2 = generate(MODEL, df, prompt, start=START, n=OUT_COUNT)
df2.head()
# Out:
# 0.0% done
# 1.0% done
# 2.0% done
# 3.0% done
# 4.0% done
# 5.0% done
# 6.0% done
# 7.0% done
# 8.0% done
# 9.0% done
# 10.0% done
# 11.0% done
# 12.0% done
# 13.0% done
# 14.0% done
# 15.0% done
# 16.0% done
# 17.0% done
# 18.0% done
# 19.0% done
# 20.0% done
# 21.0% done
# 22.0% done
# 23.0% done
# 24.0% done
# 25.0% done
# 26.0% done
# 27.0% done
# 28.0% done
# 29.0% done
# 30.0% done
# 31.0% done
# 32.0% done
# 33.0% done
# 34.0% done
# 35.0% done
# 36.0% done
# 37.0% done
# 38.0% done
# 39.0% done
# 40.0% done
# 41.0% done
# 42.0% done
# 43.0% done
# 44.0% done
# 45.0% done
# 46.0% done
# 47.0% done
# 48.0% done
# 49.0% done
# 50.0% done
# 51.0% done
# 52.0% done
# 53.0% done
# 54.0% done
# 55.0% done
# 56.0% done
# 57.0% done
# 58.0% done
# 59.0% done
# 60.0% done
# 61.0% done
# 62.0% done
# 63.0% done
# 64.0% done
# 65.0% done
# 66.0% done
# 67.0% done
# 68.0% done
# 69.0% done
# 70.0% done
# 71.0% done
# 72.0% done
# 73.0% done
# 74.0% done
# 75.0% done
# 76.0% done
# 77.0% done
# 78.0% done
# 79.0% done
# 80.0% done
# 81.0% done
# 82.0% done
# 83.0% done
# 84.0% done
# 85.0% done
# 86.0% done
# 87.0% done
# 88.0% done
# 89.0% done
# 90.0% done
# 91.0% done
# 92.0% done
# 93.0% done
# 94.0% done
# 95.0% done
# 96.0% done
# 97.0% done
# 98.0% done
# 99.0% done
#                                                title  \
# 0  A Deontological Ethical Framework Problem Solv...
# 1  A Fire Research Program in the State of Califo...
# 2    A Gang Culture Among the Latinos Research Paper
# 3  A Qualitative Research Method and Its Use in a...
# 4  “A River Runs Through It”: The Novella vs. The...
#
#                                               prompt  \
# 0  \nWrite an essay of about 200 words on the top...
# 1  \nWrite an essay of about 1000 words on the to...
# 2  \nWrite an essay of about 2900 words on the to...
# 3  \nWrite an essay of about 1200 words on the to...
# 4  \nWrite an essay of about 900 words on the top...
#
#                                                 text          model
# 0  Background Context\n\nA deontological ethical ...  deepseek-chat
# 1  Background Context\n\nThe State of California ...  deepseek-chat
# 2  Background Context\n\nThe phenomenon of gang c...  deepseek-chat
# 3  Background Context\n\nQualitative research met...  deepseek-chat
# 4  Background Context\n\nNorman Maclean’s 1976 no...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df2, EXAMPLE_ID)
# Out:
# Prompt =============================================================================================
#
# Write an essay of about 200 words on the topic 'A Deontological Ethical Framework Problem Solving Research Paper', following the stylistic and structural conventions of IvyPanda essays.
#
# STYLE REQUIREMENTS (IvyPanda-like):
# 1. The tone must be academic, clear, neutral, and objective.
# 2. The essay should include background context, a clear analytical structure, and well-developed paragraphs.
# 3. Arguments must be supported with reasoning, concise explanations, and relevant examples.
# 4. The writing must be coherent, logically progressive, and easy to read.
# 5. Avoid emotional language or overly dramatic phrasing.
#
# STRUCTURE REQUIREMENTS:
# 1. Divide the essay into several sections, each starting with a plain-text subheading.
# 2. Subheadings must contain only letters and spaces — no punctuation, no symbols, and absolutely no Markdown formatting.
#    - This means: no asterisks, no bold, no italics, no underscores, no brackets.
#    - Subheadings must appear as plain text lines, e.g. Background Context
# 3. Each subheading must be on its own line with exactly one blank line before and after it.
# 4. No overall essay title — begin directly with the first subheading.
# 5. Output must be plain text only (no Markdown, no asterisks, no bold, no italics, no hashtags, no special formatting).
#
# OPTIONAL ELEMENTS:
# You may include a plain-text references section at the end if appropriate to the topic, but this is optional.
#
# Begin with the first subheading, then continue with the first paragraph.
# Output only the essay text.
#
# ====================================================================================================
# A Deontological Ethical Framework Problem Solving Research Paper
#
# Background Context
#
# A deontological ethical framework, derived from the philosophy of Immanuel Kant, posits that the morality of an action is inherent to the action itself, judged by its adherence to a set of rules or duties, rather than by its consequences. This stands in contrast to consequentialist theories like utilitarianism. In problem-solving research, applying this framework shifts the analytical focus from outcomes to the intrinsic rightness of the methods and principles employed during the investigative process.
#
# Core Principles and Application
#
# The application of deontology in research is governed by categorical imperatives, such as treating individuals as ends in themselves and never merely as means. This translates into inviolable duties for researchers. For instance, obtaining informed consent is not a procedural hurdle to optimize data collection but a fundamental moral requirement that respects participant autonomy. Similarly, duties of honesty prohibit data fabrication, and duties of justice demand fair subject selection, regardless of the potential societal benefit a skewed sample might promise.
#
# Analytical Strengths and Limitations
#
# This framework provides clear, principled boundaries that protect research subjects and uphold integrity, offering robust arguments against unethical shortcuts. However, its rigidity presents challenges in complex, real-world scenarios. A strict deontological stance might, for example, forbid a study using minor deception even if it causes no harm and yields significant knowledge about critical social behavior. This highlights a potential conflict between unwavering duty and beneficial consequences, a central tension in research ethics.
#
# Conclusion
#
# Employing a deontological framework in problem-solving research ensures a steadfast commitment to moral principles, safeguarding the dignity and rights of all involved. While it may sometimes conflict with pragmatic goals, it serves as an essential anchor, reminding researchers that ethical constraints are not obstacles to be circumvented but the very foundation of credible and honorable scientific inquiry.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_2.csv"

df2.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 3. Few-shot prompting
#
# ```
# You are a helpful writing assistant. Your task is to generate essays of a given length and topic.
# Start directly with the first sentence. No titles or headings. Output only the essay text.
#
# Here is an example:
#
# Example topic: "{}"
# Example length: {} words
#
# Example output:
# {}
#
# Now generate a new essay.
#
# Topic: "{}"
# Length: {} words
#
# Write the essay now.
# ```
#
# В качестве примера используется эссе из этого же набора, но на другую тему.

# %%
def generate_few_shot(model_name, df, prompt_raw, start=0, n=5000):
    rows = []
    for i in range(start + 1, start + n + 1):
        prev_title = df.loc[i - 1, "title"]
        prev_length = word_count(df.loc[i - 1, "text"])
        prev_text = df.loc[i - 1, "text"]
        
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
    
        prompt_formatted = prompt_raw.format(prev_title, prev_length, prev_text, title, length)

        try:
            response = generate_response(prompt_formatted)
        except:
            continue
            
        response = response.lstrip()
    
        rows.append({"title": title, "prompt": prompt_formatted, "text": response, "model": model_name})

        print_progress(start, i, n)
    
    return pd.DataFrame(rows)

# %%
prompt = """
You are a helpful writing assistant. Your task is to generate essays of a given length and topic.
Start directly with the first sentence. No titles or headings. Output only the essay text.

Here is an example:

Example topic: "{}"
Example length: {} words

Example output:
{}

Now generate a new essay.

Topic: "{}"
Length: {} words

Write the essay now.
"""

df3 = generate_few_shot(MODEL, df, prompt, start=START, n=OUT_COUNT)
df3.head()
# Out:
# 1.0% done
# 2.0% done
# 3.0% done
# 4.0% done
# 5.0% done
# 6.0% done
# 7.0% done
# 8.0% done
# 9.0% done
# 10.0% done
# 11.0% done
# 12.0% done
# 13.0% done
# 14.0% done
# 15.0% done
# 16.0% done
# 17.0% done
# 18.0% done
# 19.0% done
# 20.0% done
# 21.0% done
# 22.0% done
# 23.0% done
# 24.0% done
# 25.0% done
# 26.0% done
# 27.0% done
# 28.0% done
# 29.0% done
# 30.0% done
# 31.0% done
# 32.0% done
# 33.0% done
# 34.0% done
# 35.0% done
# 36.0% done
# 37.0% done
# 38.0% done
# 39.0% done
# 40.0% done
# 41.0% done
# 42.0% done
# 43.0% done
# 44.0% done
# 45.0% done
# 46.0% done
# 47.0% done
# 48.0% done
# 49.0% done
# 50.0% done
# 51.0% done
# 52.0% done
# 53.0% done
# 54.0% done
# 55.0% done
# 56.0% done
# 57.0% done
# 58.0% done
# 59.0% done
# 60.0% done
# 61.0% done
# 62.0% done
# 63.0% done
# 64.0% done
# 65.0% done
# 66.0% done
# 67.0% done
# 68.0% done
# 69.0% done
# 70.0% done
# 71.0% done
# 72.0% done
# 73.0% done
# 74.0% done
# 75.0% done
# 76.0% done
# 77.0% done
# 78.0% done
# 79.0% done
# 80.0% done
# 81.0% done
# 82.0% done
# 83.0% done
# 84.0% done
# 85.0% done
# 86.0% done
# 87.0% done
# 88.0% done
# 89.0% done
# 90.0% done
# 91.0% done
# 92.0% done
# 93.0% done
# 94.0% done
# 95.0% done
# 96.0% done
# 97.0% done
# 98.0% done
# 99.0% done
# 100.0% done
#                                                title  \
# 0  A Fire Research Program in the State of Califo...
# 1    A Gang Culture Among the Latinos Research Paper
# 2  A Qualitative Research Method and Its Use in a...
# 3  “A River Runs Through It”: The Novella vs. The...
# 4  A Summary of the “Ceremony” Book by L. M. Silk...
#
#                                               prompt  \
# 0  \nYou are a helpful writing assistant. Your ta...
# 1  \nYou are a helpful writing assistant. Your ta...
# 2  \nYou are a helpful writing assistant. Your ta...
# 3  \nYou are a helpful writing assistant. Your ta...
# 4  \nYou are a helpful writing assistant. Your ta...
#
#                                                 text          model
# 0  The increasing frequency and severity of wildf...  deepseek-chat
# 1  The phenomenon of gang culture within Latino c...  deepseek-chat
# 2  Qualitative research methods occupy a vital po...  deepseek-chat
# 3  Norman Maclean’s 1976 novella “A River Runs Th...  deepseek-chat
# 4  In her seminal 1977 novel *Ceremony*, Leslie M...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df3, EXAMPLE_ID)
# Out:
# Prompt =============================================================================================
#
# You are a helpful writing assistant. Your task is to generate essays of a given length and topic.
# Start directly with the first sentence. No titles or headings. Output only the essay text.
#
# Here is an example:
#
# Example topic: "A Deontological Ethical Framework Problem Solving Research Paper"
# Example length: 200 words
#
# Example output:
# Introduction
#
# The present paper focuses on the problem involving Harriet and her best friend, Afeni. Harriet is dying and requires an expensive drug, and Afeni breaks into the drug store and steals the medicine. The rationale behind that action is that she only had half of the required sum, while the store’s owner, Amos, refused to reduce the cost or sell the drug on credit. A deontologist would firmly state that Afeni’s action is morally wrong because it violates a maxim and implies the categorical imperative.
#
# Main body
#
# A deontological ethical framework assesses actions regarding how they relate to a specific set of rules, drawing no attention to what consequences can arise. Consequently, a person has an obligation to behave appropriately, meaning that an action is considered morally wrong if it violates a commonly accepted rule. Regarding the problem under analysis, Afeni brought the law and stole a drug. In this case, a maxim of “Do not steal” is involved, and this subjective principle reveals the necessary way of behavior. As a result, Afeni violated the maxim, meaning that her action was morally wrong. Deontological ethics also relies on moral law as a categorical imperative that should guide decision-making. Consequently, this information demonstrates that a deontologist would have sufficient reasons to state that Afeni made the wrong action.
#
# Conclusion
#
# In conclusion, a deontological ethical framework stipulates that actions and decisions should meet the specific rules irrespective of what potential consequences can arise. This approach demonstrates that Afeni’s decision to steal a drug was morally wrong because it violated the maxim of “Do not steal,” irrespective of an attempt to save her friend’s life. Consequently, one can say that deontological ethics focuses on the moral law in the given moment to evaluate an action.
#
#
# Now generate a new essay.
#
# Topic: "A Fire Research Program in the State of California Essay"
# Length: 1000 words
#
# Write the essay now.
#
# ====================================================================================================
# A Fire Research Program in the State of California Essay
#
# The increasing frequency and severity of wildfires in California represent one of the most pressing environmental and public safety challenges of the 21st century, necessitating a comprehensive, scientifically robust, and well-funded fire research program. This multifaceted crisis, driven by a confluence of climatic change, historical land management practices, and expanding human development into the wildland-urban interface (WUI), demands a research agenda that is equally interdisciplinary and forward-looking. A state-level research program must therefore integrate fields from atmospheric science and forestry to social psychology and structural engineering, aiming not merely to suppress fires but to fundamentally reshape our relationship with fire in the Californian landscape. The ultimate goal of such a program is to generate actionable knowledge that enhances ecological resilience, protects communities, and guides sustainable policy, transforming fire from an omnipresent threat into a managed force of nature.
#
# The scientific foundation of this program must begin with an advanced understanding of fire behavior and its primary drivers. Research must leverage next-generation technologies, such as coupled fire-atmosphere modeling using supercomputers, drone-based LiDAR for precise fuel mapping, and artificial intelligence to analyze historical fire patterns and predict future risk zones. A critical focus must be on the dynamics of "megafires" and the conditions that lead to extreme fire behavior, including pyroconvection and ember storms. Concurrently, a parallel research pillar must investigate the ecological role of fire in California's diverse ecosystems, from coastal chaparral to Sierra Nevada forests. This involves studying the effects of different fire regimes—frequency, intensity, and seasonality—on biodiversity, soil health, and water cycles. Prescribed fire and cultural burning, practices long employed by Indigenous communities, require rigorous scientific validation and integration into modern land management. Research must quantify the ecological benefits of these practices against the risks, developing best-practice protocols for different regions and weather windows to restore ecological balance and reduce hazardous fuel loads.
#
# Equally vital is research focused on human communities and infrastructure. A social science research component is essential to understand risk perception, communication, and evacuation behavior. Studies must identify why mandatory evacuation orders are sometimes ignored and develop more effective warning systems tailored to diverse communities, including non-English speakers and vulnerable populations. Furthermore, research must guide land-use planning and the development of fire-adapted communities. This includes testing and rating fire-resistant building materials, evaluating the effectiveness of defensible space regulations, and designing community-scale fuel breaks and safe havens. Economic research should also model the full cost of wildfires, including healthcare impacts from smoke, lost economic productivity, and ecosystem service degradation, to justify investments in prevention and resilience. The program must foster innovation in firefighting technology, such as improved personal protective equipment, next-generation retardants, and autonomous systems for initial attack, while also studying firefighter safety and the physiological impacts of prolonged exposure to extreme conditions.
#
# The policy and management implications drawn from this research are where theory must translate into tangible action. A successful research program cannot exist in an academic vacuum; it must have a direct pipeline to legislators, agency leaders, and land managers. Research should inform the revision of building codes in high-risk zones, the strategic allocation of resources for fuel reduction projects, and the development of liability frameworks that encourage prescribed burning. It must also address complex governance challenges, such as coordinating response across countless local, state, and federal jurisdictions and integrating private landowner incentives into broader landscape-scale management plans. Legal and institutional research is needed to streamline environmental reviews for proactive forest health projects without sacrificing necessary protections, a significant bottleneck in current management. Furthermore, research should evaluate the efficacy of different insurance models and potential public-private partnerships for funding resilience measures, ensuring that the financial burden does not fall disproportionately on at-risk residents.
#
# Finally, a cornerstone of the program must be education and continuous adaptation. Knowledge transfer is critical; findings must be disseminated not only in scientific journals but also through extension services, community workshops, and K-12 curriculum development. Training a new generation of fire professionals—ecologists, planners, and firefighters—versed in this integrated science is paramount. The program itself must embody adaptive management, with a built-in feedback loop that continuously assesses the effectiveness of implemented strategies and pivots as conditions change. Climate projections indicating hotter droughts, reduced snowpack, and stronger Santa Ana and Diablo winds must be baked into every research question, ensuring strategies are robust under future scenarios. This requires long-term monitoring networks and a commitment to sustained funding, moving beyond reactive appropriations following disaster to a stable, strategic investment in the state’s future.
#
# In conclusion, a comprehensive fire research program for California is not a luxury but an existential necessity. It represents a commitment to confronting the wildfire crisis with the full force of scientific inquiry and innovation. By deepening our understanding of fire physics, ecology, and human dynamics, and by relentlessly translating that knowledge into smarter policy, resilient communities, and restored landscapes, such a program can chart a path toward coexistence with fire. The alternative—a continued cycle of catastrophic loss and reactionary spending—is economically and ecologically unsustainable. The imperative is clear: to invest in a science-driven future where California’s communities and natural heritage can thrive despite the flames, safeguarded by knowledge, preparation, and a rekindled respect for the essential, if formidable, role of fire in the state’s environment.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_3.csv"

df3.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 4. Content Abstraction (Regeneration Learning)
#
# Первый промпт:
# ```
# Identify the writing style and format of the text, excluding all semantic content and themes.
#
# Text:
# {}
# ```
#
# Второй промпт:
# ```
# Write an essay of about {} words on the topic '{}'.
#
# You are given the following style-and-format description:
# '{}'
#
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
# ```

# %%
def generate_with_content(model_name, df, prompt_raw_1, prompt_raw_2, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
        text = df.loc[i, "text"]

        prompt_1_formatted = prompt_raw_1.format(text)

        try:
            response_1 = generate_response(prompt_1_formatted)
            response_1 = response_1.lstrip()
    
            prompt_2_formatted = prompt_raw_2.format(length, title, response_1)
            response_2 = generate_response(prompt_2_formatted)
        except:
            continue
            
        response = response_2.lstrip()
    
        rows.append({
            "title": title, 
            "prompt_1": prompt_1_formatted, 
            "response": response_1,
            "prompt_2": prompt_2_formatted, 
            "text": response, 
            "model": model_name
        })

        print_progress(start, i, n)
    
    return pd.DataFrame(rows)

# %%
prompt_1 = """
Identify the writing style and format of the text, excluding all semantic content and themes.

Text:
{}
"""

prompt_2 = """
Write an essay of about {} words on the topic '{}'.

You are given the following style-and-format description:
'{}'

Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
Output only the essay text.
"""

# %%
df4 = generate_with_content(MODEL, df, prompt_1, prompt_2, start=START, n=OUT_COUNT)
df4.head()
# Out:
# 0.0% done
# 1.0% done
# 2.0% done
# 3.0% done
# 4.0% done
# 5.0% done
# 6.0% done
# 7.0% done
# 8.0% done
# 9.0% done
# 10.0% done
# 11.0% done
# 12.0% done
# 13.0% done
# 14.0% done
# 15.0% done
# 16.0% done
# 17.0% done
# 18.0% done
# 19.0% done
# 20.0% done
# 21.0% done
# 22.0% done
# 23.0% done
# 24.0% done
# 25.0% done
# 26.0% done
# 27.0% done
# 28.0% done
# 29.0% done
# 30.0% done
# 31.0% done
# 32.0% done
# 33.0% done
# 34.0% done
# 35.0% done
# 36.0% done
# 37.0% done
# 38.0% done
# 39.0% done
# 40.0% done
# 41.0% done
# 42.0% done
# 43.0% done
# 44.0% done
# 45.0% done
# 46.0% done
# 47.0% done
# 48.0% done
# 49.0% done
# 50.0% done
# 51.0% done
# 52.0% done
# 53.0% done
# 54.0% done
# 55.0% done
# 56.0% done
# 57.0% done
# 58.0% done
# 59.0% done
# 60.0% done
# 61.0% done
# 62.0% done
# 63.0% done
# 64.0% done
# 65.0% done
# 66.0% done
# 67.0% done
# 68.0% done
# 69.0% done
# 70.0% done
# 71.0% done
# 72.0% done
# 73.0% done
# 74.0% done
# 75.0% done
# 76.0% done
# 77.0% done
# 78.0% done
# 79.0% done
# 80.0% done
# 81.0% done
# 82.0% done
# 83.0% done
# 84.0% done
# 85.0% done
# 86.0% done
# 87.0% done
# 88.0% done
# 89.0% done
# 90.0% done
# 91.0% done
# 92.0% done
# 93.0% done
# 94.0% done
# 95.0% done
# 96.0% done
# 97.0% done
# 98.0% done
# 99.0% done
#                                                title  \
# 0  A Deontological Ethical Framework Problem Solv...
# 1  A Fire Research Program in the State of Califo...
# 2    A Gang Culture Among the Latinos Research Paper
# 3  A Qualitative Research Method and Its Use in a...
# 4  “A River Runs Through It”: The Novella vs. The...
#
#                                             prompt_1  \
# 0  \nIdentify the writing style and format of the...
# 1  \nIdentify the writing style and format of the...
# 2  \nIdentify the writing style and format of the...
# 3  \nIdentify the writing style and format of the...
# 4  \nIdentify the writing style and format of the...
#
#                                             response  \
# 0  **Writing Style:**  \nFormal, analytical, and ...
# 1  Based solely on its structural and formal char...
# 2  Based solely on its structural and formal pres...
# 3  Based on the provided text, the writing style ...
# 4  **Writing Style and Format Analysis**\n\n**For...
#
#                                             prompt_2  \
# 0  \nWrite an essay of about 200 words on the top...
# 1  \nWrite an essay of about 1000 words on the to...
# 2  \nWrite an essay of about 2900 words on the to...
# 3  \nWrite an essay of about 1200 words on the to...
# 4  \nWrite an essay of about 900 words on the top...
#
#                                                 text          model
# 0  A deontological ethical framework provides a r...  deepseek-chat
# 1  The management of wildfire risk in the State o...  deepseek-chat
# 2  The phenomenon of street gangs represents a pe...  deepseek-chat
# 3  Qualitative research methods occupy a vital po...  deepseek-chat
# 4  The process of adapting a literary work for th...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df4, EXAMPLE_ID)
# Out:
# Prompt 1 =============================================================================================
#
# Identify the writing style and format of the text, excluding all semantic content and themes.
#
# Text:
# Introduction
#
# The present paper focuses on the problem involving Harriet and her best friend, Afeni. Harriet is dying and requires an expensive drug, and Afeni breaks into the drug store and steals the medicine. The rationale behind that action is that she only had half of the required sum, while the store’s owner, Amos, refused to reduce the cost or sell the drug on credit. A deontologist would firmly state that Afeni’s action is morally wrong because it violates a maxim and implies the categorical imperative.
#
# Main body
#
# A deontological ethical framework assesses actions regarding how they relate to a specific set of rules, drawing no attention to what consequences can arise. Consequently, a person has an obligation to behave appropriately, meaning that an action is considered morally wrong if it violates a commonly accepted rule. Regarding the problem under analysis, Afeni brought the law and stole a drug. In this case, a maxim of “Do not steal” is involved, and this subjective principle reveals the necessary way of behavior. As a result, Afeni violated the maxim, meaning that her action was morally wrong. Deontological ethics also relies on moral law as a categorical imperative that should guide decision-making. Consequently, this information demonstrates that a deontologist would have sufficient reasons to state that Afeni made the wrong action.
#
# Conclusion
#
# In conclusion, a deontological ethical framework stipulates that actions and decisions should meet the specific rules irrespective of what potential consequences can arise. This approach demonstrates that Afeni’s decision to steal a drug was morally wrong because it violated the maxim of “Do not steal,” irrespective of an attempt to save her friend’s life. Consequently, one can say that deontological ethics focuses on the moral law in the given moment to evaluate an action.
#
#
# ====================================================================================================
# **Writing Style:**
# Formal, analytical, and expository. The prose is structured, objective, and declarative, employing academic diction and precise terminology. Sentences are complex and grammatically controlled, with a focus on clarity and logical progression. The tone is impersonal and didactic, avoiding figurative language or subjective expression.
#
# **Format:**
# A short academic essay, consisting of three clearly demarcated sections:
# 1. **Introduction** – Presents the scenario and states the thesis.
# 2. **Main body** – Develops the argument through definition, application of theory, and deductive reasoning.
# 3. **Conclusion** – Restates the thesis and summarizes the argument.
#
# The structure follows a conventional essay organization: introduction, development, conclusion. Paragraphs are topical and sequential, each advancing a distinct component of the analysis. No headings or subheadings beyond the implicit section labels are used.
# Prompt 2 =============================================================================================
#
# Write an essay of about 200 words on the topic 'A Deontological Ethical Framework Problem Solving Research Paper'.
#
# You are given the following style-and-format description:
# '**Writing Style:**
# Formal, analytical, and expository. The prose is structured, objective, and declarative, employing academic diction and precise terminology. Sentences are complex and grammatically controlled, with a focus on clarity and logical progression. The tone is impersonal and didactic, avoiding figurative language or subjective expression.
#
# **Format:**
# A short academic essay, consisting of three clearly demarcated sections:
# 1. **Introduction** – Presents the scenario and states the thesis.
# 2. **Main body** – Develops the argument through definition, application of theory, and deductive reasoning.
# 3. **Conclusion** – Restates the thesis and summarizes the argument.
#
# The structure follows a conventional essay organization: introduction, development, conclusion. Paragraphs are topical and sequential, each advancing a distinct component of the analysis. No headings or subheadings beyond the implicit section labels are used.'
#
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
#
# ====================================================================================================
# A Deontological Ethical Framework Problem Solving Research Paper
#
# A deontological ethical framework provides a robust methodology for problem-solving in research contexts, prioritizing duty and adherence to universal moral rules over consequentialist calculations. This essay argues that deontological ethics, by centering on principles such as respect for persons and the inviolability of informed consent, offers a necessary and stabilizing normative structure for navigating complex research dilemmas, particularly those involving human subjects. The framework’s core strength lies in its foundational imperatives, most notably the Kantian categorical imperative, which demands that individuals be treated always as ends in themselves and never merely as means. Applied to research, this translates into non-negotiable procedural duties: securing voluntary participation, ensuring full transparency, and upholding rigorous standards of honesty in data collection and reporting, irrespective of the potential beneficial outcomes a study might promise.
#
# The application of this theory yields clear, deductive reasoning for action. For instance, a researcher facing pressure to expedite a clinical trial must, under a deontological lens, categorically reject any coercion of participants or concealment of risks, as these acts violate the duty of respect. The moral worth of the action resides in its conformity to the rule, not in the utility of the research results. This creates a predictable ethical environment, protecting vulnerable populations from instrumentalization and maintaining the integrity of the scientific enterprise itself. While sometimes criticized for rigidity, this principled inflexibility is precisely its virtue in establishing trustworthy boundaries.
#
# In conclusion, a deontological approach systematically anchors research problem-solving in immutable duties rather than mutable outcomes. It affirms that the ethical conduct of research is defined by the inherent rightness of its procedures, ensuring that the pursuit of knowledge remains fundamentally aligned with the moral imperative to respect human dignity. This framework thus provides an essential, rule-based compass for researchers operating in ethically fraught terrain.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_4.csv"

df4.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 5. Outline‑guided Text Generation
#
# Первый промпт:
# ```
# You are an academic writing instructor.
# Create a well-structured outline for an academic essay on the following topic: {}.
#
# Requirements:
#
# The outline must include the following sections:
# - Introduction
# - Main Body (2–4 thematic sections)
# - Counterarguments / Alternative Perspectives
# - Conclusion
#
# Each section should contain 2–3 concise bullet points describing the key ideas or arguments.
# The outline should reflect a clear thesis-driven structure.
# Use formal academic language.
#
# Do not write the essay itself
# ```
#
# Второй промпт:
# ```
# You are an academic essay writer.
# Write a coherent academic essay of about {} words on the topic '{}' strictly following the outline below.
#
# Outline:
# {}
#
# Requirements:
# - Follow the outline in the given order without adding or removing sections.
# - Develop each bullet point into a full, well-argued paragraph.
# - Maintain a formal academic tone and clear argumentative logic.
# - Use appropriate academic transitions and signposting.
# - Do not introduce new arguments or themes not present in the outline.
# - Avoid informal language, personal anecdotes, and unsupported claims.
# ```

# %%
def generate_with_plan(model_name, df, prompt_raw_1, prompt_raw_2, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
        text = df.loc[i, "text"]
    
        prompt_1_formatted = prompt_raw_1.format(title)

        try:
            response_1 = generate_response(prompt_1_formatted)
            response_1 = response_1.lstrip()
    
            prompt_2_formatted = prompt_raw_2.format(length, title, response_1)
            response_2 = generate_response(prompt_2_formatted)
        except:
            continue
            
        response = response_2.lstrip()
    
        rows.append({
            "title": title, 
            "prompt_1": prompt_1_formatted, 
            "response": response_1,
            "prompt_2": prompt_2_formatted, 
            "text": response, 
            "model": model_name
        })

        print_progress(start, i, n)
    
    return pd.DataFrame(rows)

# %%
prompt_1 = """
You are an academic writing instructor.
Create a well-structured outline for an academic essay on the following topic: {}.

Requirements:

The outline must include the following sections:
- Introduction
- Main Body (2–4 thematic sections)
- Counterarguments / Alternative Perspectives
- Conclusion

Each section should contain 2–3 concise bullet points describing the key ideas or arguments.
The outline should reflect a clear thesis-driven structure.
Use formal academic language.

Do not write the essay itself
"""

prompt_2 = """
You are an academic essay writer.
Write a coherent academic essay of about {} words on the topic '{}' strictly following the outline below.

Outline:
{}

Requirements:
- Follow the outline in the given order without adding or removing sections.
- Develop each bullet point into a full, well-argued paragraph.
- Maintain a formal academic tone and clear argumentative logic.
- Use appropriate academic transitions and signposting.
- Do not introduce new arguments or themes not present in the outline.
- Avoid informal language, personal anecdotes, and unsupported claims.
"""

# %%
df5 = generate_with_plan(MODEL, df, prompt_1, prompt_2, start=START, n=OUT_COUNT)
df5.head()
# Out:
# 0.0% done
# 1.0% done
# 2.0% done
# 3.0% done
# 4.0% done
# 5.0% done
# 6.0% done
# 7.0% done
# 8.0% done
# 9.0% done
# 10.0% done
# 11.0% done
# 12.0% done
# 13.0% done
# 14.0% done
# 15.0% done
# 16.0% done
# 17.0% done
# 18.0% done
# 19.0% done
# 20.0% done
# 21.0% done
# 22.0% done
# 23.0% done
# 24.0% done
# 25.0% done
# 26.0% done
# 27.0% done
# 28.0% done
# 29.0% done
# 30.0% done
# 31.0% done
# 32.0% done
# 33.0% done
# 34.0% done
# 35.0% done
# 36.0% done
# 37.0% done
# 38.0% done
# 39.0% done
# 40.0% done
# 41.0% done
# 42.0% done
# 43.0% done
# 44.0% done
# 45.0% done
# 46.0% done
# 47.0% done
# 48.0% done
# 49.0% done
# 50.0% done
# 51.0% done
# 52.0% done
# 53.0% done
# 54.0% done
# 55.0% done
# 56.0% done
# 57.0% done
# 58.0% done
# 59.0% done
# 60.0% done
# 61.0% done
# 62.0% done
# 63.0% done
# 64.0% done
# 65.0% done
# 66.0% done
# 67.0% done
# 68.0% done
# 69.0% done
# 70.0% done
# 71.0% done
# 72.0% done
# 73.0% done
# 74.0% done
# 75.0% done
# 76.0% done
# 77.0% done
# 78.0% done
# 79.0% done
# 80.0% done
# 81.0% done
# 82.0% done
# 83.0% done
# 84.0% done
# 85.0% done
# 86.0% done
# 87.0% done
# 88.0% done
# 89.0% done
# 90.0% done
# 91.0% done
# 92.0% done
# 93.0% done
# 94.0% done
# 95.0% done
# 96.0% done
# 97.0% done
# 98.0% done
# 99.0% done
#                                                title  \
# 0  A Deontological Ethical Framework Problem Solv...
# 1  A Fire Research Program in the State of Califo...
# 2    A Gang Culture Among the Latinos Research Paper
# 3  A Qualitative Research Method and Its Use in a...
# 4  “A River Runs Through It”: The Novella vs. The...
#
#                                             prompt_1  \
# 0  \nYou are an academic writing instructor.\nCre...
# 1  \nYou are an academic writing instructor.\nCre...
# 2  \nYou are an academic writing instructor.\nCre...
# 3  \nYou are an academic writing instructor.\nCre...
# 4  \nYou are an academic writing instructor.\nCre...
#
#                                             response  \
# 0  **Academic Essay Outline: A Deontological Ethi...
# 1  **Outline for an Academic Essay: A Fire Resear...
# 2  **Academic Essay Outline: The Etiology and Soc...
# 3  **Outline: A Qualitative Research Method and I...
# 4  **Academic Essay Outline: “A River Runs Throug...
#
#                                             prompt_2  \
# 0  \nYou are an academic essay writer.\nWrite a c...
# 1  \nYou are an academic essay writer.\nWrite a c...
# 2  \nYou are an academic essay writer.\nWrite a c...
# 3  \nYou are an academic essay writer.\nWrite a c...
# 4  \nYou are an academic essay writer.\nWrite a c...
#
#                                                 text          model
# 0  In contemporary professional and societal cont...  deepseek-chat
# 1  **A Fire Research Program in the State of Cali...  deepseek-chat
# 2  **Academic Essay: The Etiology and Social Func...  deepseek-chat
# 3  **A Qualitative Research Method and Its Use in...  deepseek-chat
# 4  **“A River Runs Through It”: The Dialectic of ...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df5, EXAMPLE_ID)
# Out:
# Prompt 1 =============================================================================================
#
# You are an academic writing instructor.
# Create a well-structured outline for an academic essay on the following topic: A Deontological Ethical Framework Problem Solving Research Paper.
#
# Requirements:
#
# The outline must include the following sections:
# - Introduction
# - Main Body (2–4 thematic sections)
# - Counterarguments / Alternative Perspectives
# - Conclusion
#
# Each section should contain 2–3 concise bullet points describing the key ideas or arguments.
# The outline should reflect a clear thesis-driven structure.
# Use formal academic language.
#
# Do not write the essay itself
#
# ====================================================================================================
# **Academic Essay Outline: A Deontological Ethical Framework for Problem Solving**
#
# **I. Introduction**
# *   **Opening Context:** Establish the prevalence of complex ethical dilemmas in contemporary professional and societal contexts (e.g., artificial intelligence, biomedical ethics, corporate governance), necessitating structured analytical frameworks.
# *   **Thesis Statement:** This essay argues that a deontological ethical framework, grounded in the prioritization of duties, rules, and the intrinsic dignity of persons, provides a rigorous, consistent, and morally robust methodology for problem-solving, particularly in situations where consequences are uncertain or where fundamental rights are at stake.
# *   **Roadmap:** Outline the essay’s structure: defining deontological principles, demonstrating their application to a case study, engaging with consequentialist critiques, and affirming the framework’s value for upholding non-negotiable moral commitments.
#
# **II. Main Body: Foundational Principles of Deontological Ethics**
# *   **Core Tenets and Key Theorists:** Define deontology in contrast to consequentialism, focusing on the centrality of duty (Immanuel Kant’s *Groundwork*), categorical imperatives (universalizability and humanity as an end-in-itself), and the intrinsic rightness/wrongness of actions irrespective of outcomes.
# *   **The Problem-Solving Mechanism:** Explain how the framework operates procedurally: identifying relevant moral duties/rules, evaluating actions based on their adherence to these principles, and prioritizing respect for autonomous agents over utilitarian calculations.
#
# **III. Main Body: Applied Analysis – A Case Study in Data Privacy**
# *   **Presentation of a Dilemma:** Examine a specific scenario where a technology firm must decide whether to use personal user data for lucrative algorithm training without explicit, informed consent.
# *   **Deontological Resolution:** Apply the framework: 1) Determine duties (honesty, respect for autonomy, promise-keeping via user agreements); 2) Test the action against the categorical imperative (could “using data without consent” be universalized? Does it treat users merely as a means?); 3) Derive a duty-based conclusion prioritizing transparent consent procedures.
#
# **IV. Counterarguments / Alternative Perspectives**
# *   **The Consequentialist Critique:** Address the primary challenge that strict deontology can lead to morally untenable outcomes by ignoring severe negative consequences (e.g., a rule against lying potentially causing grave harm), arguing it can be rigid and impractical.
# *   **Hybrid and Virtue-Based Rejoinders:** Consider perspectives that seek to integrate duty with consequences (rule-utilitarianism) or shift focus to agent character (virtue ethics), acknowledging their appeal in complex scenarios but questioning their potential for normative inconsistency.
#
# **V. Conclusion**
# *   **Synthesis of Argument:** Reiterate that deontology offers indispensable clarity and moral fortitude in problem-solving by anchoring decisions in inviolable principles, thereby protecting fundamental rights and ensuring procedural justice, as demonstrated in the applied case.
# *   **Qualified Significance and Final Assertion:** Concede that while not exclusively sufficient for all dilemmas, a deontological framework provides a critical, non-negotiable foundation for ethical reasoning, ensuring that problem-solving never sacrifices core human dignity for expediency or uncertain gain.
# Prompt 2 =============================================================================================
#
# You are an academic essay writer.
# Write a coherent academic essay of about 200 words on the topic 'A Deontological Ethical Framework Problem Solving Research Paper' strictly following the outline below.
#
# Outline:
# **Academic Essay Outline: A Deontological Ethical Framework for Problem Solving**
#
# **I. Introduction**
# *   **Opening Context:** Establish the prevalence of complex ethical dilemmas in contemporary professional and societal contexts (e.g., artificial intelligence, biomedical ethics, corporate governance), necessitating structured analytical frameworks.
# *   **Thesis Statement:** This essay argues that a deontological ethical framework, grounded in the prioritization of duties, rules, and the intrinsic dignity of persons, provides a rigorous, consistent, and morally robust methodology for problem-solving, particularly in situations where consequences are uncertain or where fundamental rights are at stake.
# *   **Roadmap:** Outline the essay’s structure: defining deontological principles, demonstrating their application to a case study, engaging with consequentialist critiques, and affirming the framework’s value for upholding non-negotiable moral commitments.
#
# **II. Main Body: Foundational Principles of Deontological Ethics**
# *   **Core Tenets and Key Theorists:** Define deontology in contrast to consequentialism, focusing on the centrality of duty (Immanuel Kant’s *Groundwork*), categorical imperatives (universalizability and humanity as an end-in-itself), and the intrinsic rightness/wrongness of actions irrespective of outcomes.
# *   **The Problem-Solving Mechanism:** Explain how the framework operates procedurally: identifying relevant moral duties/rules, evaluating actions based on their adherence to these principles, and prioritizing respect for autonomous agents over utilitarian calculations.
#
# **III. Main Body: Applied Analysis – A Case Study in Data Privacy**
# *   **Presentation of a Dilemma:** Examine a specific scenario where a technology firm must decide whether to use personal user data for lucrative algorithm training without explicit, informed consent.
# *   **Deontological Resolution:** Apply the framework: 1) Determine duties (honesty, respect for autonomy, promise-keeping via user agreements); 2) Test the action against the categorical imperative (could “using data without consent” be universalized? Does it treat users merely as a means?); 3) Derive a duty-based conclusion prioritizing transparent consent procedures.
#
# **IV. Counterarguments / Alternative Perspectives**
# *   **The Consequentialist Critique:** Address the primary challenge that strict deontology can lead to morally untenable outcomes by ignoring severe negative consequences (e.g., a rule against lying potentially causing grave harm), arguing it can be rigid and impractical.
# *   **Hybrid and Virtue-Based Rejoinders:** Consider perspectives that seek to integrate duty with consequences (rule-utilitarianism) or shift focus to agent character (virtue ethics), acknowledging their appeal in complex scenarios but questioning their potential for normative inconsistency.
#
# **V. Conclusion**
# *   **Synthesis of Argument:** Reiterate that deontology offers indispensable clarity and moral fortitude in problem-solving by anchoring decisions in inviolable principles, thereby protecting fundamental rights and ensuring procedural justice, as demonstrated in the applied case.
# *   **Qualified Significance and Final Assertion:** Concede that while not exclusively sufficient for all dilemmas, a deontological framework provides a critical, non-negotiable foundation for ethical reasoning, ensuring that problem-solving never sacrifices core human dignity for expediency or uncertain gain.
#
# Requirements:
# - Follow the outline in the given order without adding or removing sections.
# - Develop each bullet point into a full, well-argued paragraph.
# - Maintain a formal academic tone and clear argumentative logic.
# - Use appropriate academic transitions and signposting.
# - Do not introduce new arguments or themes not present in the outline.
# - Avoid informal language, personal anecdotes, and unsupported claims.
#
# ====================================================================================================
# A Deontological Ethical Framework Problem Solving Research Paper
#
# In contemporary professional and societal contexts, from artificial intelligence to biomedical ethics, complex dilemmas necessitate structured analytical frameworks. This essay argues that a deontological ethical framework, grounded in the prioritization of duties, rules, and the intrinsic dignity of persons, provides a rigorous, consistent, and morally robust methodology for problem-solving, particularly in situations where consequences are uncertain or where fundamental rights are at stake. The analysis will proceed by defining deontological principles, demonstrating their application, engaging with critiques, and affirming the framework’s value.
#
# The deontological framework, primarily associated with Immanuel Kant, is defined in contrast to consequentialism. Its core tenets hold that an action’s moral worth derives from its adherence to duty and universalizable rules, not its outcomes. Kant’s categorical imperatives—to act only on maxims one can will as universal law and to treat humanity always as an end-in-itself—are foundational. As a problem-solving mechanism, this requires identifying relevant moral duties, evaluating actions based solely on their conformity to these principles, and prioritizing respect for autonomous agents over utilitarian calculations.
#
# Consider a technology firm deciding whether to use personal user data for algorithm training without explicit, informed consent. A deontological analysis first identifies duties: honesty, respect for autonomy, and promise-keeping implied in user agreements. Applying the categorical imperative, the maxim “use data without consent” fails universalizability and treats users merely as a means to profit. Consequently, the duty-based resolution mandates transparent consent procedures, regardless of potential financial gains from the data.
#
# A primary critique, from a consequentialist perspective, is that strict deontology can lead to morally untenable outcomes by ignoring severe harms, such as a rule against lying causing grave danger. Hybrid approaches like rule-utilitarianism or virtue ethics offer appealing flexibility. However, while these acknowledge complexity, they risk normative inconsistency, whereas deontology provides unwavering protection for fundamental principles.
#
# In synthesis, deontology offers indispensable clarity and moral fortitude in problem-solving by anchoring decisions in inviolable principles, thereby protecting rights and ensuring procedural justice, as demonstrated. While not exclusively sufficient for all dilemmas, it provides a critical, non-negotiable foundation, ensuring that ethical reasoning never sacrifices core human dignity for expediency or uncertain gain.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_5.csv"

df5.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)
