# %% [markdown]
# # Генерация датасетов моделью DeepSeek Chat
#
# DeepSeek-V3.2

# %%
EXAMPLE_ID = 0
MODEL = 'deepseek-chat'
START = 2500
OUT_COUNT = 500
OUT_FILE_PREFIX = 'deepseek_essays'
PAUSE_SECONDS = 1

# %% [markdown]
# ### Исходный датасет, написанный человеком

# %%
import pandas as pd

df = pd.read_csv("../datasets/human_essays.csv", encoding="utf-8")
df.head(10)
# Out:
#                                                title  \
# 0    12 Years a Slave: An Analysis of the Film Essay
# 1  20+ Social Media Post Ideas to Radically Simpl...
# 2  533 U.S. 27 (2001) Kyllo v. United States: The...
# 3            A Charles Schwab Corporation Case Essay
# 4  A Clinical Office Assistant’s Attire Research ...
# 5  A Comic Science Fiction Film “Back to the Futu...
# 6   A Community Yard Sale as a Memorable Event Essay
# 7  A Complex in the “Every Secret Thing” Film by ...
# 8  A Customer Told to Wear a Mask Threw Snow at a...
# 9  A Disconnect Between Public Transportation and...
#
#                                                 text
# 0  The 2013 film 12 Years a Slave proved that sla...
# 1  Social Media Examiner’s (2021) video on social...
# 2  Table of Contents\n 1. Facts\n 2. Issue\n 3. H...
# 3  Charles Schwab is a for-profit Corporation who...
# 4  The work of a clinical or medical office worke...
# 5  Table of Contents\n 1. Introduction\n 2. Movie...
# 6  Autumn is not generally viewed as an appropria...
# 7  Carl Jung identifies the mother complex with a...
# 8  The article describes a recent Chicago hot dog...
# 9  One realistic way to commute is using private ...

# %% [markdown]
# #### Пример:

# %%
print(f"{df.iloc[EXAMPLE_ID,0]}\n\n{df.iloc[EXAMPLE_ID,1]}")
# Out:
# 12 Years a Slave: An Analysis of the Film Essay
#
# The 2013 film 12 Years a Slave proved that slavery is a worldwide issue. Indeed, the film made $150 million outside the United States and $57 million in the U.S., with a production budget of $20 million (Sharf, 2020). The movie was based on the memoir Twelve Years a Slave by Solomon Northup (Ntim, 2020). It tells the story of a free African American man who was kidnapped and sold into slavery. Solomon spent twelve years away from his family, being traded from one master to another. Fortunately, the protagonist met a person who helped him deliver a message to his family and friends, who came and rescued him. This movie accurately illustrates discriminatory relationships between white slaveholders and black slaves that stemmed from the dysfunctional system in the country and prejudices in people’s mindsets at that time.
#
# The two main ethnic groups presented in this film are White and African Americans, and the three social groups are affluent slaveholders, working for middle class, and enslaved people. The movie starts with the story of a free African American violinist Solomon Northup, living with his family in Saratoga, New York (McQueen, 2013). However, he was abducted by two white men, who tortured the man and sold him into slavery, changing his name to Plat. Before they met, Solomon and these two slave traders belonged to the same middle class. However, the fact that Northup was an African American made these individuals believe that they had the right to withdraw their freedom. The two masters that Solomon had were William Ford and Edwin Epps (McQueen, 2013). The former was kind and religious, while the latter was cruel and sadistic. Since the movie was based on a real story, it indicated that slaveholders had different characters, but all had the wrong perception of race.
#
# Although 12 Years a Slave is a film about slavery, the issues of collectivism and individualism are also raised. Specifically, the main character never identified himself as an enslaved man and continued claiming he was a free citizen (McQueen, 2013). However, his counterparts on the plant had a collective mindset, imprinted in them since childhood, that slavery is normal. These people helped each other because they belonged to the same group. Although Solomon tried to become a part of this community, his individual goal to return home was above the collective values.
#
# The movie also showed prejudice, generalizations, stereotyping, and discrimination against black people. For instance, when Ford brings Solomon and Elisa to his plantation, his wife expresses her sadness that Elisa got separated from her children. However, she also stated that “something to eat and some rest” could help that woman forget her children (McQueen, 2013, 32:47-32:51). This scene demonstrated the common prejudice about slaves that they were not capable of the same feelings as white people. An example of generalization and stereotyping was how Tibeats, a carpenter, became hostile to Solomon when he showed his intelligence and gave Ford advice. In fact, Tibeats believed that Plat would never be more competent than any white individual because Plat was a “nigger” (McQueen, 2013, 36:35-36:37). Notably, before Northup became enslaved, he never experienced discrimination, but when the main character was sold into slavery, discrimination was the only attitude that he could observe.
#
# In summary, 12 Years a Slave depicts the life of enslaved people and slave owners almost two centuries ago. The film narrates a free black man’s life from the moment when he enjoyed his family’s company in the state of New York to his abduction, enslavement, and eventual liberation. Overall, the movie raised such critical issues as discrimination, prejudice, stereotyping, and generalization that allowed slaveholders to maintain this societal structure for a long time.
#
# References
#
# McQueen, S. (2013). 12 years a slave [Film]. New Regency Productions.
#
# Ntim, Z. (2020). Steve McQueen says it took 11 years to create his new anthology “Small Axe” and reveals why producers almost pulled out of his Oscar-winning film “12 Years a Slave.” Insider.
#
# Sharf, Z. (2020). Steve McQueen recalls producers rejecting “12 Years a Slave” over false beliefs about black films. Indie Wire.

# %% [markdown]
# ### Утилиты

# %%
import math
import re


def round_word_count(c):
    return math.floor(c / 100) * 100

def word_count(text):
    words = re.findall(r'\b\w+\b', text)
    return round_word_count(len(words))

def print_example(data, example_id):
    if 'prompt' in data.iloc[example_id]:
        print(f"Prompt {'=' * 93}\n{data.iloc[example_id]['prompt']}")
        print(f"{'=' * 100}")
        print(f"{data.iloc[example_id]['title']}\n\n{data.iloc[example_id]['text']}")
        print(f"{'=' * 100}")
    if 'prompt_2' in data.iloc[example_id]:
        print(f"Prompt 1 {'=' * 93}\n{data.iloc[example_id]['prompt_1']}")
        print(f"{'=' * 100}")
        print(f"{data.iloc[example_id]['response']}")
        print(f"Prompt 2 {'=' * 93}\n{data.iloc[example_id]['prompt_2']}")
        print(f"{'=' * 100}")
        print(f"{data.iloc[example_id]['title']}\n\n{data.iloc[example_id]['text']}")
        print(f"{'=' * 100}")

def print_progress(start, i, n):
    if (i - start) % (n / 100) == 0:
        print(f"{100 * (i - start) / n}% done")

# %%
from dotenv import load_dotenv
import os
from openai import OpenAI


load_dotenv()

client = OpenAI(api_key=os.getenv("DEEPSEEK_API_KEY"), base_url="https://api.deepseek.com")

# %%
import time


def generate_response(prompt):
    response = client.chat.completions.create(
        model=MODEL,
        messages=[
            {
                "role": "system",
                "content": "You are an expert academic essay writer. You produce well-structured, logical, and substantive essays with clear argumentation, proper citations, and academic rigor."
            },
            {
                "role": "user",
                "content": prompt
            }
        ],
        stream=False
    )

    time.sleep(PAUSE_SECONDS)
    
    return response.choices[0].message.content

# %% [markdown]
# ### Вариант 1. Prompt-based generation
#
# ```
# Write an essay of about {} words on the topic '{}'.
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
# ```

# %%
def generate(model_name, df, prompt_raw, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
    
        prompt_formatted = prompt_raw.format(length, title)

        try:
            response = generate_response(prompt_formatted)
        except:
            continue
            
        response = response.lstrip()
    
        rows.append({"title": title, "prompt": prompt_formatted, "text": response, "model": model_name})

        print_progress(start, i, n)
    
    return pd.DataFrame(rows)

# %%
prompt = """
Write an essay of about {} words on the topic '{}'.
Start directly with the first sentence of the essay. Absolutely no title or heading of any kind. 
Output only the essay text. 
"""

df1 = generate(MODEL, df, prompt, start=START, n=OUT_COUNT)
df1.head()
# Out:
# 0.0% done
# 1.0% done
# 2.0% done
# 3.0% done
# 4.0% done
# 5.0% done
# 6.0% done
# 7.0% done
# 8.0% done
# 9.0% done
# 10.0% done
# 11.0% done
# 12.0% done
# 13.0% done
# 14.0% done
# 15.0% done
# 16.0% done
# 17.0% done
# 18.0% done
# 19.0% done
# 20.0% done
# 21.0% done
# 22.0% done
# 23.0% done
# 24.0% done
# 25.0% done
# 26.0% done
# 27.0% done
# 28.0% done
# 29.0% done
# 30.0% done
# 31.0% done
# 32.0% done
# 33.0% done
# 34.0% done
# 35.0% done
# 36.0% done
# 37.0% done
# 38.0% done
# 39.0% done
# 40.0% done
# 41.0% done
# 42.0% done
# 43.0% done
# 44.0% done
# 45.0% done
# 46.0% done
# 47.0% done
# 48.0% done
# 49.0% done
# 50.0% done
# 51.0% done
# 52.0% done
# 53.0% done
# 54.0% done
# 55.0% done
# 56.0% done
# 57.0% done
# 58.0% done
# 59.0% done
# 60.0% done
# 61.0% done
# 62.0% done
# 63.0% done
# 64.0% done
# 65.0% done
# 66.0% done
# 67.0% done
# 68.0% done
# 69.0% done
# 70.0% done
# 71.0% done
# 72.0% done
# 73.0% done
# 74.0% done
# 75.0% done
# 76.0% done
# 77.0% done
# 78.0% done
# 79.0% done
# 80.0% done
# 81.0% done
# 82.0% done
# 83.0% done
# 84.0% done
# 85.0% done
# 86.0% done
# 87.0% done
# 88.0% done
# 89.0% done
# 90.0% done
# 91.0% done
# 92.0% done
# 93.0% done
# 94.0% done
# 95.0% done
# 96.0% done
# 97.0% done
# 98.0% done
# 99.0% done
#                                                title  \
# 0  Mulan Disney Film Directed by Bancroft & Cook ...
# 1      Multicultural Food Marketing Techniques Essay
# 2       Multiculturalism: Why Is It Important? Essay
# 3             Multimedia and Sports Journalism Essay
# 4  Multimedia Learning During Art and Design Less...
#
#                                               prompt  \
# 0  \nWrite an essay of about 300 words on the top...
# 1  \nWrite an essay of about 700 words on the top...
# 2  \nWrite an essay of about 900 words on the top...
# 3  \nWrite an essay of about 300 words on the top...
# 4  \nWrite an essay of about 900 words on the top...
#
#                                                 text          model
# 0  The 1998 Disney animated film *Mulan*, directe...  deepseek-chat
# 1  The global marketplace is no longer a monolith...  deepseek-chat
# 2  In an era defined by global interconnection an...  deepseek-chat
# 3  The landscape of sports journalism has been fu...  deepseek-chat
# 4  The integration of multimedia resources into a...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df1, EXAMPLE_ID)
# Out:
# Prompt =============================================================================================
#
# Write an essay of about 300 words on the topic 'Mulan Disney Film Directed by Bancroft & Cook Essay'.
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
#
# ====================================================================================================
# Mulan Disney Film Directed by Bancroft & Cook Essay
#
# The 1998 Disney animated film *Mulan*, directed by Tony Bancroft and Barry Cook, transcends the conventional princess narrative to deliver a powerful commentary on gender, identity, and familial duty within a framework of spectacular entertainment. While drawing loose inspiration from the ancient Chinese ballad of Hua Mulan, the film ingeniously adapts its source material for a contemporary audience, utilizing the animated musical format to explore themes of self-actualization. The central conflict arises not from a traditional villain, but from the rigid societal expectations that confine Mulan; her journey to save her father by posing as a male soldier, Ping, becomes a metaphor for the struggle to prove one’s intrinsic worth beyond prescribed gender roles. Crucially, Mulan’s success is not achieved through supernatural aid or brute strength alone, but through her intelligence, resilience, and innovative thinking, as exemplified in her pivotal defeat of the Hun army using a single rocket. This narrative choice reinforces the film’s core message that true honor comes from authenticity and courage of conscience. Furthermore, the directors skillfully balance this thematic weight with vibrant animation, memorable musical numbers, and comedic relief, largely provided by Eddie Murphy’s Mushu, ensuring broad appeal. The film’s cultural impact is significant, offering a heroine whose value is defined by her mind and spirit, challenging the passive archetypes prevalent in earlier animated features. Ultimately, Bancroft and Cook’s *Mulan* succeeds as both a captivating adventure and a substantive cultural text, arguing persuasively that identity is a complex tapestry of individual merit, loyalty, and personal truth, rather than a simple adherence to societal decree.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_1.csv"

df1.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 2. Prompt-based Style Transfer
#
# ```
# Write an essay of about {} words on the topic '{}', following the stylistic and structural conventions of IvyPanda essays.
#
# STYLE REQUIREMENTS (IvyPanda-like):
# 1. The tone must be academic, clear, neutral, and objective.
# 2. The essay should include background context, a clear analytical structure, and well-developed paragraphs.
# 3. Arguments must be supported with reasoning, concise explanations, and relevant examples.
# 4. The writing must be coherent, logically progressive, and easy to read.
# 5. Avoid emotional language or overly dramatic phrasing.
#
# STRUCTURE REQUIREMENTS:
# 1. Divide the essay into several sections, each starting with a plain-text subheading.
# 2. Subheadings must contain only letters and spaces — no punctuation, no symbols, and absolutely no Markdown formatting.
#    - This means: no asterisks, no bold, no italics, no underscores, no brackets.
#    - Subheadings must appear as plain text lines, e.g. Background Context
# 3. Each subheading must be on its own line with exactly one blank line before and after it.
# 4. No overall essay title — begin directly with the first subheading.
# 5. Output must be plain text only (no Markdown, no asterisks, no bold, no italics, no hashtags, no special formatting).
#
# OPTIONAL ELEMENTS:
# You may include a plain-text references section at the end if appropriate to the topic, but this is optional.
#
# Begin with the first subheading, then continue with the first paragraph.
# Output only the essay text.
# ```

# %%
def generate(model_name, df, prompt_raw, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
    
        prompt_formatted = prompt_raw.format(length, title)
    
        try:
            response = generate_response(prompt_formatted)
        except:
            continue
            
        response = response.lstrip()
    
        rows.append({"title": title, "prompt": prompt_formatted, "text": response, "model": model_name})

        print_progress(start, i, n)
    
    return pd.DataFrame(rows)

# %%
prompt = """
Write an essay of about {} words on the topic '{}', following the stylistic and structural conventions of IvyPanda essays.

STYLE REQUIREMENTS (IvyPanda-like):
1. The tone must be academic, clear, neutral, and objective.
2. The essay should include background context, a clear analytical structure, and well-developed paragraphs.
3. Arguments must be supported with reasoning, concise explanations, and relevant examples.
4. The writing must be coherent, logically progressive, and easy to read.
5. Avoid emotional language or overly dramatic phrasing.

STRUCTURE REQUIREMENTS:
1. Divide the essay into several sections, each starting with a plain-text subheading.
2. Subheadings must contain only letters and spaces — no punctuation, no symbols, and absolutely no Markdown formatting.
   - This means: no asterisks, no bold, no italics, no underscores, no brackets.
   - Subheadings must appear as plain text lines, e.g. Background Context
3. Each subheading must be on its own line with exactly one blank line before and after it.
4. No overall essay title — begin directly with the first subheading.
5. Output must be plain text only (no Markdown, no asterisks, no bold, no italics, no hashtags, no special formatting).

OPTIONAL ELEMENTS:
You may include a plain-text references section at the end if appropriate to the topic, but this is optional.

Begin with the first subheading, then continue with the first paragraph.
Output only the essay text.
"""

df2 = generate(MODEL, df, prompt, start=START, n=OUT_COUNT)
df2.head()
# Out:
# 0.0% done
# 1.0% done
# 2.0% done
# 3.0% done
# 4.0% done
# 5.0% done
# 6.0% done
# 7.0% done
# 8.0% done
# 9.0% done
# 10.0% done
# 11.0% done
# 12.0% done
# 13.0% done
# 14.0% done
# 15.0% done
# 16.0% done
# 17.0% done
# 18.0% done
# 19.0% done
# 20.0% done
# 21.0% done
# 22.0% done
# 23.0% done
# 24.0% done
# 25.0% done
# 26.0% done
# 27.0% done
# 28.0% done
# 29.0% done
# 30.0% done
# 31.0% done
# 32.0% done
# 33.0% done
# 34.0% done
# 35.0% done
# 36.0% done
# 37.0% done
# 38.0% done
# 39.0% done
# 40.0% done
# 41.0% done
# 42.0% done
# 43.0% done
# 44.0% done
# 45.0% done
# 46.0% done
# 47.0% done
# 48.0% done
# 49.0% done
# 50.0% done
# 51.0% done
# 52.0% done
# 53.0% done
# 54.0% done
# 55.0% done
# 56.0% done
# 57.0% done
# 58.0% done
# 59.0% done
# 60.0% done
# 61.0% done
# 62.0% done
# 63.0% done
# 64.0% done
# 65.0% done
# 66.0% done
# 67.0% done
# 68.0% done
# 69.0% done
# 70.0% done
# 71.0% done
# 72.0% done
# 73.0% done
# 74.0% done
# 75.0% done
# 76.0% done
# 77.0% done
# 78.0% done
# 79.0% done
# 80.0% done
# 81.0% done
# 82.0% done
# 83.0% done
# 84.0% done
# 85.0% done
# 86.0% done
# 87.0% done
# 88.0% done
# 89.0% done
# 90.0% done
# 91.0% done
# 92.0% done
# 93.0% done
# 94.0% done
# 95.0% done
# 96.0% done
# 97.0% done
# 98.0% done
# 99.0% done
#                                                title  \
# 0  Mulan Disney Film Directed by Bancroft & Cook ...
# 1      Multicultural Food Marketing Techniques Essay
# 2       Multiculturalism: Why Is It Important? Essay
# 3             Multimedia and Sports Journalism Essay
# 4  Multimedia Learning During Art and Design Less...
#
#                                               prompt  \
# 0  \nWrite an essay of about 300 words on the top...
# 1  \nWrite an essay of about 700 words on the top...
# 2  \nWrite an essay of about 900 words on the top...
# 3  \nWrite an essay of about 300 words on the top...
# 4  \nWrite an essay of about 900 words on the top...
#
#                                                 text          model
# 0  Background Context\n\nThe 1998 animated film M...  deepseek-chat
# 1  Background Context\n\nThe global marketplace i...  deepseek-chat
# 2  Background Context\n\nThe concept of multicult...  deepseek-chat
# 3  Background Context\n\nThe evolution of sports ...  deepseek-chat
# 4  Background Context\n\nThe integration of techn...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df2, EXAMPLE_ID)
# Out:
# Prompt =============================================================================================
#
# Write an essay of about 300 words on the topic 'Mulan Disney Film Directed by Bancroft & Cook Essay', following the stylistic and structural conventions of IvyPanda essays.
#
# STYLE REQUIREMENTS (IvyPanda-like):
# 1. The tone must be academic, clear, neutral, and objective.
# 2. The essay should include background context, a clear analytical structure, and well-developed paragraphs.
# 3. Arguments must be supported with reasoning, concise explanations, and relevant examples.
# 4. The writing must be coherent, logically progressive, and easy to read.
# 5. Avoid emotional language or overly dramatic phrasing.
#
# STRUCTURE REQUIREMENTS:
# 1. Divide the essay into several sections, each starting with a plain-text subheading.
# 2. Subheadings must contain only letters and spaces — no punctuation, no symbols, and absolutely no Markdown formatting.
#    - This means: no asterisks, no bold, no italics, no underscores, no brackets.
#    - Subheadings must appear as plain text lines, e.g. Background Context
# 3. Each subheading must be on its own line with exactly one blank line before and after it.
# 4. No overall essay title — begin directly with the first subheading.
# 5. Output must be plain text only (no Markdown, no asterisks, no bold, no italics, no hashtags, no special formatting).
#
# OPTIONAL ELEMENTS:
# You may include a plain-text references section at the end if appropriate to the topic, but this is optional.
#
# Begin with the first subheading, then continue with the first paragraph.
# Output only the essay text.
#
# ====================================================================================================
# Mulan Disney Film Directed by Bancroft & Cook Essay
#
# Background Context
#
# The 1998 animated film Mulan, directed by Tony Bancroft and Barry Cook, stands as a significant entry in the Disney Renaissance canon. It distinguishes itself by adapting the ancient Chinese legend of Hua Mulan, a young woman who disguises herself as a man to take her ailing father’s place in the imperial army. While adhering to the musical and comedic traditions of Disney animation, the film navigates complex themes of gender, identity, and familial honor, setting it apart from more conventional princess narratives. Its creation involved extensive cultural research, though it has been the subject of ongoing discourse regarding its representation of Chinese culture and its modifications to the original source material.
#
# Narrative and Thematic Analysis
#
# The film’s central thematic thrust is the subversion of traditional gender roles. Mulan’s journey is framed by her failure to conform to the rigid expectations of femininity, as satirized in the matchmaking song “Honor to Us All.” Her decision to impersonate a male soldier, Ping, becomes an act of both filial piety and personal defiance. The narrative cleverly uses her disguise to explore how identity is performed; Mulan must learn masculine-coded behaviors to survive, yet her ultimate success hinges not on brute strength but on her intelligence, ingenuity, and unconventional thinking, as demonstrated when she uses a rocket to trigger an avalanche. This resolution argues that true heroism and value are derived from individual character rather than gender.
#
# Cultural Adaptation and Representation
#
# Bancroft and Cook’s adaptation necessarily simplifies and Westernizes the ancient ballad for a global audience. The inclusion of comedic sidekicks like Mushu the dragon and the lucky cricket Cri-Kee follows Disney’s commercial formula, injecting humor but also diverting from the legend’s more solemn tone. The film’s visual style, inspired by Chinese landscape painting, and its incorporation of cultural elements like ancestor veneration demonstrate an effort toward authenticity. However, scholars note that the portrayal remains a filtered interpretation, blending Chinese motifs with a distinctly American narrative about individualism and self-discovery. This synthesis makes the story accessible but also invites critique regarding cultural appropriation.
#
# Conclusion
#
# In conclusion, Mulan represents a pivotal attempt by Disney to expand its narrative scope during the Renaissance era. Through the directorial vision of Bancroft and Cook, the film delivers an empowering story that challenges gender norms and celebrates cleverness over brute force. While its cultural representations are a negotiated blend of authenticity and commercial entertainment, its core message about integrity and self-sacrifice resonates universally. The film thus occupies a unique space as both a popular animated musical and a text that invites deeper analysis of identity and cross-cultural storytelling.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_2.csv"

df2.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 3. Few-shot prompting
#
# ```
# You are a helpful writing assistant. Your task is to generate essays of a given length and topic.
# Start directly with the first sentence. No titles or headings. Output only the essay text.
#
# Here is an example:
#
# Example topic: "{}"
# Example length: {} words
#
# Example output:
# {}
#
# Now generate a new essay.
#
# Topic: "{}"
# Length: {} words
#
# Write the essay now.
# ```
#
# В качестве примера используется эссе из этого же набора, но на другую тему.

# %%
def generate_few_shot(model_name, df, prompt_raw, start=0, n=5000):
    rows = []
    for i in range(start + 1, start + n + 1):
        prev_title = df.loc[i - 1, "title"]
        prev_length = word_count(df.loc[i - 1, "text"])
        prev_text = df.loc[i - 1, "text"]
        
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
    
        prompt_formatted = prompt_raw.format(prev_title, prev_length, prev_text, title, length)

        try:
            response = generate_response(prompt_formatted)
        except:
            continue
            
        response = response.lstrip()
    
        rows.append({"title": title, "prompt": prompt_formatted, "text": response, "model": model_name})

        print_progress(start, i, n)
    
    return pd.DataFrame(rows)

# %%
prompt = """
You are a helpful writing assistant. Your task is to generate essays of a given length and topic.
Start directly with the first sentence. No titles or headings. Output only the essay text.

Here is an example:

Example topic: "{}"
Example length: {} words

Example output:
{}

Now generate a new essay.

Topic: "{}"
Length: {} words

Write the essay now.
"""

df3 = generate_few_shot(MODEL, df, prompt, start=START, n=OUT_COUNT)
df3.head()
# Out:
# 1.0% done
# 2.0% done
# 3.0% done
# 4.0% done
# 5.0% done
# 6.0% done
# 7.0% done
# 8.0% done
# 9.0% done
# 10.0% done
# 11.0% done
# 12.0% done
# 13.0% done
# 14.0% done
# 15.0% done
# 16.0% done
# 17.0% done
# 18.0% done
# 19.0% done
# 20.0% done
# 21.0% done
# 22.0% done
# 23.0% done
# 24.0% done
# 25.0% done
# 26.0% done
# 27.0% done
# 28.0% done
# 29.0% done
# 30.0% done
# 31.0% done
# 32.0% done
# 33.0% done
# 34.0% done
# 35.0% done
# 36.0% done
# 37.0% done
# 38.0% done
# 39.0% done
# 40.0% done
# 41.0% done
# 42.0% done
# 43.0% done
# 44.0% done
# 45.0% done
# 46.0% done
# 47.0% done
# 48.0% done
# 49.0% done
# 50.0% done
# 51.0% done
# 52.0% done
# 53.0% done
# 54.0% done
# 55.0% done
# 56.0% done
# 57.0% done
# 58.0% done
# 59.0% done
# 60.0% done
# 61.0% done
# 62.0% done
# 63.0% done
# 64.0% done
# 65.0% done
# 66.0% done
# 67.0% done
# 68.0% done
# 69.0% done
# 70.0% done
# 71.0% done
# 72.0% done
# 73.0% done
# 74.0% done
# 75.0% done
# 76.0% done
# 77.0% done
# 78.0% done
# 79.0% done
# 80.0% done
# 81.0% done
# 82.0% done
# 83.0% done
# 84.0% done
# 85.0% done
# 86.0% done
# 87.0% done
# 88.0% done
# 89.0% done
# 90.0% done
# 91.0% done
# 92.0% done
# 93.0% done
# 94.0% done
# 95.0% done
# 96.0% done
# 97.0% done
# 98.0% done
# 99.0% done
# 100.0% done
#                                                title  \
# 0      Multicultural Food Marketing Techniques Essay
# 1       Multiculturalism: Why Is It Important? Essay
# 2             Multimedia and Sports Journalism Essay
# 3  Multimedia Learning During Art and Design Less...
# 4  Musculoskeletal, Metabolic, and Multisystem He...
#
#                                               prompt  \
# 0  \nYou are a helpful writing assistant. Your ta...
# 1  \nYou are a helpful writing assistant. Your ta...
# 2  \nYou are a helpful writing assistant. Your ta...
# 3  \nYou are a helpful writing assistant. Your ta...
# 4  \nYou are a helpful writing assistant. Your ta...
#
#                                                 text          model
# 0  The global marketplace is no longer a collecti...  deepseek-chat
# 1  Multiculturalism, defined as the coexistence a...  deepseek-chat
# 2  The landscape of sports journalism has been fu...  deepseek-chat
# 3  The integration of multimedia tools into art a...  deepseek-chat
# 4  The human body functions as an intricate netwo...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df3, EXAMPLE_ID)
# Out:
# Prompt =============================================================================================
#
# You are a helpful writing assistant. Your task is to generate essays of a given length and topic.
# Start directly with the first sentence. No titles or headings. Output only the essay text.
#
# Here is an example:
#
# Example topic: "Mulan Disney Film Directed by Bancroft & Cook Essay"
# Example length: 300 words
#
# Example output:
# One of the most popular Disney movies to date, Bankroft’s Mulan, which was released in 1998, presents a captivating story in a unique setting. In their work, the writers challenge the very norms of society to present a highly charismatic set of characters. In this essay, the changes in Mulan’s identity as a woman that are shown to the audience in the first part of the movie will be discussed.
#
# From the very beginning, it becomes clear that the gender roles in the movie are expected to be strictly upheld within society. The norms of the ancient Chinese community are clearly shown from the first minutes of the movie, as Mulan is being prepared to be wed (Bancroft & Cook, 1998, 0:6:30). Her role as a woman is to bring honor to her family (Bancroft & Cook, 1998, 0:6:57). Although she initially attempts to fit in, this setup is only an obstacle in Mulan’s path to the future she herself decides to choose.
#
# The rejection Mulan receives is a critical point for her character. She understands that she will never succeed at the path that is not her own (Bancroft & Cook, 1998, 0:12:05). However, choosing one’s fate as a woman of that era is a nigh-impossible task. Honor is what pushes Mulan to make a decision to challenge the otherwise predefined role that was set for her and take her father’s place in the army.
#
# In conclusion, Mulan experiences a shocking revelation that she will not succeed as a woman in this community, making her rethink the very meaning of honor on which her goal was set. She decides to choose her role herself, showing immense strength of character, care, and true devotion for her family. In this strictly hierarchical setting, Mulan’s actions are a challenge to the very foundation of society.
#
# Reference
#
# Bancroft, T., & Cook, B. (Directors). (1998). Mulan . Disney.
#
#
# Now generate a new essay.
#
# Topic: "Multicultural Food Marketing Techniques Essay"
# Length: 700 words
#
# Write the essay now.
#
# ====================================================================================================
# Multicultural Food Marketing Techniques Essay
#
# The global marketplace is no longer a collection of distinct national economies but a deeply interconnected web where consumer tastes are increasingly shaped by cross-cultural influences, making the marketing of food products a complex exercise in cultural translation and sensitivity. Effective multicultural food marketing transcends mere translation of language on packaging; it requires a nuanced understanding of cultural values, dietary practices, historical contexts, and symbolic meanings attached to food. Successful techniques in this domain generally converge on a strategic triad: authentic cultural representation, adaptive product development, and community-centric engagement, all of which must be executed with a foundational respect for the cultures being engaged to avoid the pitfalls of stereotyping or cultural appropriation.
#
# Authentic cultural representation is the cornerstone of credible multicultural marketing. This involves moving beyond superficial clichés—such as using generic "Asian" motifs or sombreros for Mexican products—and investing in deep cultural research. It means understanding regional variations; for instance, marketing a curry product requires specificity, as the culinary traditions of Punjab, Thailand, and Japan are profoundly different. Visual storytelling through packaging and advertising that reflects real people, authentic settings, and traditional preparation methods builds trust. A powerful technique is the incorporation of cultural narratives or heritage stories on packaging, explaining the origin of a dish or the significance of an ingredient within a particular community. For example, a brand marketing harissa might detail its Berber roots and its role in North African communal dining, thereby adding intangible value and educating a broader audience. This authenticity must extend to influencer partnerships, collaborating with cultural ambassadors, chefs, and food bloggers who have genuine credibility within the community, rather than merely using celebrities with tangential connections.
#
# Building upon authentic representation, adaptive product development—often termed "glocalization"—is a critical technique for bridging cultural gaps. This strategy involves modifying a core product to suit local tastes, dietary restrictions, and consumption occasions. This can range from subtle adjustments, such as altering spice levels or sweetness to align with regional palates, to more significant innovations like creating halal-certified versions of prepared meals or developing vegan alternatives to traditionally meat-centric dishes to cater to diverse ethical and religious dietary norms. The success of global chains like McDonald's, which offers McSpicy Paneer in India or Teriyaki Burgers in Japan, exemplifies this approach. However, for specialized food marketers, the technique can be more refined. It might involve creating convenient, ready-to-cook versions of complex traditional dishes, like Korean bibimbap or Nigerian jollof rice kits, that respect the original flavor profile while acknowledging the time constraints of modern consumers. This adaptation signals respect for the consumer's palate and lifestyle, positioning the brand as an enabler of cultural culinary practice rather than a dilutor of it.
#
# Finally, the most dynamic techniques are found in community-centric engagement. Multicultural marketing cannot be a one-way broadcast; it must foster dialogue and participation. This involves creating marketing campaigns that are not just *for* a cultural group but *with* them. Tactics include sponsoring and actively participating in cultural festivals, food fairs, and holiday celebrations like Diwali, Lunar New Year, or Eid, where sampling and immersive experiences can directly connect the product to its cultural context. Digital community building is equally vital, through culturally specific social media channels, recipe development contests that invite consumers to share their own uses for a product, and content that highlights customer stories and family traditions. A brand marketing Caribbean ingredients, for instance, might run a campaign inviting customers to share their family's curry goat recipe, thereby leveraging user-generated content and building a sense of shared ownership. This approach transforms consumers from passive buyers into active brand advocates within their communities, creating powerful organic word-of-mouth networks that are far more credible than traditional advertising.
#
# However, these techniques must be deployed with ethical caution. The line between appreciation and appropriation is thin. Marketing that reduces a rich culture to a mere aesthetic or fails to acknowledge origins can provoke backlash. Therefore, the overarching technique is one of partnership and reciprocity—working with cultural consultants, sourcing ingredients ethically from origin communities, and giving back through initiatives that support those communities. In conclusion, the most effective multicultural food marketing techniques are those that combine authenticity, intelligent adaptation, and genuine community engagement. In an era where consumers are increasingly discerning and value-driven, success lies not in selling a generic product to a global audience, but in thoughtfully connecting a product’s unique cultural essence to the lived experiences and identities of diverse consumers, thereby enriching the global food landscape with respect and integrity.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_3.csv"

df3.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 4. Content Abstraction (Regeneration Learning)
#
# Первый промпт:
# ```
# Identify the writing style and format of the text, excluding all semantic content and themes.
#
# Text:
# {}
# ```
#
# Второй промпт:
# ```
# Write an essay of about {} words on the topic '{}'.
#
# You are given the following style-and-format description:
# '{}'
#
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
# ```

# %%
def generate_with_content(model_name, df, prompt_raw_1, prompt_raw_2, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
        text = df.loc[i, "text"]

        prompt_1_formatted = prompt_raw_1.format(text)

        try:
            response_1 = generate_response(prompt_1_formatted)
            response_1 = response_1.lstrip()
    
            prompt_2_formatted = prompt_raw_2.format(length, title, response_1)
            response_2 = generate_response(prompt_2_formatted)
        except:
            continue
            
        response = response_2.lstrip()
    
        rows.append({
            "title": title, 
            "prompt_1": prompt_1_formatted, 
            "response": response_1,
            "prompt_2": prompt_2_formatted, 
            "text": response, 
            "model": model_name
        })

        print_progress(start, i, n)
    
    return pd.DataFrame(rows)

# %%
prompt_1 = """
Identify the writing style and format of the text, excluding all semantic content and themes.

Text:
{}
"""

prompt_2 = """
Write an essay of about {} words on the topic '{}'.

You are given the following style-and-format description:
'{}'

Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
Output only the essay text.
"""

# %%
df4 = generate_with_content(MODEL, df, prompt_1, prompt_2, start=START, n=OUT_COUNT)
df4.head()
# Out:
# 0.0% done
# 1.0% done
# 2.0% done
# 3.0% done
# 4.0% done
# 5.0% done
# 6.0% done
# 7.0% done
# 8.0% done
# 9.0% done
# 10.0% done
# 11.0% done
# 12.0% done
# 13.0% done
# 14.0% done
# 15.0% done
# 16.0% done
# 17.0% done
# 18.0% done
# 19.0% done
# 20.0% done
# 21.0% done
# 22.0% done
# 23.0% done
# 24.0% done
# 25.0% done
# 26.0% done
# 27.0% done
# 28.0% done
# 29.0% done
# 30.0% done
# 31.0% done
# 32.0% done
# 33.0% done
# 34.0% done
# 35.0% done
# 36.0% done
# 37.0% done
# 38.0% done
# 39.0% done
# 40.0% done
# 41.0% done
# 42.0% done
# 43.0% done
# 44.0% done
# 45.0% done
# 46.0% done
# 47.0% done
# 48.0% done
# 49.0% done
# 50.0% done
# 51.0% done
# 52.0% done
# 53.0% done
# 54.0% done
# 55.0% done
# 56.0% done
# 57.0% done
# 58.0% done
# 59.0% done
# 60.0% done
# 61.0% done
# 62.0% done
# 63.0% done
# 64.0% done
# 65.0% done
# 66.0% done
# 67.0% done
# 68.0% done
# 69.0% done
# 70.0% done
# 71.0% done
# 72.0% done
# 73.0% done
# 74.0% done
# 75.0% done
# 76.0% done
# 77.0% done
# 78.0% done
# 79.0% done
# 80.0% done
# 81.0% done
# 82.0% done
# 83.0% done
# 84.0% done
# 85.0% done
# 86.0% done
# 87.0% done
# 88.0% done
# 89.0% done
# 90.0% done
# 91.0% done
# 92.0% done
# 93.0% done
# 94.0% done
# 95.0% done
# 96.0% done
# 97.0% done
# 98.0% done
# 99.0% done
#                                                title  \
# 0  Mulan Disney Film Directed by Bancroft & Cook ...
# 1      Multicultural Food Marketing Techniques Essay
# 2       Multiculturalism: Why Is It Important? Essay
# 3             Multimedia and Sports Journalism Essay
# 4  Multimedia Learning During Art and Design Less...
#
#                                             prompt_1  \
# 0  \nIdentify the writing style and format of the...
# 1  \nIdentify the writing style and format of the...
# 2  \nIdentify the writing style and format of the...
# 3  \nIdentify the writing style and format of the...
# 4  \nIdentify the writing style and format of the...
#
#                                             response  \
# 0  Based on the provided text, the writing style ...
# 1  **Writing Style and Format Analysis**\n\n**Wri...
# 2  Based on a formal analysis of the text's struc...
# 3  Based solely on structural and formal characte...
# 4  **Writing Style and Format Analysis**\n\n**Sty...
#
#                                             prompt_2  \
# 0  \nWrite an essay of about 300 words on the top...
# 1  \nWrite an essay of about 700 words on the top...
# 2  \nWrite an essay of about 900 words on the top...
# 3  \nWrite an essay of about 300 words on the top...
# 4  \nWrite an essay of about 900 words on the top...
#
#                                                 text          model
# 0  The 1998 animated film *Mulan*, directed by To...  deepseek-chat
# 1  The globalized marketplace has rendered multic...  deepseek-chat
# 2  In an era defined by unprecedented global inte...  deepseek-chat
# 3  The evolution of multimedia has fundamentally ...  deepseek-chat
# 4  The impetus for this research project stems fr...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df4, EXAMPLE_ID)
# Out:
# Prompt 1 =============================================================================================
#
# Identify the writing style and format of the text, excluding all semantic content and themes.
#
# Text:
# One of the most popular Disney movies to date, Bankroft’s Mulan, which was released in 1998, presents a captivating story in a unique setting. In their work, the writers challenge the very norms of society to present a highly charismatic set of characters. In this essay, the changes in Mulan’s identity as a woman that are shown to the audience in the first part of the movie will be discussed.
#
# From the very beginning, it becomes clear that the gender roles in the movie are expected to be strictly upheld within society. The norms of the ancient Chinese community are clearly shown from the first minutes of the movie, as Mulan is being prepared to be wed (Bancroft & Cook, 1998, 0:6:30). Her role as a woman is to bring honor to her family (Bancroft & Cook, 1998, 0:6:57). Although she initially attempts to fit in, this setup is only an obstacle in Mulan’s path to the future she herself decides to choose.
#
# The rejection Mulan receives is a critical point for her character. She understands that she will never succeed at the path that is not her own (Bancroft & Cook, 1998, 0:12:05). However, choosing one’s fate as a woman of that era is a nigh-impossible task. Honor is what pushes Mulan to make a decision to challenge the otherwise predefined role that was set for her and take her father’s place in the army.
#
# In conclusion, Mulan experiences a shocking revelation that she will not succeed as a woman in this community, making her rethink the very meaning of honor on which her goal was set. She decides to choose her role herself, showing immense strength of character, care, and true devotion for her family. In this strictly hierarchical setting, Mulan’s actions are a challenge to the very foundation of society.
#
# Reference
#
# Bancroft, T., & Cook, B. (Directors). (1998). Mulan . Disney.
#
#
# ====================================================================================================
# Based on the provided text, the writing style and format are as follows:
#
# **Writing Style:**
# *   **Academic/Formal:** The tone is objective, analytical, and avoids casual language.
# *   **Expository:** The primary purpose is to explain, analyze, and interpret a subject (the film *Mulan*).
# *   **Argumentative/Thesis-Driven:** The text is structured around a central claim (thesis) regarding Mulan's changing identity and her challenge to societal norms, which it seeks to support with evidence.
# *   **Third-Person Perspective:** The writer uses "the audience," "the writers," and "Mulan," maintaining an impersonal and scholarly point of view.
#
# **Format:**
# *   **Academic Essay Structure:** The text follows a conventional essay format.
#     *   **Introduction:** The first paragraph introduces the subject, provides context, and presents the specific thesis or focus of the essay.
#     *   **Body Paragraphs:** Subsequent paragraphs develop the argument. Each begins with a topic sentence, presents evidence (in this case, film timestamps as citations), and provides analysis.
#     *   **Conclusion:** The final paragraph summarizes the main argument and reinforces the thesis without introducing new evidence.
# *   **Citation Style (APA):** The in-text citations (Bancroft & Cook, 1998, timestamp) and the reference list entry follow the author-date and formatting conventions of the American Psychological Association (APA) style, adapted for film analysis with timestamps.
# *   **Formal Referencing:** The inclusion of a "Reference" section at the end confirms a structured, academic approach to sourcing.
# Prompt 2 =============================================================================================
#
# Write an essay of about 300 words on the topic 'Mulan Disney Film Directed by Bancroft & Cook Essay'.
#
# You are given the following style-and-format description:
# 'Based on the provided text, the writing style and format are as follows:
#
# **Writing Style:**
# *   **Academic/Formal:** The tone is objective, analytical, and avoids casual language.
# *   **Expository:** The primary purpose is to explain, analyze, and interpret a subject (the film *Mulan*).
# *   **Argumentative/Thesis-Driven:** The text is structured around a central claim (thesis) regarding Mulan's changing identity and her challenge to societal norms, which it seeks to support with evidence.
# *   **Third-Person Perspective:** The writer uses "the audience," "the writers," and "Mulan," maintaining an impersonal and scholarly point of view.
#
# **Format:**
# *   **Academic Essay Structure:** The text follows a conventional essay format.
#     *   **Introduction:** The first paragraph introduces the subject, provides context, and presents the specific thesis or focus of the essay.
#     *   **Body Paragraphs:** Subsequent paragraphs develop the argument. Each begins with a topic sentence, presents evidence (in this case, film timestamps as citations), and provides analysis.
#     *   **Conclusion:** The final paragraph summarizes the main argument and reinforces the thesis without introducing new evidence.
# *   **Citation Style (APA):** The in-text citations (Bancroft & Cook, 1998, timestamp) and the reference list entry follow the author-date and formatting conventions of the American Psychological Association (APA) style, adapted for film analysis with timestamps.
# *   **Formal Referencing:** The inclusion of a "Reference" section at the end confirms a structured, academic approach to sourcing.'
#
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
#
# ====================================================================================================
# Mulan Disney Film Directed by Bancroft & Cook Essay
#
# The 1998 animated film *Mulan*, directed by Tony Bancroft and Barry Cook, transcends its surface narrative of a young woman disguising herself as a soldier to explore a profound journey of self-actualization. While the plot is driven by the external conflict of the Hun invasion, the film’s core argument centers on the protagonist’s internal struggle to reconcile her authentic identity with rigid societal expectations. Ultimately, *Mulan* posits that true honor and strength are derived not from blind conformity to prescribed gender roles, but from the courage to define oneself, thereby challenging and ultimately transforming the very norms that sought to constrain her.
#
# Mulan’s initial identity is defined entirely by the patriarchal society of imperial China, which values women solely as brides who bring honor through obedience and appearance. Her failure at the Matchmaker’s ceremony, culminating in the declaration that she will “never bring her family honor” (Bancroft & Cook, 1998, 00:12:15), visually and narratively establishes the conflict between her innate qualities—intelligence, ingenuity, and spirit—and the passive, decorative role she is expected to perform. This failure catalyzes her radical decision to take her father’s place in the army, an act that is simultaneously dishonorable in its deception yet deeply filial in its motivation to protect her family.
#
# The persona of “Ping” allows Mulan to cultivate the strengths society denied her female identity. Her success is not achieved through masculine brute force but through the application of her unique intellect and resilience, as demonstrated when she uses ingenuity to retrieve the arrow from the pole (Bancroft & Cook, 1998, 00:42:30). The climactic confrontation with Shan Yu further solidifies this thesis. Mulan defeats the Hun leader not with a soldier’s sword, but with a combination of the very “feminine” tool of a fan and the strategic mind she has always possessed (Bancroft & Cook, 1998, 01:15:10). Her victory is a synthesis, not a rejection, of her complete self.
#
# In conclusion, *Mulan* presents a narrative arc where personal authenticity triumphs over social prescription. By saving China using the unique qualities she was once punished for, Mulan redefines the concept of honor for herself, her family, and her empire. The film’s resolution, where the Emperor bows to her and her family receives the accolades of the nation, signifies a societal recognition that the greatest strength lies in the courage to be one’s true self, thereby offering a powerful critique of rigid gender binaries.
#
# **Reference**
#
# Bancroft, T. (Director), & Cook, B. (Director). (1998). *Mulan* [Film]. Walt Disney Pictures.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_4.csv"

df4.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 5. Outline‑guided Text Generation
#
# Первый промпт:
# ```
# You are an academic writing instructor.
# Create a well-structured outline for an academic essay on the following topic: {}.
#
# Requirements:
#
# The outline must include the following sections:
# - Introduction
# - Main Body (2–4 thematic sections)
# - Counterarguments / Alternative Perspectives
# - Conclusion
#
# Each section should contain 2–3 concise bullet points describing the key ideas or arguments.
# The outline should reflect a clear thesis-driven structure.
# Use formal academic language.
#
# Do not write the essay itself
# ```
#
# Второй промпт:
# ```
# You are an academic essay writer.
# Write a coherent academic essay of about {} words on the topic '{}' strictly following the outline below.
#
# Outline:
# {}
#
# Requirements:
# - Follow the outline in the given order without adding or removing sections.
# - Develop each bullet point into a full, well-argued paragraph.
# - Maintain a formal academic tone and clear argumentative logic.
# - Use appropriate academic transitions and signposting.
# - Do not introduce new arguments or themes not present in the outline.
# - Avoid informal language, personal anecdotes, and unsupported claims.
# ```

# %%
def generate_with_plan(model_name, df, prompt_raw_1, prompt_raw_2, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
        text = df.loc[i, "text"]
    
        prompt_1_formatted = prompt_raw_1.format(title)

        try:
            response_1 = generate_response(prompt_1_formatted)
            response_1 = response_1.lstrip()
    
            prompt_2_formatted = prompt_raw_2.format(length, title, response_1)
            response_2 = generate_response(prompt_2_formatted)
        except:
            continue
            
        response = response_2.lstrip()
    
        rows.append({
            "title": title, 
            "prompt_1": prompt_1_formatted, 
            "response": response_1,
            "prompt_2": prompt_2_formatted, 
            "text": response, 
            "model": model_name
        })

        print_progress(start, i, n)
    
    return pd.DataFrame(rows)

# %%
prompt_1 = """
You are an academic writing instructor.
Create a well-structured outline for an academic essay on the following topic: {}.

Requirements:

The outline must include the following sections:
- Introduction
- Main Body (2–4 thematic sections)
- Counterarguments / Alternative Perspectives
- Conclusion

Each section should contain 2–3 concise bullet points describing the key ideas or arguments.
The outline should reflect a clear thesis-driven structure.
Use formal academic language.

Do not write the essay itself
"""

prompt_2 = """
You are an academic essay writer.
Write a coherent academic essay of about {} words on the topic '{}' strictly following the outline below.

Outline:
{}

Requirements:
- Follow the outline in the given order without adding or removing sections.
- Develop each bullet point into a full, well-argued paragraph.
- Maintain a formal academic tone and clear argumentative logic.
- Use appropriate academic transitions and signposting.
- Do not introduce new arguments or themes not present in the outline.
- Avoid informal language, personal anecdotes, and unsupported claims.
"""

# %%
df5 = generate_with_plan(MODEL, df, prompt_1, prompt_2, start=START, n=OUT_COUNT)
df5.head()
# Out:
# 0.0% done
# 1.0% done
# 2.0% done
# 3.0% done
# 4.0% done
# 5.0% done
# 6.0% done
# 7.0% done
# 8.0% done
# 9.0% done
# 10.0% done
# 11.0% done
# 12.0% done
# 13.0% done
# 14.0% done
# 15.0% done
# 16.0% done
# 17.0% done
# 18.0% done
# 19.0% done
# 20.0% done
# 21.0% done
# 22.0% done
# 23.0% done
# 24.0% done
# 25.0% done
# 26.0% done
# 27.0% done
# 28.0% done
# 29.0% done
# 30.0% done
# 31.0% done
# 32.0% done
# 33.0% done
# 34.0% done
# 35.0% done
# 36.0% done
# 37.0% done
# 38.0% done
# 39.0% done
# 40.0% done
# 41.0% done
# 42.0% done
# 43.0% done
# 44.0% done
# 45.0% done
# 46.0% done
# 47.0% done
# 48.0% done
# 49.0% done
# 50.0% done
# 51.0% done
# 52.0% done
# 53.0% done
# 54.0% done
# 55.0% done
# 56.0% done
# 57.0% done
# 58.0% done
# 59.0% done
# 60.0% done
# 61.0% done
# 62.0% done
# 63.0% done
# 64.0% done
# 65.0% done
# 66.0% done
# 67.0% done
# 68.0% done
# 69.0% done
# 70.0% done
# 71.0% done
# 72.0% done
# 73.0% done
# 74.0% done
# 75.0% done
# 76.0% done
# 77.0% done
# 78.0% done
# 79.0% done
# 80.0% done
# 81.0% done
# 82.0% done
# 83.0% done
# 84.0% done
# 85.0% done
# 86.0% done
# 87.0% done
# 88.0% done
# 89.0% done
# 90.0% done
# 91.0% done
# 92.0% done
# 93.0% done
# 94.0% done
# 95.0% done
# 96.0% done
# 97.0% done
# 98.0% done
# 99.0% done
#                                                title  \
# 0  Mulan Disney Film Directed by Bancroft & Cook ...
# 1      Multicultural Food Marketing Techniques Essay
# 2       Multiculturalism: Why Is It Important? Essay
# 3             Multimedia and Sports Journalism Essay
# 4  Multimedia Learning During Art and Design Less...
#
#                                             prompt_1  \
# 0  \nYou are an academic writing instructor.\nCre...
# 1  \nYou are an academic writing instructor.\nCre...
# 2  \nYou are an academic writing instructor.\nCre...
# 3  \nYou are an academic writing instructor.\nCre...
# 4  \nYou are an academic writing instructor.\nCre...
#
#                                             response  \
# 0  **Academic Essay Outline: Re-examining Gender ...
# 1  **Academic Essay Outline: Multicultural Food M...
# 2  **Essay Outline: The Imperative of Multicultur...
# 3  **Academic Essay Outline: The Evolution and Im...
# 4  **Outline for a Research Paper: The Efficacy o...
#
#                                             prompt_2  \
# 0  \nYou are an academic essay writer.\nWrite a c...
# 1  \nYou are an academic essay writer.\nWrite a c...
# 2  \nYou are an academic essay writer.\nWrite a c...
# 3  \nYou are an academic essay writer.\nWrite a c...
# 4  \nYou are an academic essay writer.\nWrite a c...
#
#                                                 text          model
# 0  Disney’s *Mulan* (1998), directed by Tony Banc...  deepseek-chat
# 1  ### **Multicultural Food Marketing Techniques*...  deepseek-chat
# 2  **The Imperative of Multiculturalism in the 21...  deepseek-chat
# 3  **The Evolution and Impact of Multimedia in Sp...  deepseek-chat
# 4  **The Efficacy of Multimedia Learning in Art a...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df5, EXAMPLE_ID)
# Out:
# Prompt 1 =============================================================================================
#
# You are an academic writing instructor.
# Create a well-structured outline for an academic essay on the following topic: Mulan Disney Film Directed by Bancroft & Cook Essay.
#
# Requirements:
#
# The outline must include the following sections:
# - Introduction
# - Main Body (2–4 thematic sections)
# - Counterarguments / Alternative Perspectives
# - Conclusion
#
# Each section should contain 2–3 concise bullet points describing the key ideas or arguments.
# The outline should reflect a clear thesis-driven structure.
# Use formal academic language.
#
# Do not write the essay itself
#
# ====================================================================================================
# **Academic Essay Outline: Re-examining Gender and Cultural Representation in Disney’s *Mulan* (1998, Bancroft & Cook)**
#
# **Thesis Statement:** While Disney’s *Mulan* (1998) is often celebrated as a progressive narrative challenging gender norms, a critical analysis reveals that its feminist and cultural politics are ultimately constrained by the film’s commercial imperatives and Western ideological frameworks, resulting in a narrative that appropriates and simplifies Chinese cultural elements to promote an individualistic, assimilationist model of empowerment.
#
# **I. Introduction**
# *   Establish the film’s cultural significance as a landmark Disney text that ostensibly breaks from the "princess" paradigm to engage with themes of gender performativity and filial duty.
# *   Present the central thesis: the film’s progressive surface masks a complex negotiation between subversive potential and conventional Disney formula, particularly in its treatment of gender and cultural authenticity.
# *   Provide a roadmap for the essay, outlining the analysis of gender construction, cultural representation, and the film’s commercial compromises.
#
# **II. Main Body: Section A – Deconstructing and Reinscribing Gender Norms**
# *   Analyze the subversive elements of Mulan’s cross-dressing and military success as a critique of rigid gender roles, using the performative acts of "being a man" to expose their constructed nature.
# *   Argue that this subversion is contained by the narrative’s conclusion, which re-domesticates Mulan through the romantic plot with Shang and her return to the family, ultimately validating her within a heteronormative framework despite her heroism.
#
# **III. Main Body: Section B – Cultural Authenticity vs. Western Appropriation**
# *   Examine the film’s use of Chinese iconography (the Great Wall, ancestors, dragons, etc.) as a stylized aesthetic backdrop that creates a sense of "authenticity" for a Western audience.
# *   Critique the simplification and distortion of core Confucian values, such as *filial piety* and *collective honor*, reshaping them into a narrative of individual self-discovery and rebellion more palatable to Western individualism.
#
# **IV. Counterarguments / Alternative Perspectives**
# *   Acknowledge the persuasive counterargument that the film, as a mainstream animated feature, successfully introduced positive themes of female agency and Chinese culture to a global audience, fostering cross-cultural understanding.
# *   Consider the alternative perspective that the character of Mulan, as a Disney heroine, represents meaningful progress within the studio’s canon, providing a role model whose primary goal extends beyond romantic marriage.
#
# **V. Conclusion**
# *   Synthesize the analysis to reaffirm that *Mulan* operates as an ambivalent text, simultaneously challenging and conforming to dominant ideologies.
# *   Conclude that the film’s lasting impact lies in this very tension, making it a rich subject for analyzing how popular culture negotiates gender and cross-cultural representation in a global marketplace.
# *   Suggest implications for contemporary discourse on authentic storytelling and the responsibilities of cultural production in an era of remakes and globalized media.
# Prompt 2 =============================================================================================
#
# You are an academic essay writer.
# Write a coherent academic essay of about 300 words on the topic 'Mulan Disney Film Directed by Bancroft & Cook Essay' strictly following the outline below.
#
# Outline:
# **Academic Essay Outline: Re-examining Gender and Cultural Representation in Disney’s *Mulan* (1998, Bancroft & Cook)**
#
# **Thesis Statement:** While Disney’s *Mulan* (1998) is often celebrated as a progressive narrative challenging gender norms, a critical analysis reveals that its feminist and cultural politics are ultimately constrained by the film’s commercial imperatives and Western ideological frameworks, resulting in a narrative that appropriates and simplifies Chinese cultural elements to promote an individualistic, assimilationist model of empowerment.
#
# **I. Introduction**
# *   Establish the film’s cultural significance as a landmark Disney text that ostensibly breaks from the "princess" paradigm to engage with themes of gender performativity and filial duty.
# *   Present the central thesis: the film’s progressive surface masks a complex negotiation between subversive potential and conventional Disney formula, particularly in its treatment of gender and cultural authenticity.
# *   Provide a roadmap for the essay, outlining the analysis of gender construction, cultural representation, and the film’s commercial compromises.
#
# **II. Main Body: Section A – Deconstructing and Reinscribing Gender Norms**
# *   Analyze the subversive elements of Mulan’s cross-dressing and military success as a critique of rigid gender roles, using the performative acts of "being a man" to expose their constructed nature.
# *   Argue that this subversion is contained by the narrative’s conclusion, which re-domesticates Mulan through the romantic plot with Shang and her return to the family, ultimately validating her within a heteronormative framework despite her heroism.
#
# **III. Main Body: Section B – Cultural Authenticity vs. Western Appropriation**
# *   Examine the film’s use of Chinese iconography (the Great Wall, ancestors, dragons, etc.) as a stylized aesthetic backdrop that creates a sense of "authenticity" for a Western audience.
# *   Critique the simplification and distortion of core Confucian values, such as *filial piety* and *collective honor*, reshaping them into a narrative of individual self-discovery and rebellion more palatable to Western individualism.
#
# **IV. Counterarguments / Alternative Perspectives**
# *   Acknowledge the persuasive counterargument that the film, as a mainstream animated feature, successfully introduced positive themes of female agency and Chinese culture to a global audience, fostering cross-cultural understanding.
# *   Consider the alternative perspective that the character of Mulan, as a Disney heroine, represents meaningful progress within the studio’s canon, providing a role model whose primary goal extends beyond romantic marriage.
#
# **V. Conclusion**
# *   Synthesize the analysis to reaffirm that *Mulan* operates as an ambivalent text, simultaneously challenging and conforming to dominant ideologies.
# *   Conclude that the film’s lasting impact lies in this very tension, making it a rich subject for analyzing how popular culture negotiates gender and cross-cultural representation in a global marketplace.
# *   Suggest implications for contemporary discourse on authentic storytelling and the responsibilities of cultural production in an era of remakes and globalized media.
#
# Requirements:
# - Follow the outline in the given order without adding or removing sections.
# - Develop each bullet point into a full, well-argued paragraph.
# - Maintain a formal academic tone and clear argumentative logic.
# - Use appropriate academic transitions and signposting.
# - Do not introduce new arguments or themes not present in the outline.
# - Avoid informal language, personal anecdotes, and unsupported claims.
#
# ====================================================================================================
# Mulan Disney Film Directed by Bancroft & Cook Essay
#
# Disney’s *Mulan* (1998), directed by Tony Bancroft and Barry Cook, stands as a culturally significant text within the studio’s canon, ostensibly breaking from the traditional “princess” paradigm to engage with themes of gender performativity and filial duty. However, a critical examination reveals that its celebrated progressive surface masks a complex negotiation between subversive potential and conventional Disney formula. This essay argues that while *Mulan* challenges certain gender norms, its feminist and cultural politics are ultimately constrained by commercial imperatives and Western ideological frameworks, resulting in a narrative that appropriates Chinese culture to promote an individualistic model of empowerment. The analysis will proceed by deconstructing the film’s treatment of gender, critiquing its cultural representations, and acknowledging its commercial compromises.
#
# The film’s most potent subversion lies in its deconstruction of rigid gender roles through Mulan’s cross-dressing and military success. Her performative acts of “being a man” expose gender as a constructed identity, challenging the essentialist notions presented in “Make a Man Out of You.” Yet, this subversion is narratively contained. The conclusion re-domesticates Mulan through the romantic plot with Captain Shang and her celebrated return to the family hearth. Ultimately, her heroism is validated within a heteronormative framework, subtly reinscribing the very norms her journey initially disrupted.
#
# Regarding cultural representation, the film employs Chinese iconography—the Great Wall, ancestral spirits, and a dragon—as a stylized aesthetic backdrop that manufactures a sense of “authenticity” for Western audiences. More critically, it simplifies and distorts core Confucian values. The profound concepts of *filial piety* and collective familial honor are reshaped into a narrative of individual self-discovery and rebellion against tradition, a theme more palatable to Western individualism than a genuine engagement with Chinese philosophical complexity.
#
# Counterarguments rightly note the film’s positive role as a mainstream conduit for themes of female agency and Chinese culture, fostering cross-cultural understanding for a global audience. Furthermore, within the Disney canon, Mulan undeniably represents meaningful progress, offering a heroine whose primary arc extends beyond securing a romantic marriage to encompass familial salvation and personal integrity.
#
# In conclusion, *Mulan* operates as an profoundly ambivalent text, simultaneously challenging and conforming to dominant ideologies of gender and culture. Its lasting impact lies in this very tension, making it a rich subject for analyzing how popular culture negotiates representation within a global marketplace. This analysis suggests important implications for contemporary discourse, highlighting the ongoing responsibilities and challenges of authentic storytelling in an era of remakes and globalized media production.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_5.csv"

df5.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)
