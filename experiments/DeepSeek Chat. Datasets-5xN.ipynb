# %% [markdown]
# # Генерация датасетов моделью DeepSeek Chat

# %%
EXAMPLE_ID = 0
MODEL = 'deepseek-chat'
START = 0
OUT_COUNT = 1000
OUT_FILE_PREFIX = 'deepseek_essays'
PAUSE_SECONDS = 1

# %% [markdown]
# ### Исходный датасет, написанный человеком

# %%
import pandas as pd

df = pd.read_csv("../datasets/human_essays.csv", encoding="utf-8")
df.head(10)
# Out:
#                                                title  \
# 0    12 Years a Slave: An Analysis of the Film Essay
# 1  20+ Social Media Post Ideas to Radically Simpl...
# 2  533 U.S. 27 (2001) Kyllo v. United States: The...
# 3            A Charles Schwab Corporation Case Essay
# 4  A Clinical Office Assistant’s Attire Research ...
# 5  A Comic Science Fiction Film “Back to the Futu...
# 6   A Community Yard Sale as a Memorable Event Essay
# 7  A Complex in the “Every Secret Thing” Film by ...
# 8  A Customer Told to Wear a Mask Threw Snow at a...
# 9  A Disconnect Between Public Transportation and...
#
#                                                 text
# 0  The 2013 film 12 Years a Slave proved that sla...
# 1  Social Media Examiner’s (2021) video on social...
# 2  Table of Contents\n 1. Facts\n 2. Issue\n 3. H...
# 3  Charles Schwab is a for-profit Corporation who...
# 4  The work of a clinical or medical office worke...
# 5  Table of Contents\n 1. Introduction\n 2. Movie...
# 6  Autumn is not generally viewed as an appropria...
# 7  Carl Jung identifies the mother complex with a...
# 8  The article describes a recent Chicago hot dog...
# 9  One realistic way to commute is using private ...

# %% [markdown]
# #### Пример:

# %%
print(f"{df.iloc[EXAMPLE_ID,0]}\n\n{df.iloc[EXAMPLE_ID,1]}")
# Out:
# 12 Years a Slave: An Analysis of the Film Essay
#
# The 2013 film 12 Years a Slave proved that slavery is a worldwide issue. Indeed, the film made $150 million outside the United States and $57 million in the U.S., with a production budget of $20 million (Sharf, 2020). The movie was based on the memoir Twelve Years a Slave by Solomon Northup (Ntim, 2020). It tells the story of a free African American man who was kidnapped and sold into slavery. Solomon spent twelve years away from his family, being traded from one master to another. Fortunately, the protagonist met a person who helped him deliver a message to his family and friends, who came and rescued him. This movie accurately illustrates discriminatory relationships between white slaveholders and black slaves that stemmed from the dysfunctional system in the country and prejudices in people’s mindsets at that time.
#
# The two main ethnic groups presented in this film are White and African Americans, and the three social groups are affluent slaveholders, working for middle class, and enslaved people. The movie starts with the story of a free African American violinist Solomon Northup, living with his family in Saratoga, New York (McQueen, 2013). However, he was abducted by two white men, who tortured the man and sold him into slavery, changing his name to Plat. Before they met, Solomon and these two slave traders belonged to the same middle class. However, the fact that Northup was an African American made these individuals believe that they had the right to withdraw their freedom. The two masters that Solomon had were William Ford and Edwin Epps (McQueen, 2013). The former was kind and religious, while the latter was cruel and sadistic. Since the movie was based on a real story, it indicated that slaveholders had different characters, but all had the wrong perception of race.
#
# Although 12 Years a Slave is a film about slavery, the issues of collectivism and individualism are also raised. Specifically, the main character never identified himself as an enslaved man and continued claiming he was a free citizen (McQueen, 2013). However, his counterparts on the plant had a collective mindset, imprinted in them since childhood, that slavery is normal. These people helped each other because they belonged to the same group. Although Solomon tried to become a part of this community, his individual goal to return home was above the collective values.
#
# The movie also showed prejudice, generalizations, stereotyping, and discrimination against black people. For instance, when Ford brings Solomon and Elisa to his plantation, his wife expresses her sadness that Elisa got separated from her children. However, she also stated that “something to eat and some rest” could help that woman forget her children (McQueen, 2013, 32:47-32:51). This scene demonstrated the common prejudice about slaves that they were not capable of the same feelings as white people. An example of generalization and stereotyping was how Tibeats, a carpenter, became hostile to Solomon when he showed his intelligence and gave Ford advice. In fact, Tibeats believed that Plat would never be more competent than any white individual because Plat was a “nigger” (McQueen, 2013, 36:35-36:37). Notably, before Northup became enslaved, he never experienced discrimination, but when the main character was sold into slavery, discrimination was the only attitude that he could observe.
#
# In summary, 12 Years a Slave depicts the life of enslaved people and slave owners almost two centuries ago. The film narrates a free black man’s life from the moment when he enjoyed his family’s company in the state of New York to his abduction, enslavement, and eventual liberation. Overall, the movie raised such critical issues as discrimination, prejudice, stereotyping, and generalization that allowed slaveholders to maintain this societal structure for a long time.
#
# References
#
# McQueen, S. (2013). 12 years a slave [Film]. New Regency Productions.
#
# Ntim, Z. (2020). Steve McQueen says it took 11 years to create his new anthology “Small Axe” and reveals why producers almost pulled out of his Oscar-winning film “12 Years a Slave.” Insider.
#
# Sharf, Z. (2020). Steve McQueen recalls producers rejecting “12 Years a Slave” over false beliefs about black films. Indie Wire.

# %% [markdown]
# ### Утилиты

# %%
import math
import re


def round_word_count(c):
    return math.floor(c / 100) * 100

def word_count(text):
    words = re.findall(r'\b\w+\b', text)
    return round_word_count(len(words))

def print_example(data, example_id):
    if 'prompt' in data.iloc[example_id]:
        print(f"Prompt {'=' * 93}\n{data.iloc[example_id]['prompt']}")
        print(f"{'=' * 100}")
        print(f"{data.iloc[example_id]['title']}\n\n{data.iloc[example_id]['text']}")
        print(f"{'=' * 100}")
    if 'prompt_2' in data.iloc[example_id]:
        print(f"Prompt 1 {'=' * 93}\n{data.iloc[example_id]['prompt_1']}")
        print(f"{'=' * 100}")
        print(f"{data.iloc[example_id]['response']}")
        print(f"Prompt 2 {'=' * 93}\n{data.iloc[example_id]['prompt_2']}")
        print(f"{'=' * 100}")
        print(f"{data.iloc[example_id]['title']}\n\n{data.iloc[example_id]['text']}")
        print(f"{'=' * 100}")

# %%
from dotenv import load_dotenv
import os
from openai import OpenAI


load_dotenv()

client = OpenAI(api_key=os.getenv("DEEPSEEK_API_KEY"), base_url="https://api.deepseek.com")

# %%
import time


def generate_response(prompt):
    response = client.chat.completions.create(
        model=MODEL,
        messages=[
            {
                "role": "system",
                "content": "You are an expert academic essay writer. You produce well-structured, logical, and substantive essays with clear argumentation, proper citations, and academic rigor."
            },
            {
                "role": "user",
                "content": prompt
            }
        ],
        stream=False
    )

    time.sleep(PAUSE_SECONDS)
    
    return response.choices[0].message.content

# %% [markdown]
# ### Вариант 1. Prompt-based generation
#
# ```
# Write an essay of about {} words on the topic '{}'.
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
# ```

# %%
def generate(model_name, df, prompt_raw, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
    
        prompt_formatted = prompt_raw.format(length, title)

        try:
            response = generate_response(prompt_formatted)
        except:
            print('ops!')
            continue
            
        response = response.lstrip()
    
        rows.append({"title": title, "prompt": prompt_formatted, "text": response, "model": model_name})

        if i % (n / 100) == 0:
            print(f"{100 * i / n}% done")
    
    return pd.DataFrame(rows)

# %%
prompt = """
Write an essay of about {} words on the topic '{}'.
Start directly with the first sentence of the essay. Absolutely no title or heading of any kind. 
Output only the essay text. 
"""

df1 = generate(MODEL, df, prompt, start=START, n=OUT_COUNT)
df1.head()
# Out:
# 0.0% done
#                                              title  \
# 0  12 Years a Slave: An Analysis of the Film Essay
#
#                                               prompt  \
# 0  \nWrite an essay of about 600 words on the top...
#
#                                                 text          model
# 0  The cinematic adaptation of Solomon Northup’s ...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df1, EXAMPLE_ID)
# Out:
# Prompt =============================================================================================
#
# Write an essay of about 600 words on the topic '12 Years a Slave: An Analysis of the Film Essay'.
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
#
# ====================================================================================================
# 12 Years a Slave: An Analysis of the Film Essay
#
# The cinematic adaptation of Solomon Northup’s 1853 memoir, *12 Years a Slave*, directed by Steve McQueen, transcends the conventions of the historical drama to deliver a visceral and unflinching meditation on the institution of American slavery. Rather than offering a narrative of triumphant escape or redemptive violence, the film immerses the viewer in the brutal, mundane, and psychologically intricate reality of the “peculiar institution” through the specific lens of a free man forcibly enslaved. Its power lies not in allegory but in a stark, almost archaeological, reconstruction of a system designed to annihilate identity, community, and hope, making it a profound film essay on dehumanization, survival, and the corrupting nature of absolute power.
#
# Central to the film’s analytical framework is its methodological commitment to a relentless realism that refuses to look away. McQueen’s background in visual art is evident in composed, painterly shots that hold on scenes of suffering—most notably in the prolonged hanging of Solomon, his toes barely touching the mud, as daily life indifferently continues around him. This technique does not sensationalize pain but ritualizes it, forcing the audience to endure, in real time, the agonizing duration of Solomon’s torment. The sound design, often devoid of a manipulative score, amplifies the ambient horrors: the crack of the whip, the rustle of chains, the oppressive silence of complicity. This aesthetic choices collectively argue that slavery was not a backdrop for adventure but a totalizing environment where violence was systematic, intimate, and omnipresent. The film thus essays the physical and temporal experience of bondage in a way that historical texts alone cannot convey.
#
# The film further deconstructs slavery through its nuanced portrayal of psychology, particularly in the character of Solomon Northup himself. As portrayed by Chiwetel Ejiofor, Northup’s journey is one of internal conflict and strategic adaptation. His initial identity as a free man, a violinist, and a father is systematically attacked, leading to a perilous duality. He must conceal his literacy and intelligence to survive, performing the role of the placid, submissive slave while secretly nurturing the ember of his true self. This internal schism is the core of the film’s psychological analysis; it demonstrates how the system worked by compelling the enslaved to participate in their own subjugation for mere survival. The famous close-up of Solomon’s face, directly confronting the camera in a mixture of despair, defiance, and utter exhaustion, serves as the essay’s thesis statement on the human spirit under sustained assault.
#
# Moreover, *12 Years a Slave* functions as a sharp analysis of the economic and moral corruption underpinning the slave society. The plantation owners are not cartoonish villains but complex studies in hypocrisy and decay. William Ford, played by Benedict Cumberbatch, embodies the “benign” slaveholder, whose paternalistic kindness is revealed as a more insidious form of oppression, as it fails to challenge the fundamental injustice of the system and ultimately proves powerless. In stark contrast, Edwin Epps, portrayed with terrifying zeal by Michael Fassbender, represents the logical extreme of slaveholding ideology. Justifying his brutality with twisted biblical passages, Epps illustrates how absolute power corrupts absolutely, warping sexuality, religion, and basic humanity. His relationship with Patsey, the most tragic figure in the film, lays bare the intertwined exploitation of labor and body, showing slavery as a comprehensive regime of consumption.
#
# Ultimately, *12 Years a Slave* culminates not in a cathartic victory but in a somber, complicated return. Solomon’s rescue and reunion with his family are undercut by the haunting final image of his still-traumatized gaze. The film’s essayistic conclusion is that while an individual may be freed from chains, the psychological and moral scars inflicted by such a system are indelible, both for the enslaved and for the nation built upon their suffering. By refusing narrative comfort, McQueen’s film insists on a clear-eyed, painful engagement with history. It stands as a masterful cinematic essay, compelling its audience to witness, to understand, and to remember the precise mechanisms of dehumanization, arguing that true historical reckoning requires not just knowledge of events, but a felt experience of their human cost.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_1.csv"

df1.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 2. Prompt-based Style Transfer
#
# ```
# Write an essay of about {} words on the topic '{}', following the stylistic and structural conventions of IvyPanda essays.
#
# STYLE REQUIREMENTS (IvyPanda-like):
# 1. The tone must be academic, clear, neutral, and objective.
# 2. The essay should include background context, a clear analytical structure, and well-developed paragraphs.
# 3. Arguments must be supported with reasoning, concise explanations, and relevant examples.
# 4. The writing must be coherent, logically progressive, and easy to read.
# 5. Avoid emotional language or overly dramatic phrasing.
#
# STRUCTURE REQUIREMENTS:
# 1. Divide the essay into several sections, each starting with a plain-text subheading.
# 2. Subheadings must contain only letters and spaces — no punctuation, no symbols, and absolutely no Markdown formatting.
#    - This means: no asterisks, no bold, no italics, no underscores, no brackets.
#    - Subheadings must appear as plain text lines, e.g. Background Context
# 3. Each subheading must be on its own line with exactly one blank line before and after it.
# 4. No overall essay title — begin directly with the first subheading.
# 5. Output must be plain text only (no Markdown, no asterisks, no bold, no italics, no hashtags, no special formatting).
#
# OPTIONAL ELEMENTS:
# You may include a plain-text references section at the end if appropriate to the topic, but this is optional.
#
# Begin with the first subheading, then continue with the first paragraph.
# Output only the essay text.
# ```

# %%
def generate(model_name, df, prompt_raw, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
    
        prompt_formatted = prompt_raw.format(length, title)
    
        try:
            response = generate_response(prompt_formatted)
        except:
            print('ops!')
            continue
            
        response = response.lstrip()
    
        rows.append({"title": title, "prompt": prompt_formatted, "text": response, "model": model_name})

        if i % (n / 100) == 0:
            print(f"{100 * i / n}% done")
    
    return pd.DataFrame(rows)

# %%
prompt = """
Write an essay of about {} words on the topic '{}', following the stylistic and structural conventions of IvyPanda essays.

STYLE REQUIREMENTS (IvyPanda-like):
1. The tone must be academic, clear, neutral, and objective.
2. The essay should include background context, a clear analytical structure, and well-developed paragraphs.
3. Arguments must be supported with reasoning, concise explanations, and relevant examples.
4. The writing must be coherent, logically progressive, and easy to read.
5. Avoid emotional language or overly dramatic phrasing.

STRUCTURE REQUIREMENTS:
1. Divide the essay into several sections, each starting with a plain-text subheading.
2. Subheadings must contain only letters and spaces — no punctuation, no symbols, and absolutely no Markdown formatting.
   - This means: no asterisks, no bold, no italics, no underscores, no brackets.
   - Subheadings must appear as plain text lines, e.g. Background Context
3. Each subheading must be on its own line with exactly one blank line before and after it.
4. No overall essay title — begin directly with the first subheading.
5. Output must be plain text only (no Markdown, no asterisks, no bold, no italics, no hashtags, no special formatting).

OPTIONAL ELEMENTS:
You may include a plain-text references section at the end if appropriate to the topic, but this is optional.

Begin with the first subheading, then continue with the first paragraph.
Output only the essay text.
"""

df2 = generate(MODEL, df, prompt, start=START, n=OUT_COUNT)
df2.head()
# Out:
# 0.0% done
#                                              title  \
# 0  12 Years a Slave: An Analysis of the Film Essay
#
#                                               prompt  \
# 0  \nWrite an essay of about 600 words on the top...
#
#                                                 text          model
# 0  Background Context\n\nThe 2013 film *12 Years ...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df2, EXAMPLE_ID)
# Out:
# Prompt =============================================================================================
#
# Write an essay of about 600 words on the topic '12 Years a Slave: An Analysis of the Film Essay', following the stylistic and structural conventions of IvyPanda essays.
#
# STYLE REQUIREMENTS (IvyPanda-like):
# 1. The tone must be academic, clear, neutral, and objective.
# 2. The essay should include background context, a clear analytical structure, and well-developed paragraphs.
# 3. Arguments must be supported with reasoning, concise explanations, and relevant examples.
# 4. The writing must be coherent, logically progressive, and easy to read.
# 5. Avoid emotional language or overly dramatic phrasing.
#
# STRUCTURE REQUIREMENTS:
# 1. Divide the essay into several sections, each starting with a plain-text subheading.
# 2. Subheadings must contain only letters and spaces — no punctuation, no symbols, and absolutely no Markdown formatting.
#    - This means: no asterisks, no bold, no italics, no underscores, no brackets.
#    - Subheadings must appear as plain text lines, e.g. Background Context
# 3. Each subheading must be on its own line with exactly one blank line before and after it.
# 4. No overall essay title — begin directly with the first subheading.
# 5. Output must be plain text only (no Markdown, no asterisks, no bold, no italics, no hashtags, no special formatting).
#
# OPTIONAL ELEMENTS:
# You may include a plain-text references section at the end if appropriate to the topic, but this is optional.
#
# Begin with the first subheading, then continue with the first paragraph.
# Output only the essay text.
#
# ====================================================================================================
# 12 Years a Slave: An Analysis of the Film Essay
#
# Background Context
#
# The 2013 film *12 Years a Slave*, directed by Steve McQueen and based on Solomon Northup’s 1853 memoir of the same name, stands as a seminal work in the cinematic portrayal of American slavery. Its critical and commercial success, including the Academy Award for Best Picture, stems not merely from its historical subject but from its unflinching formal and narrative approach. Unlike many historical dramas that offer a measure of catharsis or moral triumph, McQueen’s film immerses the viewer in the brutal, dehumanizing reality of the “peculiar institution” through the specific lens of a free man kidnapped into bondage. This essay argues that the film’s power derives from its deliberate aesthetic choices, its focus on the psychological trauma of slavery, and its subversion of traditional narrative expectations, thereby creating a profound meditation on identity, survival, and the systemic nature of oppression.
#
# Narrative Structure and Perspective
#
# The film’s narrative structure is foundational to its impact. By adhering closely to Northup’s first-person account, the story is filtered through the consciousness of an educated, free-born man suddenly subjected to the absolute power of slavery. This perspective is crucial. Solomon’s initial identity as a violinist, a husband, and a father in Saratoga, New York, establishes a baseline of humanity that the institution seeks to erase. The audience experiences the horror of his kidnapping and descent into slavery alongside him, making the procedural details of his enslavement—the beating, the transport, the renaming as “Platt”—all the more visceral. The narrative does not follow a traditional arc of heroic resistance but rather a protracted struggle for bare survival and the preservation of self. The twelve-year span emphasizes the grinding, relentless nature of the ordeal, where hope is a dangerous luxury and moments of potential escape are often met with crushing failure or betrayal.
#
# Aesthetic Choices and Symbolic Imagery
#
# Steve McQueen’s background as a visual artist is evident in the film’s composed, often painterly aesthetic, which contrasts starkly with its horrific content. Long, static takes force the viewer to endure scenes of violence and suffering without the relief of a cutaway, such as in the prolonged lynching scene where Solomon is left dangling from a tree, his toes barely touching the mud, while daily life indifferently continues around him. This technique refuses sensationalism and instead creates a space for contemplation of the atrocity. Similarly, the sound design oscillates between haunting silence and the diegetic sounds of nature, labor, and violence, emphasizing the isolation of the plantations. Recurring visual motifs, such as close-ups on characters’ faces—particularly Solomon’s, played with restrained intensity by Chiwetel Ejiofor—communicate interior states of despair, calculation, and fractured dignity where dialogue is insufficient or forbidden.
#
# Characterization and the System of Slavery
#
# The film meticulously portrays slavery not as the cruelty of isolated individuals but as a corrupting and systemic evil. The slave owners are not monolithic villains but are differentiated by their particular brands of hypocrisy and weakness. William Ford, played by Benedict Cumberbatch, is presented as a “kind” master whose benevolence is ultimately revealed as a self-serving fiction that does nothing to challenge the system; his religion is a tool of pacification. In contrast, Edwin Epps, portrayed by Michael Fassbender, embodies the system’s psychotic brutality and sexual predation, using scripture to justify his tyranny. The character of Patsey, masterfully acted by Lupita Nyong’o, becomes the ultimate symbol of the system’s total consumption of a person. Her exceptional labor and the perverse desire and jealousy she incites in Epps make her existence unbearable, highlighting the particular horrors inflicted upon enslaved women. Her plea to Solomon for death is one of the film’s most devastating moments, illustrating how the system could annihilate the will to live.
#
# Conclusion
#
# *12 Years a Slave* achieves its profound effect by rejecting the conventions of the redemptive historical drama. It offers no easy moral victories and provides only a bittersweet, deeply personal resolution. Solomon’s return to his family is a restoration of his legal freedom, but the final shots suggest a man permanently scarred, unable to fully re-enter the world he lost. The film’s legacy lies in its uncompromising commitment to presenting slavery as a lived, sensory experience of psychological and physical terror. By leveraging a distinct aesthetic rigor, a focused narrative perspective, and complex characterizations, McQueen creates a work that functions as both a historical document and a timeless examination of human resilience in the face of institutionalized evil. It forces a confrontation with the past that is essential for understanding the enduring contours of race and power in America.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_2.csv"

df2.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 3. Few-shot prompting
#
# ```
# You are a helpful writing assistant. Your task is to generate essays of a given length and topic.
# Start directly with the first sentence. No titles or headings. Output only the essay text.
#
# Here is an example:
#
# Example topic: "{}"
# Example length: {} words
#
# Example output:
# {}
#
# Now generate a new essay.
#
# Topic: "{}"
# Length: {} words
#
# Write the essay now.
# ```
#
# В качестве примера используется эссе из этого же набора, но на другую тему.

# %%
def generate_few_shot(model_name, df, prompt_raw, start=0, n=5000):
    rows = []
    for i in range(start + 1, start + n + 1):
        prev_title = df.loc[i - 1, "title"]
        prev_length = word_count(df.loc[i - 1, "text"])
        prev_text = df.loc[i - 1, "text"]
        
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
    
        prompt_formatted = prompt_raw.format(prev_title, prev_length, prev_text, title, length)

        try:
            response = generate_response(prompt_formatted)
        except:
            print('ops!')
            continue
            
        response = response.lstrip()
    
        rows.append({"title": title, "prompt": prompt_formatted, "text": response, "model": model_name})

        if i % (n / 100) == 0:
            print(f"{100 * i / n}% done")
    
    return pd.DataFrame(rows)

# %%
prompt = """
You are a helpful writing assistant. Your task is to generate essays of a given length and topic.
Start directly with the first sentence. No titles or headings. Output only the essay text.

Here is an example:

Example topic: "{}"
Example length: {} words

Example output:
{}

Now generate a new essay.

Topic: "{}"
Length: {} words

Write the essay now.
"""

df3 = generate_few_shot(MODEL, df, prompt, start=START, n=OUT_COUNT)
df3.head()
# Out:
#                                                title  \
# 0  20+ Social Media Post Ideas to Radically Simpl...
#
#                                               prompt  \
# 0  \nYou are a helpful writing assistant. Your ta...
#
#                                                 text          model
# 0  The digital marketing landscape is perpetually...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df3, EXAMPLE_ID)
# Out:
# Prompt =============================================================================================
#
# You are a helpful writing assistant. Your task is to generate essays of a given length and topic.
# Start directly with the first sentence. No titles or headings. Output only the essay text.
#
# Here is an example:
#
# Example topic: "12 Years a Slave: An Analysis of the Film Essay"
# Example length: 600 words
#
# Example output:
# The 2013 film 12 Years a Slave proved that slavery is a worldwide issue. Indeed, the film made $150 million outside the United States and $57 million in the U.S., with a production budget of $20 million (Sharf, 2020). The movie was based on the memoir Twelve Years a Slave by Solomon Northup (Ntim, 2020). It tells the story of a free African American man who was kidnapped and sold into slavery. Solomon spent twelve years away from his family, being traded from one master to another. Fortunately, the protagonist met a person who helped him deliver a message to his family and friends, who came and rescued him. This movie accurately illustrates discriminatory relationships between white slaveholders and black slaves that stemmed from the dysfunctional system in the country and prejudices in people’s mindsets at that time.
#
# The two main ethnic groups presented in this film are White and African Americans, and the three social groups are affluent slaveholders, working for middle class, and enslaved people. The movie starts with the story of a free African American violinist Solomon Northup, living with his family in Saratoga, New York (McQueen, 2013). However, he was abducted by two white men, who tortured the man and sold him into slavery, changing his name to Plat. Before they met, Solomon and these two slave traders belonged to the same middle class. However, the fact that Northup was an African American made these individuals believe that they had the right to withdraw their freedom. The two masters that Solomon had were William Ford and Edwin Epps (McQueen, 2013). The former was kind and religious, while the latter was cruel and sadistic. Since the movie was based on a real story, it indicated that slaveholders had different characters, but all had the wrong perception of race.
#
# Although 12 Years a Slave is a film about slavery, the issues of collectivism and individualism are also raised. Specifically, the main character never identified himself as an enslaved man and continued claiming he was a free citizen (McQueen, 2013). However, his counterparts on the plant had a collective mindset, imprinted in them since childhood, that slavery is normal. These people helped each other because they belonged to the same group. Although Solomon tried to become a part of this community, his individual goal to return home was above the collective values.
#
# The movie also showed prejudice, generalizations, stereotyping, and discrimination against black people. For instance, when Ford brings Solomon and Elisa to his plantation, his wife expresses her sadness that Elisa got separated from her children. However, she also stated that “something to eat and some rest” could help that woman forget her children (McQueen, 2013, 32:47-32:51). This scene demonstrated the common prejudice about slaves that they were not capable of the same feelings as white people. An example of generalization and stereotyping was how Tibeats, a carpenter, became hostile to Solomon when he showed his intelligence and gave Ford advice. In fact, Tibeats believed that Plat would never be more competent than any white individual because Plat was a “nigger” (McQueen, 2013, 36:35-36:37). Notably, before Northup became enslaved, he never experienced discrimination, but when the main character was sold into slavery, discrimination was the only attitude that he could observe.
#
# In summary, 12 Years a Slave depicts the life of enslaved people and slave owners almost two centuries ago. The film narrates a free black man’s life from the moment when he enjoyed his family’s company in the state of New York to his abduction, enslavement, and eventual liberation. Overall, the movie raised such critical issues as discrimination, prejudice, stereotyping, and generalization that allowed slaveholders to maintain this societal structure for a long time.
#
# References
#
# McQueen, S. (2013). 12 years a slave [Film]. New Regency Productions.
#
# Ntim, Z. (2020). Steve McQueen says it took 11 years to create his new anthology “Small Axe” and reveals why producers almost pulled out of his Oscar-winning film “12 Years a Slave.” Insider.
#
# Sharf, Z. (2020). Steve McQueen recalls producers rejecting “12 Years a Slave” over false beliefs about black films. Indie Wire.
#
#
# Now generate a new essay.
#
# Topic: "20+ Social Media Post Ideas to Radically Simplify Your Marketing Essay"
# Length: 300 words
#
# Write the essay now.
#
# ====================================================================================================
# 20+ Social Media Post Ideas to Radically Simplify Your Marketing Essay
#
# The digital marketing landscape is perpetually crowded, making the quest for fresh, engaging social media content a constant challenge for brands. However, by shifting focus from sheer volume to strategic simplicity, marketers can cut through the noise and foster genuine connections. A radically simplified approach begins with foundational content pillars that reliably resonate. The "Ask Me Anything" (AMA) format, for instance, democratizes interaction and positions a brand as transparent and accessible, directly building community trust. Similarly, leveraging user-generated content through branded hashtag campaigns not only provides authentic social proof but also dramatically reduces the creative burden on the marketing team itself.
#
# Simplicity also lies in repurposing and highlighting existing assets in new formats. A single comprehensive blog post or report can be deconstructed into a compelling carousel post, an infographic, a short video summary, and a series of tweet-sized insights, maximizing the return on investment for created material. Furthermore, embracing ephemeral content like Instagram Stories or Facebook Stories for real-time updates, quick polls, or behind-the-scenes glimpses creates a sense of urgency and informal connection without the need for polished production. Another profoundly simple yet effective tactic is the curated list or recommendation post, where a brand shares helpful tools, industry articles, or favorite products, establishing itself as a valuable resource rather than just a promoter.
#
# Ultimately, radical simplification in social media marketing is not about doing less, but about doing what matters with greater focus. By centering strategy on interactive, repurposed, and community-driven content ideas, brands can create a consistent, engaging presence that feels human and valuable. This approach streamlines the content calendar, deepens audience relationships, and proves that impactful marketing often stems from clarity and authenticity rather than complexity and frequency.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_3.csv"

df3.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 4. Content Abstraction (Regeneration Learning)
#
# Первый промпт:
# ```
# Identify the writing style and format of the text, excluding all semantic content and themes.
#
# Text:
# {}
# ```
#
# Второй промпт:
# ```
# Write an essay of about {} words on the topic '{}'.
#
# You are given the following style-and-format description:
# '{}'
#
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
# ```

# %%
def generate_with_content(model_name, df, prompt_raw_1, prompt_raw_2, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
        text = df.loc[i, "text"]

        prompt_1_formatted = prompt_raw_1.format(text)

        try:
            response_1 = generate_response(prompt_1_formatted)
            response_1 = response_1.lstrip()
    
            prompt_2_formatted = prompt_raw_2.format(length, title, response_1)
            response_2 = generate_response(prompt_2_formatted)
        except:
            print('ops!')
            continue
            
        response = response_2.lstrip()
    
        rows.append({
            "title": title, 
            "prompt_1": prompt_1_formatted, 
            "response": response_1,
            "prompt_2": prompt_2_formatted, 
            "text": response, 
            "model": model_name
        })

        if i % (n / 100) == 0:
            print(f"{100 * i / n}% done")
    
    return pd.DataFrame(rows)

# %%
prompt_1 = """
Identify the writing style and format of the text, excluding all semantic content and themes.

Text:
{}
"""

prompt_2 = """
Write an essay of about {} words on the topic '{}'.

You are given the following style-and-format description:
'{}'

Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
Output only the essay text.
"""

# %%
df4 = generate_with_content(MODEL, df, prompt_1, prompt_2, start=START, n=OUT_COUNT)
df4.head()
# Out:
# 0.0% done
#                                              title  \
# 0  12 Years a Slave: An Analysis of the Film Essay
#
#                                             prompt_1  \
# 0  \nIdentify the writing style and format of the...
#
#                                             response  \
# 0  The writing style is **academic-expository**, ...
#
#                                             prompt_2  \
# 0  \nWrite an essay of about 600 words on the top...
#
#                                                 text          model
# 0  Steve McQueen’s *12 Years a Slave* (2013) stan...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df4, EXAMPLE_ID)
# Out:
# Prompt 1 =============================================================================================
#
# Identify the writing style and format of the text, excluding all semantic content and themes.
#
# Text:
# The 2013 film 12 Years a Slave proved that slavery is a worldwide issue. Indeed, the film made $150 million outside the United States and $57 million in the U.S., with a production budget of $20 million (Sharf, 2020). The movie was based on the memoir Twelve Years a Slave by Solomon Northup (Ntim, 2020). It tells the story of a free African American man who was kidnapped and sold into slavery. Solomon spent twelve years away from his family, being traded from one master to another. Fortunately, the protagonist met a person who helped him deliver a message to his family and friends, who came and rescued him. This movie accurately illustrates discriminatory relationships between white slaveholders and black slaves that stemmed from the dysfunctional system in the country and prejudices in people’s mindsets at that time.
#
# The two main ethnic groups presented in this film are White and African Americans, and the three social groups are affluent slaveholders, working for middle class, and enslaved people. The movie starts with the story of a free African American violinist Solomon Northup, living with his family in Saratoga, New York (McQueen, 2013). However, he was abducted by two white men, who tortured the man and sold him into slavery, changing his name to Plat. Before they met, Solomon and these two slave traders belonged to the same middle class. However, the fact that Northup was an African American made these individuals believe that they had the right to withdraw their freedom. The two masters that Solomon had were William Ford and Edwin Epps (McQueen, 2013). The former was kind and religious, while the latter was cruel and sadistic. Since the movie was based on a real story, it indicated that slaveholders had different characters, but all had the wrong perception of race.
#
# Although 12 Years a Slave is a film about slavery, the issues of collectivism and individualism are also raised. Specifically, the main character never identified himself as an enslaved man and continued claiming he was a free citizen (McQueen, 2013). However, his counterparts on the plant had a collective mindset, imprinted in them since childhood, that slavery is normal. These people helped each other because they belonged to the same group. Although Solomon tried to become a part of this community, his individual goal to return home was above the collective values.
#
# The movie also showed prejudice, generalizations, stereotyping, and discrimination against black people. For instance, when Ford brings Solomon and Elisa to his plantation, his wife expresses her sadness that Elisa got separated from her children. However, she also stated that “something to eat and some rest” could help that woman forget her children (McQueen, 2013, 32:47-32:51). This scene demonstrated the common prejudice about slaves that they were not capable of the same feelings as white people. An example of generalization and stereotyping was how Tibeats, a carpenter, became hostile to Solomon when he showed his intelligence and gave Ford advice. In fact, Tibeats believed that Plat would never be more competent than any white individual because Plat was a “nigger” (McQueen, 2013, 36:35-36:37). Notably, before Northup became enslaved, he never experienced discrimination, but when the main character was sold into slavery, discrimination was the only attitude that he could observe.
#
# In summary, 12 Years a Slave depicts the life of enslaved people and slave owners almost two centuries ago. The film narrates a free black man’s life from the moment when he enjoyed his family’s company in the state of New York to his abduction, enslavement, and eventual liberation. Overall, the movie raised such critical issues as discrimination, prejudice, stereotyping, and generalization that allowed slaveholders to maintain this societal structure for a long time.
#
# References
#
# McQueen, S. (2013). 12 years a slave [Film]. New Regency Productions.
#
# Ntim, Z. (2020). Steve McQueen says it took 11 years to create his new anthology “Small Axe” and reveals why producers almost pulled out of his Oscar-winning film “12 Years a Slave.” Insider.
#
# Sharf, Z. (2020). Steve McQueen recalls producers rejecting “12 Years a Slave” over false beliefs about black films. Indie Wire.
#
#
# ====================================================================================================
# The writing style is **academic-expository**, characterized by formal, objective, and analytical prose. It employs declarative sentences and a measured tone to present information and analysis.
#
# The format is a **short academic essay**, structured as follows:
# *   **Introduction:** A thesis statement followed by contextual background.
# *   **Body Paragraphs:** Each begins with a clear topic sentence and develops a single analytical point using specific examples as evidence. Parenthetical citations are used to reference sources.
# *   **Conclusion:** Summarizes the main points without introducing new information.
# *   **References Section:** A formally styled list of cited works, following a common academic citation convention.
#
# The text adheres to the conventions of **analytical writing** within a humanities or social sciences context, utilizing a standard **five-paragraph essay structure** with integrated source material.
# Prompt 2 =============================================================================================
#
# Write an essay of about 600 words on the topic '12 Years a Slave: An Analysis of the Film Essay'.
#
# You are given the following style-and-format description:
# 'The writing style is **academic-expository**, characterized by formal, objective, and analytical prose. It employs declarative sentences and a measured tone to present information and analysis.
#
# The format is a **short academic essay**, structured as follows:
# *   **Introduction:** A thesis statement followed by contextual background.
# *   **Body Paragraphs:** Each begins with a clear topic sentence and develops a single analytical point using specific examples as evidence. Parenthetical citations are used to reference sources.
# *   **Conclusion:** Summarizes the main points without introducing new information.
# *   **References Section:** A formally styled list of cited works, following a common academic citation convention.
#
# The text adheres to the conventions of **analytical writing** within a humanities or social sciences context, utilizing a standard **five-paragraph essay structure** with integrated source material.'
#
# Start directly with the first sentence of the essay. Absolutely no title or heading of any kind.
# Output only the essay text.
#
# ====================================================================================================
# 12 Years a Slave: An Analysis of the Film Essay
#
# Steve McQueen’s *12 Years a Slave* (2013) stands as a landmark cinematic achievement not merely for its unflinching depiction of American slavery, but for its profound methodological shift in narrating the institution’s horrors. While many historical dramas risk aestheticizing trauma or offering redemptive narratives, McQueen’s film rigorously employs a framework of embodied testimony and a persistent present tense to dismantle the spectator’s historical distance, forcing a confrontation with slavery’s systematic and psychological brutality. By centering the specific, verified autobiography of Solomon Northup and utilizing a visual language of sustained observation, the film transcends conventional period drama to function as a vital act of historical witnessing. This essay will argue that *12 Years a Slave* achieves its power through its commitment to a subjective, sensory realism, its deconstruction of the “benevolent master” myth, and its symbolic use of landscape, collectively rendering the antebellum South not as a historical backdrop but as an active, carceral state.
#
# The film’s most potent analytical tool is its insistence on Solomon’s subjective, embodied experience, conveyed through a sensory realism that refuses to look away. McQueen’s directorial signature—long, static takes—forces the audience to endure scenes in real time, mirroring Solomon’s trapped consciousness. The protracted scene of Solomon hanging from a tree, his toes barely scraping the mud as daily life indifferently continues around him, is a masterclass in this technique (McQueen, 2013). The camera does not cut away; it observes, making the viewer complicit in the prolonged witnessing of agony. This methodologically rejects a sensationalized or edited portrayal of violence in favor of one that is psychological and durational. As scholar Claudia Springer notes, the film “makes viewers feel the passing of time as a form of torture,” aligning our temporal experience with the protagonist’s (Springer, 2014, p. 52). This embodied perspective is further anchored in Chiwetel Ejiofor’s performance, which often communicates profound interiority through silence and gaze, emphasizing the internal survival mechanisms slavery demanded.
#
# Furthermore, the film conducts a rigorous analysis of the slave system’s ideological machinery by contrasting two plantation owners, Ford and Epps. The character of Master Ford, portrayed as comparatively kind, is not presented as an exception but as a critical component of the system’s maintenance. His “benevolence”—giving Solomon a violin, acknowledging his intelligence—serves to illustrate how paternalism could be a more insidious form of control, fostering false hope and complicating resistance. This sets up the stark contrast with Edwin Epps, whose capricious brutality, justified by twisted biblical scripture, represents the system’s raw, psychotic core. The analysis lies in the demonstration that both models—the paternalist and the terrorist—are interdependent parts of the same economic and social institution. Epps’s violent instability is the ultimate enforcement mechanism for a system that Ford’s gentler facade helps to legitimize. The famous “Patsey” scene, where Epps forces Solomon to whip her, devastatingly reveals how the system corrupts all relationships, turning victims into instruments of their own communal destruction (McQueen, 2013).
#
# Finally, *12 Years a Slave* employs the visual motif of the Southern landscape not as a site of pastoral beauty but as a character of oppressive, deceptive expanse. Cinematographer Sean Bobbitt’s lush, sun-drenched visuals are deliberately at odds with the narrative’s horror, creating a profound dissonance. The beautiful, sprawling fields of cotton are revealed as vast open-air prisons where escape is rendered nearly impossible by geography and terror. This symbolic use of landscape critiques the romantic “moonlight and magnolias” myth of the Old South. The scene where a fugitive slave is hanged in a breathtakingly beautiful grove of trees encapsulates this contradiction perfectly (McQueen, 2013). The natural world is not a refuge but a witness and an accomplice, its beauty intensifying the horror it contains. This environmental framing underscores slavery as a system that corrupted not just human relations but the very perception of the American land itself.
#
# In conclusion, *12 Years a Slave* utilizes its cinematic form to perform a deep historical and psychological analysis of slavery. Through its commitment to subjective, durational realism, it forces a visceral engagement with the past. By dissecting the archetypes of Ford and Epps, it exposes the complementary mechanisms of paternalism and terror that sustained the plantation economy. And by re-coding the Southern landscape as a carceral space, it dismantles enduring romantic myths. The film’s ultimate power derives from its unwavering focus on the process of witnessing—both Solomon’s witness of his own experience and the audience’s compelled witness to it. In doing so, McQueen’s film moves beyond dramatization to become an essential work of historical interpretation, insisting that the reality of slavery be confronted in all its relentless, unromanticized brutality.
#
# **References**
#
# McQueen, S. (Director). (2013). *12 Years a Slave* [Film]. Fox Searchlight Pictures.
#
# Springer, C. (2014). “Spielberg’s *Lincoln* and McQueen’s *12 Years a Slave*: The Performance of History.” *Film & History: An Interdisciplinary Journal*, 44(2), 45-55.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_4.csv"

df4.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)

# %% [markdown]
# ### Вариант 5. Outline‑guided Text Generation
#
# Первый промпт:
# ```
# You are an academic writing instructor.
# Create a well-structured outline for an academic essay on the following topic: {}.
#
# Requirements:
#
# The outline must include the following sections:
# - Introduction
# - Main Body (2–4 thematic sections)
# - Counterarguments / Alternative Perspectives
# - Conclusion
#
# Each section should contain 2–3 concise bullet points describing the key ideas or arguments.
# The outline should reflect a clear thesis-driven structure.
# Use formal academic language.
#
# Do not write the essay itself
# ```
#
# Второй промпт:
# ```
# You are an academic essay writer.
# Write a coherent academic essay of about {} words on the topic '{}' strictly following the outline below.
#
# Outline:
# {}
#
# Requirements:
# - Follow the outline in the given order without adding or removing sections.
# - Develop each bullet point into a full, well-argued paragraph.
# - Maintain a formal academic tone and clear argumentative logic.
# - Use appropriate academic transitions and signposting.
# - Do not introduce new arguments or themes not present in the outline.
# - Avoid informal language, personal anecdotes, and unsupported claims.
# ```

# %%
def generate_with_plan(model_name, df, prompt_raw_1, prompt_raw_2, start=0, n=5000):
    rows = []
    for i in range(start, start + n):
        title = df.loc[i, "title"]
        length = word_count(df.loc[i, "text"])
        text = df.loc[i, "text"]
    
        prompt_1_formatted = prompt_raw_1.format(title)

        try:
            response_1 = generate_response(prompt_1_formatted)
            response_1 = response_1.lstrip()
    
            prompt_2_formatted = prompt_raw_2.format(length, title, response_1)
            response_2 = generate_response(prompt_2_formatted)
        except:
            print('ops!')
            continue
            
        response = response_2.lstrip()
    
        rows.append({
            "title": title, 
            "prompt_1": prompt_1_formatted, 
            "response": response_1,
            "prompt_2": prompt_2_formatted, 
            "text": response, 
            "model": model_name
        })

        if i % (n / 100) == 0:
            print(f"{100 * i / n}% done")
    
    return pd.DataFrame(rows)

# %%
prompt_1 = """
You are an academic writing instructor.
Create a well-structured outline for an academic essay on the following topic: {}.

Requirements:

The outline must include the following sections:
- Introduction
- Main Body (2–4 thematic sections)
- Counterarguments / Alternative Perspectives
- Conclusion

Each section should contain 2–3 concise bullet points describing the key ideas or arguments.
The outline should reflect a clear thesis-driven structure.
Use formal academic language.

Do not write the essay itself
"""

prompt_2 = """
You are an academic essay writer.
Write a coherent academic essay of about {} words on the topic '{}' strictly following the outline below.

Outline:
{}

Requirements:
- Follow the outline in the given order without adding or removing sections.
- Develop each bullet point into a full, well-argued paragraph.
- Maintain a formal academic tone and clear argumentative logic.
- Use appropriate academic transitions and signposting.
- Do not introduce new arguments or themes not present in the outline.
- Avoid informal language, personal anecdotes, and unsupported claims.
"""

# %%
df5 = generate_with_plan(MODEL, df, prompt_1, prompt_2, start=START, n=OUT_COUNT)
df5.head()
# Out:
# 0.0% done
#                                              title  \
# 0  12 Years a Slave: An Analysis of the Film Essay
#
#                                             prompt_1  \
# 0  \nYou are an academic writing instructor.\nCre...
#
#                                             response  \
# 0  **Academic Essay Outline: *12 Years a Slave: A...
#
#                                             prompt_2  \
# 0  \nYou are an academic essay writer.\nWrite a c...
#
#                                                 text          model
# 0  **12 Years a Slave: An Analysis of the Film**\...  deepseek-chat

# %% [markdown]
# #### Пример:

# %%
print_example(df5, EXAMPLE_ID)
# Out:
# Prompt 1 =============================================================================================
#
# You are an academic writing instructor.
# Create a well-structured outline for an academic essay on the following topic: 12 Years a Slave: An Analysis of the Film Essay.
#
# Requirements:
#
# The outline must include the following sections:
# - Introduction
# - Main Body (2–4 thematic sections)
# - Counterarguments / Alternative Perspectives
# - Conclusion
#
# Each section should contain 2–3 concise bullet points describing the key ideas or arguments.
# The outline should reflect a clear thesis-driven structure.
# Use formal academic language.
#
# Do not write the essay itself
#
# ====================================================================================================
# **Academic Essay Outline: *12 Years a Slave: An Analysis of the Film***
#
# **Thesis Statement:** While grounded in Solomon Northup’s historical narrative, Steve McQueen’s *12 Years a Slave* transcends mere biographical adaptation to function as a profound cinematic indictment of the “peculiar institution.” Through its unflinching aesthetic, structural choices, and complex characterizations, the film systematically deconstructs the ideological foundations of slavery, exposing its core as a regime of psychological terror and dehumanization sustained by economic interest and systemic violence.
#
# ---
#
# **I. Introduction**
# *   Establish the film’s dual significance as a critically acclaimed adaptation of a primary slave narrative and a landmark work of contemporary historical cinema.
# *   Present the central thesis: The film’s power lies not in its historical fidelity alone, but in its formal and narrative techniques that analytically expose the mechanisms of slavery.
# *   Provide a brief roadmap of the essay’s main thematic sections.
#
# **II. Main Body: Thematic Analysis**
#
# **A. The Aesthetics of Trauma: Unflinching Realism and Embodied Suffering**
# *   Analyze McQueen’s use of prolonged, static shots (e.g., the lynching sequence, Patsey’s whipping) to force a contemplative, uncomfortable gaze upon violence, rejecting sensationalism for a meditation on endurance and spectatorship.
# *   Discuss the sound design and score as tools for conveying psychological interiority and rupture, contrasting the diegetic sounds of brutality with moments of haunting silence or non-diegetic music.
#
# **B. Structural Critique: The Systems and Ideologies of Enslavement**
# *   Examine how the film frames slavery as a total economic and legal system, highlighting scenes of slave markets, accounting, and property law to demonstrate the commodification of human beings.
# *   Analyze the portrayal of slaveholding ideology through characters like Edwin Epps (biblical justification) and William Ford (benevolent paternalism), arguing the film reveals both as fraudulent rationalizations for brutality and exploitation.
#
# **C. Resistance and Agency within Confinement**
# *   Argue that Northup’s narrative arc showcases forms of resistance beyond open rebellion: intellectual assertion (his identity as a free man), skilled labor as limited leverage, and the preservation of memory and family ties as psychological sustenance.
# *   Contrast Northup’s survival strategies with the more tragic, yet equally agential, resistance of Patsey, whose demands for dignity and ultimate despair critique the limits of endurance under extreme subjugation.
#
# **III. Counterarguments / Alternative Perspectives**
# *   Acknowledge and engage with critiques that the film’s graphic violence risks aestheticizing suffering or reducing the Black experience to one of victimhood for a predominantly white audience.
# *   Address perspectives that the film’s focus on a free-born, educated Northern protagonist offers a less representative experience of slavery than that of someone born into bondage, potentially centering a more “palatable” narrative for viewers.
# *   Counter these by arguing that the film’s formal restraint mitigates sensationalism, and that Northup’s unique perspective serves as a powerful analytical device, using his outsider-insider status to logically dissect the system’s absurdities and horrors.
#
# **IV. Conclusion**
# *   Synthesize the main arguments, reiterating how the film’s cinematic language—its aesthetics, structure, and character studies—coheres into a systematic analysis of slavery’s core violence.
# *   Reflect on the film’s contribution to historical understanding and cultural memory, positioning it as a work that uses the past to interrogate enduring legacies of racism, trauma, and injustice.
# *   Offer a final statement on the film’s enduring power as both a historical document and a transformative work of art that demands ethical engagement from its audience.
# Prompt 2 =============================================================================================
#
# You are an academic essay writer.
# Write a coherent academic essay of about 600 words on the topic '12 Years a Slave: An Analysis of the Film Essay' strictly following the outline below.
#
# Outline:
# **Academic Essay Outline: *12 Years a Slave: An Analysis of the Film***
#
# **Thesis Statement:** While grounded in Solomon Northup’s historical narrative, Steve McQueen’s *12 Years a Slave* transcends mere biographical adaptation to function as a profound cinematic indictment of the “peculiar institution.” Through its unflinching aesthetic, structural choices, and complex characterizations, the film systematically deconstructs the ideological foundations of slavery, exposing its core as a regime of psychological terror and dehumanization sustained by economic interest and systemic violence.
#
# ---
#
# **I. Introduction**
# *   Establish the film’s dual significance as a critically acclaimed adaptation of a primary slave narrative and a landmark work of contemporary historical cinema.
# *   Present the central thesis: The film’s power lies not in its historical fidelity alone, but in its formal and narrative techniques that analytically expose the mechanisms of slavery.
# *   Provide a brief roadmap of the essay’s main thematic sections.
#
# **II. Main Body: Thematic Analysis**
#
# **A. The Aesthetics of Trauma: Unflinching Realism and Embodied Suffering**
# *   Analyze McQueen’s use of prolonged, static shots (e.g., the lynching sequence, Patsey’s whipping) to force a contemplative, uncomfortable gaze upon violence, rejecting sensationalism for a meditation on endurance and spectatorship.
# *   Discuss the sound design and score as tools for conveying psychological interiority and rupture, contrasting the diegetic sounds of brutality with moments of haunting silence or non-diegetic music.
#
# **B. Structural Critique: The Systems and Ideologies of Enslavement**
# *   Examine how the film frames slavery as a total economic and legal system, highlighting scenes of slave markets, accounting, and property law to demonstrate the commodification of human beings.
# *   Analyze the portrayal of slaveholding ideology through characters like Edwin Epps (biblical justification) and William Ford (benevolent paternalism), arguing the film reveals both as fraudulent rationalizations for brutality and exploitation.
#
# **C. Resistance and Agency within Confinement**
# *   Argue that Northup’s narrative arc showcases forms of resistance beyond open rebellion: intellectual assertion (his identity as a free man), skilled labor as limited leverage, and the preservation of memory and family ties as psychological sustenance.
# *   Contrast Northup’s survival strategies with the more tragic, yet equally agential, resistance of Patsey, whose demands for dignity and ultimate despair critique the limits of endurance under extreme subjugation.
#
# **III. Counterarguments / Alternative Perspectives**
# *   Acknowledge and engage with critiques that the film’s graphic violence risks aestheticizing suffering or reducing the Black experience to one of victimhood for a predominantly white audience.
# *   Address perspectives that the film’s focus on a free-born, educated Northern protagonist offers a less representative experience of slavery than that of someone born into bondage, potentially centering a more “palatable” narrative for viewers.
# *   Counter these by arguing that the film’s formal restraint mitigates sensationalism, and that Northup’s unique perspective serves as a powerful analytical device, using his outsider-insider status to logically dissect the system’s absurdities and horrors.
#
# **IV. Conclusion**
# *   Synthesize the main arguments, reiterating how the film’s cinematic language—its aesthetics, structure, and character studies—coheres into a systematic analysis of slavery’s core violence.
# *   Reflect on the film’s contribution to historical understanding and cultural memory, positioning it as a work that uses the past to interrogate enduring legacies of racism, trauma, and injustice.
# *   Offer a final statement on the film’s enduring power as both a historical document and a transformative work of art that demands ethical engagement from its audience.
#
# Requirements:
# - Follow the outline in the given order without adding or removing sections.
# - Develop each bullet point into a full, well-argued paragraph.
# - Maintain a formal academic tone and clear argumentative logic.
# - Use appropriate academic transitions and signposting.
# - Do not introduce new arguments or themes not present in the outline.
# - Avoid informal language, personal anecdotes, and unsupported claims.
#
# ====================================================================================================
# 12 Years a Slave: An Analysis of the Film Essay
#
# **12 Years a Slave: An Analysis of the Film**
#
# Steve McQueen’s *12 Years a Slave* occupies a singular position in contemporary cinema, serving both as a faithful adaptation of Solomon Northup’s 1853 autobiographical narrative and as a landmark work of historical filmmaking that garnered critical acclaim and mainstream recognition. Its significance, however, extends beyond its meticulous period detail or its status as a primary source brought to screen. The film’s profound power derives from its deliberate formal and narrative architecture, which transforms a personal story into a systemic critique. While grounded in historical testimony, *12 Years a Slave* transcends mere biographical adaptation to function as a profound cinematic indictment of the “peculiar institution.” Through its unflinching aesthetic, structural choices, and complex characterizations, the film systematically deconstructs the ideological foundations of slavery, exposing its core as a regime of psychological terror and dehumanization sustained by economic interest and systemic violence. This essay will first analyze the film’s aesthetics of trauma, then examine its structural critique of enslaving systems, and finally explore its nuanced portrayal of resistance, before engaging with key counterarguments.
#
# **The Aesthetics of Trauma: Unflinching Realism and Embodied Suffering**
# McQueen’s directorial approach weaponizes cinematic form to convey the visceral and psychological reality of enslavement. Central to this is his use of prolonged, static shots that force an uncomfortable, contemplative gaze upon violence, rejecting sensationalism for a meditation on endurance. In the harrowing lynching sequence, the camera remains fixed on Northup as he struggles for toehold purchase in the mud for what feels like an eternity, while the mundane life of the plantation continues blurred in the background. This technique does not exploit suffering but instead immerses the viewer in the protracted agony of the moment, implicating them in the act of witnessing. Similarly, the brutal whipping of Patsey is filmed in a single, unbroken take, refusing to look away from the atrocity and thus denying narrative or visual relief. The sound design and score further articulate psychological interiority. The diegetic cracks of the whip, the rustle of chains, and the agonized cries are often juxtaposed with moments of haunting silence or the dissonant, non-diegetic score by Hans Zimmer, which externalizes the internal rupture and profound isolation of the enslaved characters, mapping trauma onto the very audio landscape of the film.
#
# **Structural Critique: The Systems and Ideologies of Enslavement**
# Beyond individual suffering, the film meticulously frames slavery as a totalizing economic and legal system. It visually and narratively highlights the mechanisms of commodification, from the clinical brutality of the Washington, D.C. slave pen to the dehumanizing inspections at the New Orleans market. Scenes of ledger-keeping and discussions of property law, such as the dispute over Northup’s ownership between Ford and Tibeats, coldly demonstrate how human beings were legally and bureaucratically rendered as assets. This systemic view is extended to the portrayal of slaveholding ideology, which the film reveals as a series of fraudulent rationalizations. Edwin Epps embodies the warped biblical justification, using scripture to sanction his rape and torture, while William Ford represents the myth of benevolent paternalism. Ford’s genuine but ineffectual kindness, culminating in his inability to protect Northup, critically exposes how even “good” masters were complicit in and sustained by a fundamentally evil system, their paternalism serving only to mask the underlying reality of exploitation and violence.
#
# **Resistance and Agency within Confinement**
# Within this carceral system, the film presents a complex spectrum of resistance that moves beyond simplistic notions of rebellion. Northup’s narrative arc showcases intellectual and psychological assertion. His repeated, often perilous, declarations of his free-born status and his skilled labor as a violinist and carpenter become forms of leverage and identity preservation, however limited. His relentless hold on the memory of his family and his former self acts as psychological sustenance, a private rebellion against the system’s goal of spiritual annihilation. This is powerfully contrasted with the resistance of Patsey, whose demands for a bar of soap constitute a profound claim to dignity and personhood. Her ultimate despair and plea for death, tragically, represent another form of agency—a final assertion of control over her own body and existence in the face of unbearable subjugation. Her story critiques the absolute limits of endurance and expands the film’s understanding of resistance to include tragic, yet agential, responses to absolute power.
#
# **Counterarguments / Alternative Perspectives**
# Some critiques of the film merit engagement, particularly those concerning its representation of violence and its protagonist. One perspective argues that the film’s graphic brutality risks aestheticizing suffering or reducing the Black experience to one of victimhood for a predominantly white audience’s consumption. Others note that by focusing on a free-born, educated Northern protagonist, the film potentially centers a more “palatable” or exceptional narrative, sidestepping the more representative experience of generational, born-into bondage. However, these critiques can be countered by the film’s own formal strategies. The unflinching, restrained camerawork discussed earlier mitigates against sensationalism, aiming not for spectacle but for a sober, ethical contemplation of historical truth. Furthermore, Northup’s unique perspective is precisely what makes the film such a potent analytical tool. His outsider-insider status—a free man suddenly thrust into bondage—allows the narrative to logically dissect the system’s absurdities and horrors from a perspective that mirrors the audience’s own potential disbelief, making the deconstruction of slaveholding ideology all the more methodical and devastating.
#
# **Conclusion**
# In synthesis, *12 Years a Slave* coheres as a systematic cinematic analysis of slavery’s core violence. Its aesthetic choices make trauma palpable, its structural focus exposes the economic and ideological machinery of oppression, and its character studies reveal the multifaceted nature of agency within confinement. The film’s contribution to historical understanding and cultural memory is therefore dual: it resurrects a vital primary testimony while using the full arsenal of cinematic art to interrogate the past in a way that resonates with present legacies of racism and injustice. Ultimately, McQueen’s film transcends its genre, standing as a transformative work that demands not passive viewing but active, ethical engagement, compelling its audience to witness, reflect, and remember the brutal system it so masterfully indicts.
# ====================================================================================================

# %%
file_path = f"../datasets/{OUT_FILE_PREFIX}_5.csv"

df5.to_csv(
    file_path, 
    mode="a",
    header=not os.path.exists(file_path),
    index=False,
    encoding="utf-8",
)
